# %%
# !ls data/han/AWS/
# Out:
# 남이섬_2016.xlsx  남이섬_2020.xlsx  청평_2019.xlsx  화천_2018.xlsx
# 남이섬_2017.xlsx  청평_2016.xlsx    청평_2020.xlsx  화천_2019.xlsx
# 남이섬_2018.xlsx  청평_2017.xlsx    화천_2016.xlsx  화천_2020.xlsx
# 남이섬_2019.xlsx  청평_2018.xlsx    화천_2017.xlsx

# %%
# !pwd
# Out:
# /home/cjinw/work/water-quality/rnn

# %%
# %matplotlib widget
import pandas as pd
import numpy as np
from glob import glob
import os
import datetime
import matplotlib.pyplot as plt
    
from tensorflow.keras.layers import Input, Concatenate, Dot, Add, ReLU, Activation
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.optimizers import Adam
import tensorflow as tf
from tensorflow import keras

# %%
# for Korean in plot
import matplotlib
import matplotlib.font_manager as fm
fm.get_fontconfig_fonts()
font_location = '/usr/share/fonts/truetype/nanum/NanumGothicCoding.ttf'
#font_location = '/usr/share/fonts/opentype/noto/NotoSansCJK-Regular.ttc'
# font_location = 'C:/Windows/Fonts/NanumGothic.ttf' # For Windows
fprop = fm.FontProperties(fname=font_location)

# %%
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"]="0,1"

# %%
# folder = 'data/han/자동'
# folder = 'data/han/수질'
# folder = 'data/han/AWS'
# folder = 'data/nakdong/자동'
# folder = 'data/gum/자동'
folder = 'data/yeongsan1/자동'

# ## 한강
# ## 자동
# file_names = [['가평_2016.xlsx','가평_2017.xlsx','가평_2018.xlsx', '가평_2019.xlsx'], 
#               ['의암호_2016.xlsx','의암호_2017.xlsx','의암호_2018.xlsx', '의암호_2019.xlsx'],
#               ['서상_2016.xlsx','서상_2017.xlsx','서상_2018.xlsx', '서상_2019.xlsx']]

## 수질
# file_names = [['가평천3_2016.xlsx','가평천3_2017.xlsx','가평천3_2018.xlsx', '가평천3_2019.xlsx'],
#               ['대성리_2016.xlsx','대성리_2017.xlsx','대성리_2018.xlsx', '대성리_2019.xlsx'],
#               ['청평댐3_2016.xlsx','청평댐3_2017.xlsx','청평댐3_2018.xlsx', '청평댐3_2019.xlsx'],
#               ['춘천댐1_2016.xlsx','춘천댐1_2017.xlsx','춘천댐1_2018.xlsx', '춘천댐1_2019.xlsx'],
#               ['대성리_2016.xlsx','대성리_2017.xlsx','대성리_2018.xlsx', '대성리_2019.xlsx'],
#               ['의암_2016.xlsx','의암_2017.xlsx','의암_2018.xlsx', '의암_2019.xlsx'],
#               ['춘성교_2016.xlsx','춘성교_2017.xlsx','춘성교_2018.xlsx', '춘성교_2019.xlsx'],
#               ['남이섬_2016.xlsx','남이섬_2017.xlsx','남이섬_2018.xlsx', '남이섬_2019.xlsx'],
#               ['청평댐3_2016.xlsx','청평댐3_2017.xlsx','청평댐3_2018.xlsx', '청평댐3_2019.xlsx'],
#               ['춘천_2016.xlsx','춘천_2017.xlsx','춘천_2018.xlsx', '춘천_2019.xlsx']
#              ]


## AWS
# file_names = [['남이섬_2016.xlsx','남이섬_2017.xlsx','남이섬_2018.xlsx', '남이섬_2018.xlsx'],
#               ['청평_2016.xlsx', '청평_2017.xlsx', '청평_2018.xlsx', '청평_2019.xlsx'],
#               ['화천_2016.xlsx', '화천_2017.xlsx', '화천_2018.xlsx', '화천_2019.xlsx']]
 

    
## 낙동강
# #자동
# file_names = [['도개_2016.xlsx','도개_2017.xlsx','도개_2018.xlsx', '도개_2019.xlsx'],
#               ['신암_2016.xlsx','신암_2017.xlsx','신암_2018.xlsx', '신암_2019.xlsx'],
#               ['회상_2016.xlsx','회상_2017.xlsx','회상_2018.xlsx', '회상_2019.xlsx']]


## 금강
#자동
# file_names = [['현도_2016.xlsx','현도_2017.xlsx','현도_2018.xlsx', '현도_2019.xlsx'],
#               ['대청호_2016.xlsx','대청호_2017.xlsx','대청호_2018.xlsx', '대청호_2019.xlsx'],
#               ['옥천천_2016.xlsx','옥천천_2017.xlsx','옥천천_2018.xlsx', '옥천천_2019.xlsx'],
#               ['장계_2016.xlsx','장계_2017.xlsx','장계_2018.xlsx', '장계_2019.xlsx']]
             

    
    
## 영산강
#자동
# file_names = [['나주_2016.xlsx','나주_2017.xlsx','나주_2018.xlsx', '나주_2019.xlsx'],
#               ['지석천_2016.xlsx','지석천_2017.xlsx','지석천_2018.xlsx', '지석천_2019.xlsx'],
#               ['용봉_2016.xlsx','용봉_2017.xlsx','용봉_2018.xlsx', '용봉_2019.xlsx'],
#               ['서창교_2016.xlsx','서창교_2017.xlsx','서창교_2018.xlsx', '서창교_2019.xlsx'],
#               ['우치_2016.xlsx','우치_2017.xlsx','우치_2018.xlsx', '우치_2019.xlsx']]
              
    
file_names = [['서창교_2016.xlsx','서창교_2017.xlsx','서창교_2018.xlsx', '서창교_2019.xlsx']]

# %%
target_col = '용존산소'
# 각각의 강 마다, 측정소 별로 column을 맞춰야함
# 0: 자동, 1: 수질, 2: AWS(ASOS), 
han = [':,2:', ':,28:45', ':,26:29']
nakdong = [':,2:', ':,2:12']
gum = [':,2:'] #, ':,28:45', ':,26:29']
# gain_han = ['save/han/1', 'save/han/2', 'save/han/3']

# interpolation_option = True
interpolation_option = False
# gain_save_path = gain_han[2]

iloc_val = gum[0]
iloc_val
# Out:
# ':,2:'

# %%
def make_columns(df):
    column_list = ['측정날짜', '측정소명', '수온', '수소이온농도','전기전도도', '용존산소', '총유기탄소', '총질소', '총인', '클로로필-a']
    list_df = pd.DataFrame(columns=column_list)
    list_df
    df = df.drop(columns=df.columns.difference(column_list))
    new_column = list_df.columns.difference(df.columns)
#     print(new_column)
    if not new_column.empty :
        print("Make_columns")
        for i in range(new_column.shape[0]):
            df[new_column[i]] = pd.Series()
#     print('columns')
#     print(df.columns)
    return df

# %%
def make_timeseries(df, interpolate=None):
    print(df.shape)
    date_col = df.columns[0]
    df[date_col] = pd.to_datetime(df[date_col])
    df = df[df[date_col].notna()]

    year = pd.DatetimeIndex(df[date_col]).year.astype(np.int64)

    start = str(year[0]) + "-01-01 00:00"
#     start

    end = str(year[0]) + "-12-31 23:00"
#     end

    time_series = pd.date_range(start = start, end = end, freq='H')
    time_series
    time_series = pd.DataFrame(time_series)
    time_series.columns = [date_col]   
    time_series

    df = pd.concat([time_series, df], axis=0)
    df = df.drop_duplicates([date_col], keep="last")
    df = df.sort_values([date_col], axis=0)
    
    if interpolate :
        print('interpolation')
        df = df.interpolate(metod='spline', order=2, limit_direction='both')
        
    print(df.shape)
    return df

# %%
def make_dataframe(file_names, iloc_val, interpolate=None):
    day = 24*60*60
    year = (365.2425)*day

    df_full = []
    df = []
    
    for loc in range(len(file_names)):
    
        df_loc = []
        for y in range(len(file_names[loc])):
            path = os.path.join(folder, file_names[loc][y])
            print(file_names[loc][y])
            df_tmp = make_timeseries(pd.read_excel(path), interpolate=interpolate)
#             df_tmp = pd.read_excel(path).dropna(axis='columns', how = 'all')
            df_tmp = make_columns(df_tmp)
            
    #         df_tmp = pd.read_excel(path).dropna(axis='columns', how = 'all')
    #         print(df_tmp.head) 
            df_loc.append(df_tmp)
#             df_loc.append(pd.read_excel(path))
        df_full.append(pd.concat(df_loc))
    #     df.append(df_full[loc].iloc[:,2:11])
        df.append(eval(f"df_full[loc].iloc[{iloc_val}]"))
    #     df.append(df_full[loc].iloc[:, [2,3,4,5,6,7,10]])
    #     df.append(df_full[loc].iloc[:, 2:11])
        date_time = pd.to_datetime(df_full[loc].iloc[:, 0], format='%Y.%m.%d %H:%M', utc=True)
        timestamp_s = date_time.map(datetime.datetime.timestamp)
        df[loc]['Day sin'] = np.sin(timestamp_s * (2 * np.pi / day))
        df[loc]['Day cos'] = np.cos(timestamp_s * (2 * np.pi / day))
        df[loc]['Year sin'] = np.sin(timestamp_s * (2 * np.pi / year))
        df[loc]['Year cos'] = np.cos(timestamp_s * (2 * np.pi / year))
        df[loc] = df[loc].reset_index(drop=True)
        
#         print(df[loc].shape[0])
#         rows = df[loc].shape[0]
#         percentage = round(rows * 0.7)
#         df[loc] = df[loc].dropna(axis='columns',  thresh=percentage)
        

    
    return df

# %%
def normalize(df):
    # normalize data
    df_all = pd.concat(df)
    
    train_mean = df_all.mean()
    train_std = df_all.std()
    for i in range(len(file_names)):
        df[i] = (df[i]-train_mean)/train_std
    
    
    return df_all, train_mean, train_std

# %%
def min_max_normalize(df):
    # normalize data
    df_all = pd.concat(df)
    
    train_min = df_all.min()
    train_max = df_all.max()
    for i in range(len(file_names)):
        df[i] = (df[i]-train_min)/(train_max - train_min)       
    
    
    return df_all, train_min, train_max

# %%
##for normal
# df = make_dataframe(file_names, iloc_val)
## for interpolation
df = make_dataframe(file_names, iloc_val, interpolate=interpolation_option)
df_all, train_mean, train_std = normalize(df)
# df_all, train_mean, train_std = min_max_normalize(df)
# Out:
# 서창교_2016.xlsx
# (8697, 31)
# (8784, 31)
# Make_columns
# 서창교_2017.xlsx
# /home/cjinw/work/tf-2/lib/python3.7/site-packages/ipykernel_launcher.py:11: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   # This is added back by InteractiveShellApp.init_path()
# (8743, 31)
# (8760, 31)
# Make_columns
# 서창교_2018.xlsx
# (8756, 31)
# (8760, 31)
# Make_columns
# 서창교_2019.xlsx
# (8760, 31)
# (8760, 31)
# Make_columns

# %%
train_mean, train_std
# Out:
# (수온          1.831678e+01
#  수소이온농도      6.764941e+00
#  전기전도도       4.007425e+02
#  용존산소        5.361571e+00
#  총유기탄소       5.296327e+00
#  클로로필-a      1.890899e+01
#  총인                   NaN
#  총질소                  NaN
#  Day sin     6.037108e-15
#  Day cos     2.747555e-15
#  Year sin   -5.681266e-08
#  Year cos    2.053380e-05
#  dtype: float64,
#  수온           7.516481
#  수소이온농도       0.343338
#  전기전도도       94.598576
#  용존산소         3.271126
#  총유기탄소        1.346887
#  클로로필-a      22.553221
#  총인                NaN
#  총질소               NaN
#  Day sin      0.707117
#  Day cos      0.707117
#  Year sin     0.707110
#  Year cos     0.707124
#  dtype: float64)

# %% [markdown]
# ##

# %%
# just for Create WidnowGenerator 
train_df = df[0]
val_df = df[0]
test_df = df[0]

# %%
class WindowGenerator():
  def __init__(self, input_width, label_width, shift,
               train_df=train_df, val_df=val_df, test_df=test_df,
            #train_df=None, val_df=None, test_df=None,
#                out_features = None,
               out_features = None, out_num_features = None,
               label_columns=None):
    # Store the raw data.
    self.train_df = train_df
    self.val_df = val_df
    self.test_df = test_df

    # Work out the label column indices.
    self.label_columns = label_columns
    if label_columns is not None:
      self.label_columns_indices = {name: i for i, name in
                                    enumerate(label_columns)}
    self.column_indices = {name: i for i, name in
                           enumerate(train_df.columns)}

    # Work out the window parameters.
    self.input_width = input_width
    self.label_width = label_width
    self.shift = shift

    self.total_window_size = input_width + shift

    self.input_slice = slice(0, input_width)
    self.input_indices = np.arange(self.total_window_size)[self.input_slice]

    self.label_start = self.total_window_size - self.label_width
    self.labels_slice = slice(self.label_start, None)
    self.label_indices = np.arange(self.total_window_size)[self.labels_slice]

  def __repr__(self):
    return '\n'.join([
        f'Total window size: {self.total_window_size}',
        f'Input indices: {self.input_indices}',
        f'Label indices: {self.label_indices}',
        f'Label column name(s): {self.label_columns}'])

# %%
def split_window(self, features):
  inputs = features[:, self.input_slice, :]
  labels = features[:, self.labels_slice, :]
  if self.label_columns is not None:
    labels = tf.stack(
        [labels[:, :, self.column_indices[name]] for name in self.label_columns],
        axis=-1)

  # Slicing doesn't preserve static shape information, so set the shapes
  # manually. This way the `tf.data.Datasets` are easier to inspect.
  inputs.set_shape([None, self.input_width, None])
  labels.set_shape([None, self.label_width, None])

  return inputs, labels

WindowGenerator.split_window = split_window

# %%
def plot(self, model=None, plot_col='T (degC)', max_subplots=3):
  inputs, labels = self.example
  plt.figure(figsize=(10, 8))
  plot_col_index = self.column_indices[plot_col]
  max_n = min(max_subplots, len(inputs))
  for n in range(max_n):
    plt.subplot(3, 1, n+1)
    plt.ylabel(f'{plot_col} [normed]', fontproperties=fprop)
    plt.plot(self.input_indices, inputs[n, :, plot_col_index],
             label='Inputs', marker='.', zorder=-10)

    if self.label_columns:
      label_col_index = self.label_columns_indices.get(plot_col, None)
    else:
      label_col_index = plot_col_index

    if label_col_index is None:
      continue

    plt.scatter(self.label_indices, labels[n, :, label_col_index],
                edgecolors='k', label='Labels', c='#2ca02c', s=64)
    if model is not None:
      predictions = model(inputs)
      plt.scatter(self.label_indices, predictions[n, :, label_col_index],
                  marker='X', edgecolors='k', label='Predictions',
                  c='#ff7f0e', s=64)

    if n == 0:
      plt.legend()

  plt.xlabel('Time [h]')

WindowGenerator.plot = plot

# %%
@property
def train(self):
  return self.make_dataset(self.train_df)

@property
def val(self):
  return self.make_dataset(self.val_df)

@property
def test(self):
  return self.make_dataset(self.test_df)

@property
def example(self):
  """Get and cache an example batch of `inputs, labels` for plotting."""
  result = getattr(self, '_example', None)
  if result is None:
    # No example batch was found, so get one from the `.train` dataset
    result = next(iter(self.train))
    # And cache it for next time
    self._example = result
  return result
@property
def example2(self):
  """Get and cache an example batch of `inputs, labels` for plotting."""
  result = getattr(self, '_example2', None)
  if result is None:
    # No example batch was found, so get one from the `.train` dataset
    result = next(iter(self.val))
    # And cache it for next time
    self._example = result
  return result
@property
def example3(self):
  """Get and cache an example batch of `inputs, labels` for plotting."""
  result = getattr(self, '_example3', None)
  if result is None:
    # No example batch was found, so get one from the `.train` dataset
    result = next(iter(self.test))
    # And cache it for next time
    self._example = result
  return result


WindowGenerator.train = train
WindowGenerator.val = val
WindowGenerator.test = test
WindowGenerator.example = example
WindowGenerator.example2 = example2
WindowGenerator.example3 = example3

# %%
def sample_batch_index(total, batch_size):
    '''Sample index of the mini-batch.

    Args:
        - total: total number of samples
        - batch_size: batch size

    Returns:
        - batch_idx: batch index
    '''
    total_idx = np.random.permutation(total)
    batch_idx = total_idx[:batch_size]
    return batch_idx

# %%
def binary_sampler(p, shape):
  '''Sample binary random variables.
  
  Args:
    - p: probability of 1
    - shape: matrix shape
    
  Returns:
    - binary_random_matrix: generated binary random matrix.
  '''
  unif_random_matrix = np.random.uniform(0., 1., size = shape)
  binary_random_matrix = 1*(unif_random_matrix < p)
  return binary_random_matrix

# %%
def uniform_sampler(low, high, shape):
  '''Sample uniform random variables.
  
  Args:
    - low: low limit
    - high: high limit
    - rows: the number of rows
    - cols: the number of columns
    
  Returns:
    - uniform_random_matrix: generated uniform random matrix.
  '''
  return np.random.uniform(low, high, size = shape)

# %%
class MissData(object):
    def __init__(self, load_dir=None):
        if load_dir:
            self.missarr = np.load(os.path.join(load_dir, 'miss.npy'))
            self.idxarr = np.load(os.path.join(load_dir, 'idx.npy'))
            
    def make_missdata(self, data_x, missrate=0.2):
        data = data_x.copy()
        rows, cols = data_x.shape
        total_no = rows*cols
        total_miss_no = np.round(total_no*missrate).astype(int)
        total_idx = self.idxarr.shape[0]
        idxarr = self.idxarr
        missarr = self.missarr
        #print(total_miss_no)
        miss_no = 0
        cum_no = self.idxarr[:,3:4]
        cum_no = cum_no.reshape((total_idx))
        cum_sum = np.max(cum_no)
        #print(cum_no)
        #print(total_idx)
        while True:
            loc_count = np.around(np.random.random()*cum_sum)
            #print('loc_count =', loc_count)
            idx = len(cum_no[cum_no <= loc_count])-1
            #print(cum_no[cum_no <= loc_count])
            #print('idx =', idx)
            startnan = idxarr[idx][0]
            nanlen = idxarr[idx][2]
            loc = np.around(np.random.random()*(rows-nanlen)).astype(int)
            #print('loc =', loc)
            #print(loc_count, idx)
            #print(idxarr[idx])
            #data_copy = data[loc:loc+nanlen].copy()
            data_copy = data[loc:loc+nanlen]
            #print('startnan=', startnan)
            #isnan = missarr[startnan:startnan+nanlen].copy()
            isnan = missarr[startnan:startnan+nanlen]
            #print('isnan =',isnan)
            miss_no += idxarr[idx][1]
            if (miss_no > total_miss_no):
                break
            data_copy[isnan==1] = np.nan
            data[loc:loc+nanlen] = data_copy
        #print('miss_data =', data)
        return data
    
    def save(data, max_tseq, save_dir='save'):
        no, dim = data.shape
        #print((no, dim))
        isnan = np.isnan(data).astype(int)
        isany = np.any(isnan, axis=1).astype(int)
        shifted = np.roll(isany, 1)
        shifted[0] = 1
        #print(isnan)
        #print(isany.astype(int))
        #print(shifted)
        startnan = ((isany == 1) & (shifted ==0)).astype(int)
        #print(startnan)
        group = startnan.cumsum()
        group = group*isany
#         print(group)
        n = np.max(group)
#         print(n)
        missarr = None
        cum_no = 0
        rowidx = 0
        for i in range(1, n+1):
            g = (group == i).astype(int)
            i = np.argmax(g)
            rows = g.sum()
            #print(len)
            #print(i)
            #print(type(missarr))
            if rows <= max_tseq:
                nanseq = isnan[i:i+rows, :]
                no = np.sum(nanseq)
                #print(no)
                if missarr is None:
                    missarr = nanseq
                    idxarr = np.array([[rowidx, no, rows, cum_no]])
                else:
                    missarr = np.concatenate((missarr, nanseq))
                    idxarr = np.concatenate((idxarr, [[rowidx, no, rows, cum_no]]), axis=0)
                cum_no += no
                rowidx += rows

        print(idxarr)
        miss_npy_file = os.path.join(save_dir, 'miss.npy')
        idx_npy_file = os.path.join(save_dir, 'idx.npy')
        if not os.path.exists(save_dir):
            os.makedirs(save_dir)
        np.save(miss_npy_file, missarr)
        np.save(idx_npy_file, idxarr)
        print('miss_data file saved')

# %%
def interpolate(np_data, max_gap=3):
    #n = np_data.shape[1]
    data = pd.DataFrame(np_data)
    #data[0][0] = np.nan
    #data[0][1] = np.nan
    #data[0][2] = np.nan
    #data[data.columns[0]][0] = np.nan
    #data[data.columns[0]][1] = np.nan
    #data[data.columns[0]][2] = np.nan
    
    # create mask
    mask = data.copy()
    grp = ((mask.notnull() != mask.shift().notnull()).cumsum())
    grp['ones'] = 1
    for i in data.columns:
        mask[i] = (grp.groupby(i)['ones'].transform('count') < max_gap) | data[i].notnull()
    data = data.interpolate(method='polynomial', order=5, limit=max_gap, axis=0).bfill()[mask]
    return data.to_numpy()
    #return data
    
#filled_data = interpolate(norm_data, max_gap=3)
#np.arange(0, 5, dtype=int)
#['%d'%val for val in range(0,5)]

# %%
class GainDataGenerator(keras.utils.Sequence):
    'Generates data for GAIN'
    def __init__(self,
                 data_list,
                 batch_size=32,
                 input_width=24*3,
                 label_width=24*3,
                 shift=0,
                 fill_no=4,
                 miss_rate=0.2,
                 hint_rate=0.9,
                 normalize=True,
                 miss_pattern=None,
                 miss_data_load_dir='save',
                 alpha=100.):
        'Initialization'
        window_size = input_width
        
        # interpollation
        filled_data = []
        for data in data_list:
            data = interpolate(data, max_gap=fill_no)
            filled_data.append(data)
            
        data_list = filled_data
        
        # whole data
        self.data = np.concatenate(data_list)

        # TO-DO
        
        # pre calculation for  sequence data
        last_cum = 0
        cums = []
        for data in data_list:
            isnan = np.isnan(data)
            isany = np.any(isnan, axis=1)
            #shift same as pd.shift(isany, fill_value=True)
            shifted = np.roll(isany, 1)
            shifted[0] = True # set to nan
            
            start_seq = ((isany == False) & (shifted == True)).astype(int)
            cum = start_seq.cumsum()
            cum += last_cum
            last_cum = np.max(cum)
            cum[isany] = 0
            cums.append(cum)

        # Define mask matrix
        if miss_pattern is None:
            print("pattern none")
            self.data_m = binary_sampler(1-miss_rate, self.data.shape)
        else:
            #MissData.save(self.data, max_tseq = 12)
            print("load save")
            self.miss = MissData(load_dir=miss_data_load_dir)
            self.miss_rate = miss_rate
            miss_data = self.miss.make_missdata(self.data, self.miss_rate)
            self.data_m = 1. - np.isnan(miss_data).astype(float)
            
            self.data_m_rand = binary_sampler(1-(miss_rate/10.), self.data.shape)
            self.data_m[self.data_m_rand==0.] = 0.
        self.miss_pattern = miss_pattern
        
        # sequence data
        self.ids = np.concatenate(cums)
        data_idx = np.empty((0), dtype=int)
        for i in range(1, last_cum+1):
            seq_len = (self.ids == i).sum()
            start_id = np.argmax(self.ids == i)
            # possible data number in seqeunce
            time_len = seq_len - window_size + 1
            start_ids = np.arange(start_id, start_id+time_len)
            data_idx = np.append(data_idx, start_ids)
            
        # start index set for sequence data
        self.data_idx = data_idx
        self.input_width = input_width
        self.no = len(data_idx)
        
        #print('self.no = ', self.no)
        
        self.batch_size = batch_size
        
        # random shuffling  index
        self.batch_idx = sample_batch_index(self.no, self.no)
        self.batch_id = 0
        self.shape = (batch_size,self.input_width)+self.data.shape[1:]
        #self.hint_rate = hint_rate
            
    def __len__(self):
        'Denotes the number of batches per epoch'
        #return int(128/self.batch_size)
        #return 2
        return 1

    def __getitem__(self, index):
        'Generate one batch of data'
        #print('index =', index)
        # Sample batch
        x = np.empty((0, self.input_width, self.data.shape[1]))
        #m = np.empty((0, self.input_width, self.data.shape[1]))
        #h = np.empty((0, self.input_width, self.data.shape[1]))
        y = np.empty((0, self.input_width, self.data.shape[1]))
        #print(x.shape)
        #print(self.data.shape)
        #print(self.input_width)
        #self.batch_idx = sample_batch_index(self.no, self.batch_size)
        for cnt in range(0, self.batch_size):
            i = self.batch_idx[self.batch_id]
            self.batch_id += 1
            #self.batch_id %= self.batch_size
            self.batch_id %= self.no
            if self.miss_pattern and (self.batch_id == 0):
                self.batch_idx = sample_batch_index(self.no, self.no)
                miss_data = self.miss.make_missdata(self.data, self.miss_rate)
                self.data_m = 1. - np.isnan(miss_data).astype(float)
                self.data_m_rand = binary_sampler(1-self.miss_rate/10., self.data.shape)
                self.data_m[self.data_m_rand==0.] = 0.
            idx1 = self.data_idx[i]
            idx2 = self.data_idx[i]+self.input_width
            #print(idx1, idx2)
        
            Y_mb = self.data[idx1:idx2].copy()
            X_mb = Y_mb.copy()
            M_mb = self.data_m[idx1:idx2]
            Z_mb = uniform_sampler(0, 0.01, shape=X_mb.shape)
            X_mb = M_mb*X_mb + (1-M_mb)*Z_mb
            #H_mb_temp = binary_sampler(self.hint_rate, shape=X_mb.shape)
            #H_mb = M_mb * H_mb_temp
            X_mb[M_mb == 0] = np.nan
            Y_mb[M_mb == 1] = np.nan
            x = np.append(x, [X_mb], axis=0)
            #m = np.append(m, [M_mb], axis=0)
            #h = np.append(h, [H_mb], axis=0)
            y = np.append(y, [Y_mb], axis=0)
            
        #return [x, m, h], y
        return x, y
    
    def on_epoch_end(self):
        'Updates indexes after each epoch'
        return

# dgen = GainDataGenerator(df)

# %%
class GAIN(keras.Model):
    def __init__(self, shape, alpha=100., load=False, hint_rate=0.9, gen_sigmoid=True, **kwargs):
        super(GAIN, self).__init__(**kwargs)
        self.shape = shape
        self.dim = np.prod(shape).astype(int)
        self.h_dim = self.dim
        self.gen_sigmoid = gen_sigmoid
        self.build_generator()
        self.build_discriminator()
        self.hint_rate = hint_rate
        self.alpha = alpha
        self.generator_optimizer = Adam()
        self.discriminator_optimizer = Adam()

    ## GAIN models
    def build_generator(self):
        last_activation = 'sigmoid' if self.gen_sigmoid else None
        xavier_initializer = tf.keras.initializers.GlorotNormal()

        shape = self.shape
        #x = Input(shape=(self.dim,), name='generator_input_x')
        #m = Input(shape=(self.dim,), name='generator_input_m')
        x = Input(shape=shape, name='generator_input_x')
        m = Input(shape=shape, name='generator_input_m')
        
        x_f = Flatten()(x)
        m_f = Flatten()(m)

        a = Concatenate()([x_f, m_f])

        a = Dense(self.h_dim, activation='relu', kernel_initializer=xavier_initializer)(a)
        #a = keras.layers.BatchNormalization()(a)
        a = Dense(self.h_dim, activation='relu', kernel_initializer=xavier_initializer)(a)
        #a = keras.layers.BatchNormalization()(a)
        a = Dense(self.dim, activation=last_activation, kernel_initializer=xavier_initializer)(a)
        G_prob = keras.layers.Reshape(shape)(a)
        self.generator = keras.models.Model([x, m], G_prob, name='generator')

    def build_discriminator(self):
        xavier_initializer = tf.keras.initializers.GlorotNormal()
        shape = self.shape

        #x = Input(shape=(self.dim,), name='discriminator_input_x')
        #h = Input(shape=(self.dim,), name='discriminator_input_h')
        x = Input(shape=shape, name='discriminator_input_x')
        h = Input(shape=shape, name='discriminator_input_h')
        
        x_f = Flatten()(x)
        h_f = Flatten()(h)

        a = Concatenate()([x_f, h_f])

        a = Dense(self.h_dim, activation='relu', kernel_initializer=xavier_initializer)(a)
        a = Dense(self.h_dim, activation='relu', kernel_initializer=xavier_initializer)(a)
        a = Dense(self.dim, activation='sigmoid', kernel_initializer=xavier_initializer)(a)
        D_prob = keras.layers.Reshape(shape)(a)
        self.discriminator = keras.models.Model([x, h], D_prob, name='discriminator')
        
    def call(self, inputs):
        if isinstance(inputs, tuple):
            inputs = inputs[0]
        shape = inputs.shape
        dims = np.prod(shape[1:])
        input_width = shape[1]
        #print('inputs.shape=',inputs.shape)
        x = inputs
        #x = x.reshape((n, -1))
        #print('dims=',dims)
        #x = keras.layers.Reshape((dims,))(x)
        #x = keras.layers.Reshape(tf.TensorShape((self.dim,)))(x)
        #print('x =', x)
        #print('x.shape = ', x.shape)
        #x = keras.layers.Reshape(tf.TensorShape([57]))(x)
        
        isnan = tf.math.is_nan(x)
        #m = 1.- keras.backend.cast(isnan, dtype=tf.float32)
        m = tf.where(isnan, 0., 1.)
        z = keras.backend.random_uniform(shape=tf.shape(x), minval=0.0, maxval=0.01)
        x = tf.where(isnan, z, x)
        #z = uniform_sampler(0, 0.01, shape=x.shape)
        #z = tf.keras.backend.random_uniform(shape=x.shape, minval=0.0, maxval=0.01)
        imputed_data = self.generator([x, m], training=False)
        #imputed_data = m*x + (1-m)*imputed_data
        #imputed_data = tf.where(isnan, imputed_data, np.nan)
        imputed_data = tf.where(isnan, imputed_data, x)
        #imputed_data = keras.layers.Reshape(shape[1:])(imputed_data)
        #print('imputed_data.shape = ', imputed_data.shape)
        
        return imputed_data
    
    def D_loss(M, D_prob):
        ## GAIN loss
        return -tf.reduce_mean(M * tf.keras.backend.log(D_prob + 1e-8) \
                         + (1-M) * tf.keras.backend.log(1. - D_prob + 1e-8))
    
    def G_loss(self, M, D_prob, X, G_sample):
        G_loss_temp = -tf.reduce_mean((1-M) * tf.keras.backend.log(D_prob + 1e-8))
        MSE_loss = tf.reduce_mean((M * X - M * G_sample)**2) / (tf.reduce_mean(M) + 1e-8)
        #G_loss_temp = GAIN.G_loss_bincross(M, D_prob)
        #MSE_loss = GAIN.MSE_loss(M, X, G_sample)
        G_loss = G_loss_temp + self.alpha * MSE_loss
        return G_loss
        
    def RMSE_loss(y_true, y_pred):
        isnan = tf.math.is_nan(y_true)
        M = tf.where(isnan, 1., 0.)
        return tf.sqrt(tf.reduce_sum(tf.where(isnan, 0., y_pred-y_true)**2)/tf.reduce_sum(1-M))
    
    def train_step(self, data):
        #[x, m, h], y = data
        x, y = data
        #X = keras.layers.Reshape((self.dim,), input_shape=self.shape)(x)
        #Y = keras.layers.Reshape((self.dim,), input_shape=self.shape)(y)
        #X = keras.layers.Flatten()(x)
        #Y = keras.layers.Flatten()(y)
        X = x
        Y = y
        #X = tf.reshape(x, shape=(x.shape[0], -1))
        #Y = tf.reshape(y, shape=(x.shape[0], -1))
        isnan = tf.math.is_nan(X)
        #M = 1 - keras.backend.cast(isnan, dtype=tf.float32)
        M = tf.where(isnan, 0., 1.)
        Z = keras.backend.random_uniform(shape=tf.shape(X), minval=0.0, maxval=0.01)
        #H_temp = binary_sampler(self.hint_rate, shape=X.shape)
        H_rand = keras.backend.random_uniform(shape=tf.shape(X), minval=0.0, maxval=1.)
        #H_temp = 1*keras.backend.cast((H_rand < self.hint_rate), dtype=tf.float32)
        H_temp = tf.where(H_rand < self.hint_rate, 1., 0.)
        
        H = M * H_temp
        #X = M * X + (1-M) * Z
        X = tf.where(isnan, Z, X)
        with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
            G_sample = self.generator([X, M], training=True)

            # Combine with observed data
            #Hat_X = tf.where(isnan, G_sample, X)
            Hat_X = X * M + G_sample * (1-M)
            D_prob = self.discriminator([Hat_X, H], training=True)
            gen_loss = self.G_loss(M, D_prob, X, G_sample)
            disc_loss = tf.keras.backend.mean(tf.keras.losses.binary_crossentropy(M, D_prob))
            #disc_loss = GAIN.D_loss(M, D_prob)
            #disc_loss = GAIN.D_loss(M, D_prob)

        gradients_of_generator = gen_tape.gradient(gen_loss, self.generator.trainable_variables)
        gradients_of_discriminator = disc_tape.gradient(disc_loss, self.discriminator.trainable_variables)

        self.generator_optimizer.apply_gradients(zip(gradients_of_generator, self.generator.trainable_variables))
        self.discriminator_optimizer.apply_gradients(zip(gradients_of_discriminator, self.discriminator.trainable_variables))
        
        rmse = tf.sqrt(tf.reduce_sum(tf.where(isnan, G_sample - Y, 0.)**2)/tf.reduce_sum(1-M))
        return {
                 'gen_loss':     gen_loss,
                 'disc_loss':    disc_loss,
                 'rmse':         rmse,
               }
    
    def save(self, save_dir='save'):
        if not os.path.exists(save_dir):
          os.makedirs(save_dir)
        disc_savefile = os.path.join(save_dir, 'discriminator.h5')
        gen_savefile = os.path.join(save_dir, 'generator.h5')
        self.discriminator.save_weights(disc_savefile)
        self.generator.save_weights(gen_savefile)

    def load(self, save_dir='save'):
        disc_savefile = os.path.join(save_dir, 'discriminator.h5')
        gen_savefile = os.path.join(save_dir, 'generator.h5')
        try:
          self.discriminator.load_weights(disc_savefile)
          self.generator.load_weights(gen_savefile)
          print('model weights loaded')
        except:
          print('model loadinng error')

# %%
def make_dataset_gain(self, data):
  dg = GainDataGenerator(
      df,
      input_width = self.input_width,
      label_width = self.label_width,
      batch_size = 128,
      normalize = False,
      miss_pattern = True,
      miss_rate = 0.15,
      fill_no = 3,
  )
  self.dg = dg
  ds = tf.data.Dataset.from_generator(
      lambda: dg,
      output_types=(tf.float32, tf.float32),
      output_shapes=(
        dg.shape,
        dg.shape
        #[batch_size, train_generator.dim],
        #[batch_size, train_generator.dim],
      )
  )
  return ds

WindowGenerator.make_dataset = make_dataset_gain

# %% [markdown]
# # 측정망별 반복 구간

# %%
norm_df = pd.concat(df,axis=0)
norm_data = norm_df.to_numpy()
MissData.save(norm_data, max_tseq = 24)
# 1: 자동, 2: 수질,
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-26-cfa51a005c02> in <module>
#       1 norm_df = pd.concat(df,axis=0)
#       2 norm_data = norm_df.to_numpy()
# ----> 3 MissData.save(norm_data, max_tseq = 24)
#       4 # 1: 자동, 2: 수질,
#
# <ipython-input-21-e01fd5ce4061> in save(data, max_tseq, save_dir)
#      86                 rowidx += rows
#      87
# ---> 88         print(idxarr)
#      89         miss_npy_file = os.path.join(save_dir, 'miss.npy')
#      90         idx_npy_file = os.path.join(save_dir, 'idx.npy')
#
# UnboundLocalError: local variable 'idxarr' referenced before assignment

# %%
dgen = GainDataGenerator(df)

# %%
train_df = df_all
val_df = df_all
test_df = df_all
df_all

# %%
wide_window = WindowGenerator(
    input_width=24*5, label_width=24*5, shift=0,
    #label_columns=['T (degC)']
)

wide_window

# %% [markdown]
# ## Graph

# %%
wide_window.example[0].shape

# %%
wide_window.plot(plot_col=target_col)
print('make_dataset_gain: dg.no = ', wide_window.dg.no)

# %%
plt.figure(figsize=(9,10))
isnan = np.isnan(norm_data).astype(int)
data = isnan
n = data.shape[0]
seq_len = n//8
for i in range(8):
    plt.subplot(181+i)
    plt.imshow(data[i*seq_len:(i+1)*seq_len, 0:], aspect='auto')
    plt.yticks([])
plt.show()

# %% [markdown]
# ## 컴파일 및 학습_GAIN

# %%
val_performance = {}
performance = {}

# %%
gain = GAIN(shape=wide_window.dg.shape[1:], gen_sigmoid=False)
gain.compile(loss=GAIN.RMSE_loss)

# %%
MAX_EPOCHS = 2000

def compile_and_fit(model, window, patience=10):
  early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss',
                                                    patience=patience,
                                                    mode='min')

  #model.compile(loss=tf.losses.MeanSquaredError(),
                #optimizer=tf.optimizers.Adam(),
                #metrics=[tf.metrics.MeanAbsoluteError()])
  model.compile(loss=GAIN.RMSE_loss)

  history = model.fit(window.train, epochs=MAX_EPOCHS,
                      validation_data=window.val,
                      callbacks=[early_stopping])
  return history

# %% [markdown]
# **모델 학습**

# %%
history = compile_and_fit(gain, wide_window, patience=MAX_EPOCHS//5)


val_performance['Gain'] = gain.evaluate(wide_window.val)
performance['Gain'] = gain.evaluate(wide_window.test, verbose=0)

# gain.save(save_dir='save')
# Out:
# Epoch 1/2000
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-158-8039682b8e8f> in <module>
# ----> 1 history = compile_and_fit(gain, wide_window, patience=MAX_EPOCHS//5)
#       2
#       3
#       4 val_performance['Gain'] = gain.evaluate(wide_window.val)
#       5 performance['Gain'] = gain.evaluate(wide_window.test, verbose=0)
#
# <ipython-input-157-9a2fac184c46> in compile_and_fit(model, window, patience)
#      13   history = model.fit(window.train, epochs=MAX_EPOCHS,
#      14                       validation_data=window.val,
# ---> 15                       callbacks=[early_stopping])
#      16   return history
#
# ~/work/tf-2/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1098                 _r=1):
#    1099               callbacks.on_train_batch_begin(step)
# -> 1100               tmp_logs = self.train_function(iterator)
#    1101               if data_handler.should_sync:
#    1102                 context.async_wait()
#
# ~/work/tf-2/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     826     tracing_count = self.experimental_get_tracing_count()
#     827     with trace.Trace(self._name) as tm:
# --> 828       result = self._call(*args, **kwds)
#     829       compiler = "xla" if self._experimental_compile else "nonXla"
#     830       new_tracing_count = self.experimental_get_tracing_count()
#
# ~/work/tf-2/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     869       # This is the first call of __call__, so we have to initialize.
#     870       initializers = []
# --> 871       self._initialize(args, kwds, add_initializers_to=initializers)
#     872     finally:
#     873       # At this point we know that the initialization is complete (or less
#
# ~/work/tf-2/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in _initialize(self, args, kwds, add_initializers_to)
#     724     self._concrete_stateful_fn = (
#     725         self._stateful_fn._get_concrete_function_internal_garbage_collected(  # pylint: disable=protected-access
# --> 726             *args, **kwds))
#     727
#     728     def invalid_creator_scope(*unused_args, **unused_kwds):
#
# ~/work/tf-2/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _get_concrete_function_internal_garbage_collected(self, *args, **kwargs)
#    2967       args, kwargs = None, None
#    2968     with self._lock:
# -> 2969       graph_function, _ = self._maybe_define_function(args, kwargs)
#    2970     return graph_function
#    2971
#
# ~/work/tf-2/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _maybe_define_function(self, args, kwargs)
#    3359
#    3360           self._function_cache.missed.add(call_context_key)
# -> 3361           graph_function = self._create_graph_function(args, kwargs)
#    3362           self._function_cache.primary[cache_key] = graph_function
#    3363
#
# ~/work/tf-2/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3204             arg_names=arg_names,
#    3205             override_flat_arg_shapes=override_flat_arg_shapes,
# -> 3206             capture_by_value=self._capture_by_value),
#    3207         self._function_attributes,
#    3208         function_spec=self.function_spec,
#
# ~/work/tf-2/lib/python3.7/site-packages/tensorflow/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes)
#     988         _, original_func = tf_decorator.unwrap(python_func)
#     989
# --> 990       func_outputs = python_func(*func_args, **func_kwargs)
#     991
#     992       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# ~/work/tf-2/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in wrapped_fn(*args, **kwds)
#     632             xla_context.Exit()
#     633         else:
# --> 634           out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     635         return out
#     636
#
# ~/work/tf-2/lib/python3.7/site-packages/tensorflow/python/framework/func_graph.py in wrapper(*args, **kwargs)
#     975           except Exception as e:  # pylint:disable=broad-except
#     976             if hasattr(e, "ag_error_metadata"):
# --> 977               raise e.ag_error_metadata.to_exception(e)
#     978             else:
#     979               raise
#
# ValueError: in user code:
#
#     /home/cjinw/work/tf-2/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py:805 train_function  *
#         return step_function(self, iterator)
#     /home/cjinw/work/tf-2/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py:795 step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     /home/cjinw/work/tf-2/lib/python3.7/site-packages/tensorflow/python/distribute/distribute_lib.py:1259 run
#         return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#     /home/cjinw/work/tf-2/lib/python3.7/site-packages/tensorflow/python/distribute/distribute_lib.py:2730 call_for_each_replica
#         return self._call_for_each_replica(fn, args, kwargs)
#     /home/cjinw/work/tf-2/lib/python3.7/site-packages/tensorflow/python/distribute/distribute_lib.py:3417 _call_for_each_replica
#         return fn(*args, **kwargs)
#     /home/cjinw/work/tf-2/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py:788 run_step  **
#         outputs = model.train_step(data)
#     <ipython-input-152-dd74a459a41d>:150 train_step
#         rmse = tf.sqrt(tf.reduce_sum(tf.where(isnan, G_sample - Y, 0.)**2)/tf.reduce_sum(1-M))
#     /home/cjinw/work/tf-2/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:1180 binary_op_wrapper
#         raise e
#     /home/cjinw/work/tf-2/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:1164 binary_op_wrapper
#         return func(x, y, name=name)
#     /home/cjinw/work/tf-2/lib/python3.7/site-packages/tensorflow/python/util/dispatch.py:201 wrapper
#         return target(*args, **kwargs)
#     /home/cjinw/work/tf-2/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:561 subtract
#         return gen_math_ops.sub(x, y, name)
#     /home/cjinw/work/tf-2/lib/python3.7/site-packages/tensorflow/python/ops/gen_math_ops.py:10317 sub
#         "Sub", x=x, y=y, name=name)
#     /home/cjinw/work/tf-2/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:750 _apply_op_helper
#         attrs=attr_protos, op_def=op_def)
#     /home/cjinw/work/tf-2/lib/python3.7/site-packages/tensorflow/python/framework/func_graph.py:592 _create_op_internal
#         compute_device)
#     /home/cjinw/work/tf-2/lib/python3.7/site-packages/tensorflow/python/framework/ops.py:3536 _create_op_internal
#         op_def=op_def)
#     /home/cjinw/work/tf-2/lib/python3.7/site-packages/tensorflow/python/framework/ops.py:2016 __init__
#         control_input_ops, op_def)
#     /home/cjinw/work/tf-2/lib/python3.7/site-packages/tensorflow/python/framework/ops.py:1856 _create_c_op
#         raise ValueError(str(e))
#
#     ValueError: Dimensions must be equal, but are 12 and 5 for '{{node sub_6}} = Sub[T=DT_FLOAT](generator/reshape_7/Reshape, IteratorGetNext:1)' with input shapes: [128,120,12], [128,120,5].

# %% [markdown]
# **학습 loss history 출력**

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax2 = ax.twinx()
ax.plot(history.history['gen_loss'], label='gen_loss')
ax.plot(history.history['disc_loss'], label='disc_loss')
ax2.plot(history.history['rmse'], label='rmse', color='green')
ax2.plot(history.history['val_loss'], label='val_loss', color='red')
#plt.legend(history.history.keys(), loc='upper right')
#ax.legend(loc='upper center')
ax.legend(loc='upper center')
ax2.legend(loc='upper right')
ax.set_xlabel("epochs")
ax.set_ylabel("loss")
ax2.set_ylabel("rmse")
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# **성능 측정**

# %%
gain.evaluate(wide_window.test.repeat(), steps=100)
# Out:
# load save
# 100/100 [==============================] - 3s 31ms/step - loss: 0.1707
# 0.170664981007576

# %% [markdown]
# **model save**

# %%
gain.save(save_dir='save')

# %% [markdown]
# **샘플 prediction 출력**

# %%
wide_window.plot(gain, plot_col='총유기탄소')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
norm_df = pd.concat(df,axis=0)

# %%
data = norm_df.to_numpy()

total_n = wide_window.dg.data.shape[0]
print(total_n)
unit_shape = wide_window.dg.shape[1:]
print(unit_shape)
#dim = np.prod(wide_window.dg.shape[1:]).astype(int)
dim = wide_window.dg.shape[1]
print(dim)
n = (total_n//dim)*dim

x = data[0:n].copy()
y_true = data[0:n].copy()

#x = interpolate(x, max_gap=3)

print('x.shape =', x.shape)
x_reshape = x.reshape((-1,)+unit_shape)
print('x_reshape.shape =', x_reshape.shape)
isnan = np.isnan(x_reshape)
print(isnan.sum())
print('y_true.shape=', y_true.shape)
isnan = np.isnan(y_true)
print(isnan.sum())

x_remain = data[-wide_window.dg.shape[1]:].copy()
x_remain_reshape = x_remain.reshape((-1,)+unit_shape)
x_remain_reshape.shape
# Out:
# 140256
# (120, 12)
# 120
# x.shape = (140160, 12)
# x_reshape.shape = (1168, 120, 12)
# 169322
# y_true.shape= (140160, 12)
# 169322
# (1, 120, 12)

# %%
gain.evaluate(x_reshape, y_true.reshape((-1,)+unit_shape))
# Out:
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0000e+00
# 0.0

# %%
y_pred = gain.predict(x_reshape)
y_remain_pred = gain.predict(x_remain_reshape)

# %%
y_pred = y_pred.reshape(y_true.shape)
y_remain_pred = y_remain_pred.reshape(x_remain.shape)
print(y_pred.shape, y_remain_pred.shape)
y_pred = np.append(y_pred, y_remain_pred[-(total_n-n):], axis=0)
print(y_pred.shape)
# Out:
# (140160, 12) (120, 12)
# (140256, 12)

# %%
y_pred[~np.isnan(data)] = np.nan

# %%
n = 8
plt.figure(figsize=(9,20))
for i in range(n):
    #plt.subplot('%d1%d'%(n,i))
    plt.subplot(811+i)
    plt.plot(x[:, i])
    plt.plot(y_pred[:, i])
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# **Imputed Data**

# %%
total_n = wide_window.dg.data.shape[0]
print(total_n)
unit_shape = wide_window.dg.shape[1:]
print('unit_shape=', unit_shape)
time_seq = unit_shape[0]
print(time_seq)
n = (total_n//time_seq)*time_seq
print('n=', n)

gans = []
oris = []
for i in range(len(df)):
    x = df[i].to_numpy()
    total_n = x.shape[0]
    n = (total_n//time_seq)*time_seq
    x = x[0:n]
    x_block = x.reshape((-1,)+unit_shape)
    y = gain.predict(x_block)
    y_gan = y.reshape(x.shape)
    
    # cut off sin, cos data
    if (i > 0):
        x = x[:, :-4]
        y_gan = y_gan[:, :-4]
    gans.append(y_gan)
    oris.append(x)
print(x.shape)
print(y_gan.shape)
# Out:
# 140256
# unit_shape= (120, 12)
# 120
# n= 140160
# (35040, 8)
# (35040, 8)

# %% [markdown]
# # 예측

# %%
df[0].head
# Out:
# <bound method NDFrame.head of              수온    수소이온농도     전기전도도      용존산소     총유기탄소       총질소        총인  \
# 0     -0.983586 -1.179277 -0.150285 -1.591779 -1.311312       NaN       NaN
# 1     -0.995480 -1.179277 -0.150285 -1.625545 -1.311312       NaN       NaN
# 2     -0.995480 -1.179277 -0.150285 -1.659311 -1.311312       NaN       NaN
# 3     -0.995480 -1.179277 -0.150285 -1.659311 -1.311312       NaN       NaN
# 4     -0.995480 -1.179277 -0.150285 -1.659311 -1.311312       NaN       NaN
# ...         ...       ...       ...       ...       ...       ...       ...
# 35059 -0.840847 -0.919091 -0.531435 -0.950227 -0.538581 -0.892581 -0.649845
# 35060 -0.840847 -0.919091 -0.548760 -0.916461 -0.538581 -0.854676 -0.550052
# 35061 -0.852742 -0.919091 -0.548760 -0.916461 -0.538581 -0.832214 -0.649845
# 35062 -0.864637 -0.919091 -0.548760 -0.882696 -0.538581 -0.872927 -0.550052
# 35063 -0.852742 -0.919091 -0.548760 -0.916461 -0.538581 -0.882754 -0.550052
#
#          클로로필-a       Day sin   Day cos  Year sin  Year cos
# 0     -0.578755 -1.999588e-12  1.414209 -0.003771  1.414160
# 1     -0.587829  3.660241e-01  1.366021 -0.002757  1.414162
# 2     -0.578755  7.071043e-01  1.224741 -0.001743  1.414164
# 3     -0.578755  9.999964e-01  0.999996 -0.000730  1.414165
# 4     -0.587829  1.224741e+00  0.707104  0.000284  1.414165
# ...         ...           ...       ...       ...       ...
# 35059 -0.560607 -1.366021e+00  0.366024 -0.008109  1.414142
# 35060 -0.551533 -1.224741e+00  0.707104 -0.007096  1.414147
# 35061 -0.551533 -9.999964e-01  0.999996 -0.006082  1.414152
# 35062 -0.551533 -7.071043e-01  1.224741 -0.005068  1.414156
# 35063 -0.551533 -3.660241e-01  1.366021 -0.004055  1.414159
#
# [35064 rows x 12 columns]>

# %%
ori = np.concatenate(oris, axis=1)
gan = np.concatenate(gans, axis=1)
# print(oris[0].shape, gans[0].shape)
# print(oris[1].shape, gans[1].shape)
# print(ori.shape, gan.shape)

total_no = ori.shape[0]
train_no = int(total_no*0.8)
val_no = int(total_no * 0.9)

train_slice = slice(0, train_no)
val_slice = slice(train_no, val_no)
test_slice = slice(val_no, None)

train_df = pd.DataFrame(gan[train_slice])
val_df = pd.DataFrame(gan[val_slice])
test_df = pd.DataFrame(gan[test_slice])

train_ori_df = pd.DataFrame(ori[train_slice])
val_ori_df = pd.DataFrame(ori[val_slice])
test_ori_df = pd.DataFrame(ori[test_slice])

num_features = train_df.shape[1]
#out_num_features = oris[0].shape[1]-4
# out_features = [target_col_idx]
# out_num_features = len(out_features)
# out_num_features

# %%
train_df
# Out:
#              0         1         2         3         4         5         6   \
# 0     -0.983586 -1.179277 -0.150285 -1.591779 -1.311312 -0.719843 -0.452586
# 1     -0.995480 -1.179277 -0.150285 -1.625545 -1.311312 -0.455890 -0.502437
# 2     -0.995480 -1.179277 -0.150285 -1.659311 -1.311312 -0.615235 -0.436407
# 3     -0.995480 -1.179277 -0.150285 -1.659311 -1.311312 -0.521445 -0.543660
# 4     -0.995480 -1.179277 -0.150285 -1.659311 -1.311312 -0.481226 -0.519578
# ...         ...       ...       ...       ...       ...       ...       ...
# 28027 -1.209588 -0.658906 -0.670034  0.332877 -0.635172 -0.477029 -0.849431
# 28028 -1.221483 -0.658906 -0.670034  0.366643 -0.635172 -0.488261 -0.699741
# 28029 -1.221483 -0.658906 -0.670034  0.366643 -0.635172 -0.543012 -0.599948
# 28030 -1.209588 -0.658906 -0.670034  0.366643 -0.635172 -0.594956 -0.550052
# 28031 -1.209588 -0.658906 -0.670034  0.366643 -0.635172 -0.658131 -0.550052
#
#              7             8         9   ...        26        27        28  \
# 0     -0.578755 -1.999588e-12  1.414209  ... -0.749638 -0.587343 -1.423695
# 1     -0.587829  3.660241e-01  1.366021  ... -0.749638 -0.735486 -1.423695
# 2     -0.578755  7.071043e-01  1.224741  ... -0.699741 -0.739290 -1.423695
# 3     -0.578755  9.999964e-01  0.999996  ... -0.699741 -0.166052 -1.411800
# 4     -0.587829  1.224741e+00  0.707104  ... -0.749638 -0.069390 -1.423695
# ...         ...           ...       ...  ...       ...       ...       ...
# 28027 -0.560607 -1.366021e+00  0.366024  ...  0.009638  1.288119 -0.971691
# 28028 -0.551533 -1.224741e+00  0.707104  ... -0.001191  0.920313 -0.959796
# 28029 -0.542459 -9.999964e-01  0.999996  ... -0.100984  0.944942 -0.959796
# 28030 -0.533384 -7.071043e-01  1.224741  ... -0.100984  0.802382 -0.959796
# 28031 -0.533384 -3.660241e-01  1.366021  ... -0.150880  1.116917 -0.959796
#
#              29        30        31        32        33        34        35
# 0     -0.268628  0.109589  1.109493 -1.214721  1.223082 -0.211942 -0.714866
# 1     -0.268628  0.109589  1.109493 -1.311312  1.095328 -0.411714 -0.705792
# 2     -0.138535  0.109589  1.143259 -1.214721  1.074270 -0.358586 -0.723940
# 3     -0.138535  0.109589  1.109493 -1.311312  1.114983 -0.354610 -0.733014
# 4     -0.268628  0.109589  1.109493 -1.311312  1.152888 -0.299630 -0.714866
# ...         ...       ...       ...       ...       ...       ...       ...
# 28027 -0.398720 -0.150285  1.109493 -0.055624  0.932477 -0.150880  0.019820
# 28028 -0.398720 -0.132960  1.109493  0.040968  1.023730 -0.250673  0.178168
# 28029 -0.528813 -0.132960  1.075727 -0.055624  0.967574 -0.200777  0.349011
# 28030 -0.528813 -0.132960  1.075727  0.137559  0.932477 -0.100984  0.253722
# 28031 -0.528813 -0.132960  1.041961 -0.055624  1.063039 -0.100984  0.410756
#
# [28032 rows x 36 columns]

# %%
df[0].columns
# Out:
# Index(['수온', '수소이온농도', '전기전도도', '용존산소', '총유기탄소', '총질소', '총인', '클로로필-a',
#        'Day sin', 'Day cos', 'Year sin', 'Year cos'],
#       dtype='object')

# %%
MAX_EPOCHS = 150
target_col = '용존산소'
num_features = df[0].shape[1]
label_columns_indices = {name: i for i, name in enumerate(df[0])}
target_col_idx = label_columns_indices[target_col]
# target_col_idx
# out_features = [target_col_idx]
out_features = [3,4,5,6,7]
out_num_features = len(out_features)
out_num_features
# Out:
# 5

# %%
class WaterDataGenerator(keras.utils.Sequence):
    'Generates data for water'
    def __init__(self,
                 imputed_data,
                 ori_data = None,
                 batch_size=32,
                 input_width=24*7,
                 label_width=24*3,
                 shift=24*3,
                 skip_time = None,
                 shuffle = True,
                 out_features = None,
                 out_num_features = None,
                ):
        'Initialization'
        self.window_size = input_width+shift
        self.total_no = imputed_data.shape[0]
        self.data = imputed_data
        self.input_width = input_width
        self.label_width = label_width
        self.batch_size = batch_size
        self.input_shape = (batch_size, input_width, self.data.shape[1])
        self.out_num_features = out_num_features
#         print("out_features")
#         print(out_features)
        if out_features:
            self.out_features = out_features
        else:
            self.out_features = [i for i in range(out_num_features)]
        self.label_shape = (batch_size, label_width, self.out_num_features)
        if (skip_time):
            # TO-DO
            self.no = self.total_no - self.window_size
            self.data_idx = np.arange(0, self.no)
        else:
            self.no = self.total_no - self.window_size
            self.data_idx = np.arange(0, self.no)
            
        if shuffle:
            self.batch_idx = np.random.permutation(self.no)
        else:
            self.batch_idx = np.arange(0, self.no)
        self.batch_id = 0
        
        
    def __len__(self):
        'Denotes the number of batches per epoch'
        #return int(128/self.batch_size)
        #return 2
        return 1

    def __getitem__(self, index):
        'Generate one batch of data'
        #print('index =', index)
        #print('self.no =', self.no)
        #print('self.total_no =', self.total_no)
        #print('self.batch_id =', self.batch_id)
        # Sample batch
        label_width = self.label_width
        batch_idx = self.batch_idx
        
        x = np.empty((0, self.input_width, self.data.shape[1]))
        
        #y = np.empty((0, self.input_width, self.data.shape[1]))
        y = np.empty((0, self.label_width, self.out_num_features))
       
        #print(x.shape)
        #print(y.shape)
        
        
        for cnt in range(0, self.batch_size):
            i = self.batch_id
            self.batch_id += 1
            idx1 = self.data_idx[batch_idx[i]]
            idx2 = idx1 + self.input_width
            
            X = self.data[idx1:idx2].to_numpy()
            
            
            idx1 = self.data_idx[batch_idx[i]] + self.window_size - label_width
            idx2 = idx1 + label_width
            
            #Y = self.data[idx1:idx2,:,:out_num_features]
            Y = self.data.iloc[idx1:idx2, self.out_features].to_numpy()
            #Y = self.data[idx1:idx2]
            #print('Y.shape = ', Y.shape)
            #Y = Y.iloc[:,:out_num_features]
            
            self.batch_id %= self.no
            #print("x.shape=", x.shape)
            #print('X.shape=', X.shape)
            #print(type(x), type(X))
            x = np.append(x, [X], axis = 0)
            
            y = np.append(y, [Y], axis = 0)
            
        return x, y
    
    def on_epoch_end(self):
        'Updates indexes after each epoch'
        return

# %% [markdown]
# **WaterDataGenerator 테스트**

# %%
OUT_STEPS = 24*5

# %%
# OUT_STEPS = 24*3
# wdg = WaterDataGenerator(train_df,
#                          batch_size=128,
#                          input_width = 24*7,
#                          label_width = OUT_STEPS,
#                          shift = OUT_STEPS,
#                          out_num_features = out_num_features,
# #                          out_features = out_features
#                         )

# %%
# train_df

# %%
# it = iter(wdg)

# %%
# x,y = next(it)
# x.shape, y.shape

# %%
def make_dataset_water(self, data):
#   print("make_dataset_water")
#   print(out_features)
  dg = WaterDataGenerator(
      data,
      batch_size = 128,
      input_width = self.input_width,
      label_width = self.label_width,
      shift = self.label_width,
      out_features = out_features,
      out_num_features = out_num_features,
  )
  #self.dg = dg
  ds = tf.data.Dataset.from_generator(
      lambda: dg,
      output_types=(tf.float32, tf.float32),
      output_shapes=(
        dg.input_shape,
        dg.label_shape
        #[batch_size, train_generator.dim],
        #[batch_size, train_generator.dim],
      )
  )
  return ds

WindowGenerator.make_dataset = make_dataset_water

# %%
def plot2(self, model=None, plot_col=0, max_subplots=3, plot_out_col=0):
  inputs, labels = self.example
  plt.figure(figsize=(10, 8))
  plot_col_index = self.column_indices[plot_col]
  plot_out_col_index = self.column_indices[plot_out_col]
  max_n = min(max_subplots, len(inputs))
  for n in range(max_n):
    plt.subplot(3, 1, n+1)
    plt.ylabel(f'{plot_col} [normed]', fontproperties=fprop)
    plt.plot(self.input_indices, inputs[n, :, plot_col_index],
             label='Inputs', marker='.', zorder=-10)

    if self.label_columns:
      label_col_index = self.label_columns_indices.get(plot_col, None)
      label_out_col_index = self.label_columns_indices.get(plot_out_col, None)
    else:
      label_col_index = plot_col_index
      label_out_col_index = plot_out_col_index

    if label_col_index is None:
      continue

    plt.scatter(self.label_indices, labels[n, :, label_out_col_index],
                label='Labels', c='#2ca02c')
    if model is not None:
      predictions = model(inputs)
      plt.scatter(self.label_indices, predictions[n, :, label_out_col_index],
                  marker=None, label='Predictions',
                  c='#ff7f0e')

    if n == 0:
      plt.legend()

  plt.xlabel('Time [h]')

WindowGenerator.plot2 = plot2

# %% [markdown]
# **1일단위로 변환**

# %%
def hour_to_day_mean(array):
    
#     print("1")
#     print(array)
    
    time = 24
    array = np.reshape(array, (array.shape[0], array.shape[1]//time, time, array.shape[2]))

    array = np.mean(array, axis=2)
    
#     print(array)

    return array

def plot24(self, model=None, plot_col=0, max_subplots=3, plot_out_col=0):
    
  inputs, labels = self.example
  plt.figure(figsize=(10, 8))
  plot_col_index = self.column_indices[plot_col]
  plot_out_col_index = self.column_indices[plot_out_col]
  max_n = min(max_subplots, len(inputs))

  if self.label_columns:
    label_col_index = self.label_columns_indices.get(plot_col, None)
    label_out_col_index = self.label_columns_indices.get(plot_out_col, None)
  else:
    label_col_index = plot_col_index
    label_out_col_index = plot_out_col_index
    
  for n in range(max_n):
    plt.subplot(3, 1, n+1)
    plt.ylabel(f'{df_all.columns[plot_col]} [normed]', fontproperties=fprop)
    
    input_temp = hour_to_day_mean(inputs[n, :, plot_col_index])
    input_temp = (input_temp * (train_std[plot_col] + 1e-6)) + train_mean[plot_col]
#     input_temp = input_temp * train_std[plot_col] + train_mean[plot_col]
    
    plt.plot(
        hour_to_day_mean(self.input_indices),
        input_temp,
        label='Inputs', marker='.', zorder=-10)

    if label_col_index is None:
      continue
    
    label_temp = hour_to_day_mean(labels[n, :, label_out_col_index])
    label_temp = (label_temp * (train_std[plot_col] + 1e-6)) + train_mean[plot_col]
#     label_temp = label_temp * train_std[plot_col] + train_mean[plot_col]
    
    plt.plot(
        hour_to_day_mean(self.label_indices),
        label_temp,
        label='Labels', marker='.', zorder=-10, c='#2ca02c')
    
    if model is not None:
      predictions = model(inputs)
    
      #predictions = predictions * train_std[plot_col] * train_mean[plot_col]
      predict_temp = hour_to_day_mean(predictions[n,:, label_out_col_index])
      predict_temp = (predict_temp * (train_std[plot_col] + 1e-6)) + train_mean[plot_col]
#       predict_temp = predict_temp * train_std[plot_col] + train_mean[plot_col]
    
      plt.plot(
          hour_to_day_mean(self.label_indices),
          predict_temp,
          label='Predictions', marker='.', zorder=-10, c='#ff7f0e')

    if n == 0:
      plt.legend()

  plt.xlabel('Time [day]')

WindowGenerator.plot24 = plot24

# %% [markdown]
# **예측률 계산**

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
def compa(self, model=None, plot_col=0, max_subplots=3, plot_out_col=0, windows=None):
       
    if example is not None :
        inputs, labels = windows
    else :
        inputs, labels = self.example
        
        
#     plot_out_col_index = self.column_indices[plot_out_col]
    
#     if self.label_columns:
#         label_out_col_index = self.label_columns_indices.get(plot_out_col, None)
#     else:
#         label_out_col_index = plot_out_col_index
    
    if model is None:
        return
    
#     print(plot_col)
    
#     print("column : " + df_all.columns[plot_col])
    
    mae = 0
    mse = 0
    rmse = 0
    mape = 0
    pred_arr = []
    label_arr = []
    
    sum_pred = 0
    sum_label =0
    
    o = 0
    p = 0
    
#     print(train_std[plot_col])
    
#     print(inputs.shape)
#     print(inputs[0].shape)

#     inputs = inputs[0:1]
    
# #     print(inputs)
    
#     labels = labels[0:1]
    
    predictions = model(inputs)
    
    pred = predictions.numpy()
    label = labels.numpy()
    
    for i in range(5) :
#         print(print("column : " + df_all.columns[plot_col[i]]))
        pred[:,:,i] = pred[:,:,i] * train_std[plot_col[i]] + train_mean[plot_col[i]]
        label[:,:,i] = label[:,:,i]* train_std[plot_col[i]] + train_mean[plot_col[i]]

        
#     pred_temp = hour_to_day_mean(pred[127:128,:,:]) 
    #for n in range(len(inputs)):
    #     for i in range(5) :         
     #           pred_temp = hour_to_day_mean(pred[n:n+1,:,i:i+1])
     #           label_temp = hour_to_day_mean(label[n:n+1,:,i:i+1])
    
     #for n in range(len(inputs)):           
      #      pred_temp = hour_to_day_mean(pred[n:n+1,:,:])
      #      label_temp = hour_to_day_mean(label[n:n+1,:,:])
            
#     print(pred.shape)
    
    pred = hour_to_day_mean(pred)
    label = hour_to_day_mean(label)
    
    o = np.sum(label[:,4,:],axis=0)
    
    p = np.sum(pred[:,4,:],axis=0)
    
    print("p")
    print(p)
    print("o")
    print(o)
    
       
    err = np.abs(o-p) / o *100
    
#     print(err.shape)
    
#     print(err)
    
    print(err[0])
    print(err[1])
    print(err[2])
    print(err[3])
    print(err[4])
    
    
#     print(np.sum(err,axis=0))
    
    
        
        
#     print(pred_temp)
#     np.sum(pred_temp)
#     print(pred_temp.shape)
    
#     label_temp = hour_to_day_mean(label[0][:][0])
#     print(pred[0,:,0])
#     print("adsfasdfadsfadsf")
#     print(pred_temp)
#     print(pred[0,0,0])
#     print(pred[0,0,1])
#     print(pred[0,0,2])
#     print(pred[0,0,3])
#     print(pred[0,0,4])
#       pred_temp = hour_to_day_mean(pred[0][:][0]) 
#     label_temp = hour_to_day_mean(label[0][:][0])
        
#     print(pred_temp[4])
#     print(pred_temp[4])
    
#     for n in range(len(inputs)):
#         pred_temp = hour_to_day_mean(pred[n][:][0]) 
#         label_temp = hour_to_day_mean(label[n][:][0])
        
#         print(pred_temp[4])
#         print(pred_temp[4])
    
    
#     predictions[:][:][pred_col_no] = predictions[:][:][pred_col_no] * train_std[plot_col] + train_mean[plot_col]
#     labels = labels * train_std[plot_col] + train_mean[plot_col]
    
    
#     print(predictions[0])
# #     print(plot_col)
# #     print(plot_out_col_index)
# #     pred = predictions.numpy()
# #     print(pred.shape)
# #     print(pred)
# #     print(pred[0][0][pred_col_no])

#     label = labels.numpy()
#     print(label.shape)
#     print(label)
#     print(label[0][0][pred_col_no])
    
    
    
#     print('++++++++++++++++++++++++')
#     print(np.sum(predictions.numpy()))
    
#     print(predictions.numpy().sum())
    
#     print('++++++++++++++++++++++++')
#     print(np.sum(labels.numpy()))
    
#     o = np.sum(labels.numpy())
#     p = np.sum(predictions.numpy())
#     print('++++++++++++++++++++++++')
#     print(np.abs(o-p) / o *100)

    
    
    
#     if min_max_normailze :
#         predictions = predictions * train_std[plot_col] + train_mean[plot_col]
#         labels = labels * train_std[plot_col] + train_mean[plot_col]
        
#         predictions = predictions.numpy()
#         labels = labels.numpy()
        
#         predictions = (predictions - predictions.min()) / (predictions.max() - predictions.min())
#         labels = (labels - labels.min()) / (labels.max() - labels.min())
    
#     for n in range(len(inputs)):
#         pred_temp = hour_to_day_mean(predictions[n,:,label_out_col_index]) 
#         label_temp = hour_to_day_mean(labels[n,:,label_out_col_index])
        
#         pred_arr.append(pred_temp[4])
#         label_arr.append(label_temp[4])
        
# #         print(pred_temp[4].numpy())

        
#         sum_pred = sum_pred + pred_temp[4].numpy()
#         sum_label = sum_label + label_temp[4].numpy()
       
        
#     mae = mean_absolute_error(label_arr, pred_arr) 
#     mse = mean_squared_error(label_arr, pred_arr)
#     rmse = np.sqrt(mse)
#     mape = np.mean(np.abs((np.array(label_arr) - np.array(pred_arr))/np.array(label_arr)) )*100
    
   

# #     print(sum_pred)
#     pbias = ( np.abs(sum_label - sum_pred) / sum_label ) * 100 
    
# #     pbias = ( (sum_label - sum_pred) / sum_label ) * 100 
    
#     print("mae:")  
#     print(mae)
    
#     print("mse:")  
#     print(mse)
    
#     print("rmse")  
#     print(rmse)
    
#     print("mape")  
#     print(mape)
    
#     print('pbias')
#     print(pbias)
    
    

WindowGenerator.compa = compa

# %%
np.abs(5.9624996  - 8.015346 ) / 5.9624996 *100
# Out:
# 34.42929203718519

# %%
30 * 128
# Out:
# 3840

# %%
train_std
# Out:
# 수온           8.406999
# 수소이온농도       0.768682
# 전기전도도       57.720177
# 용존산소         2.961568
# 총유기탄소        1.035289
# 총질소          0.712306
# 총인           0.020042
# 클로로필-a      11.020416
# Day sin      0.707109
# Day cos      0.707109
# Year sin     0.707102
# Year cos     0.707117
# dtype: float64

# %%
train_df.shape
# Out:
# (28032, 36)

# %%
#multi_window.compa(elman_model, plot_col=out_features[0])

# %%
# target_col = '용존산소'
# num_features = df[0].shape[1]
# label_columns_indices = {name: i for i, name in enumerate(df[0])}
# target_col_idx = label_columns_indices[target_col]
# # target_col_idx
# out_features = [target_col_idx]
# # out_features = [3,5,6,7,8]
# out_num_features = len(out_features)
# out_num_features

# %%
def compile_and_fit(model, window, patience=1000):
  early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss',
                                                    patience=patience,
                                                    mode='min')

  model.compile(loss=tf.losses.MeanSquaredError(),
                optimizer=tf.optimizers.Adam(),
                metrics=[tf.metrics.MeanAbsoluteError()])
#   model.compile(loss=tf.losses.MeanSquaredError(),
#                 optimizer=tf.optimizers.Adam(),
#                 metrics=[tf.metrics.MeanSquaredError()])
  #model.compile(loss=GAIN.RMSE_loss)

  history = model.fit(window.train, epochs=MAX_EPOCHS,
                      validation_data=window.val,
                      callbacks=[early_stopping])
  return history

# %%
def plot_history(history):
    fig = plt.figure()
    ax = fig.add_subplot(111)
    ax.plot(history.history['loss'], label='loss')
    ax.plot(history.history['mean_absolute_error'], label='mae')
#     ax.plot(history.history['mean_squared_error'], label='mse')
    ax.plot(history.history['val_loss'], label='val_loss')
    ax.plot(history.history['val_mean_absolute_error'], label='val_mae')
#     ax.plot(history.history['val_mean_squared_error'], label='val_mse')
    #plt.legend(history.history.keys(), loc='upper right')
    #ax.legend(loc='upper center')
    ax.legend()
    ax.set_xlabel("epochs")
    ax.set_ylabel("loss")
    plt.show()

# %%
multi_window = WindowGenerator(input_width=24*7,
                               label_width=OUT_STEPS,
                               shift=OUT_STEPS,
                               train_df=train_df,
                               val_df=val_df,
                               test_df=test_df,
                               out_features = out_features,
                               out_num_features = out_num_features,
                               )

# %%
multi_val_performance = {}
multi_performance = {}

# %% [markdown]
# **Elman_RNN**

# %%
elman_model = tf.keras.Sequential([
    # Take the last time step.
    # Shape [batch, time, features] => [batch, 1, features]
    tf.keras.layers.SimpleRNN(128, return_sequences=False),

    tf.keras.layers.Dense(OUT_STEPS*out_num_features,
                          kernel_initializer=tf.initializers.zeros),

    tf.keras.layers.Reshape([OUT_STEPS, out_num_features])
])

# %%
elman_model = tf.keras.Sequential([
    # Take the last time step.
    # Shape [batch, time, features] => [batch, 1, features]
#     tf.keras.layers.SimpleRNN(128, return_sequences=True),
#     tf.keras.layers.SimpleRNN(128, return_sequences=True),
#     tf.keras.layers.SimpleRNN(128, return_sequences=True),
#     tf.keras.layers.SimpleRNN(128, return_sequences=True),
#     tf.keras.layers.SimpleRNN(128, return_sequences=True),
#     tf.keras.layers.SimpleRNN(128, return_sequences=True),
#     tf.keras.layers.SimpleRNN(128, return_sequences=True),
#     tf.keras.layers.SimpleRNN(128, return_sequences=True),
    tf.keras.layers.SimpleRNN(128, return_sequences=False),

    tf.keras.layers.Dense(OUT_STEPS*out_num_features,
                          kernel_initializer=tf.initializers.zeros),

    tf.keras.layers.Reshape([OUT_STEPS, out_num_features])
])

# %%
history = compile_and_fit(elman_model, multi_window)
multi_val_performance['ELMAN_RNN'] = elman_model.evaluate(multi_window.val.repeat(-1), steps=100)
multi_performance['ELMAN_RNN'] = elman_model.evaluate(multi_window.test.repeat(-1), verbose=1, steps=100)
print('val performance =', multi_val_performance['ELMAN_RNN'])
print('test performance = ', multi_performance['ELMAN_RNN'])
# Out:
# Epoch 1/150
# 1/1 [==============================] - 1s 832ms/step - loss: 0.6825 - mean_absolute_error: 0.6609 - val_loss: 0.3654 - val_mean_absolute_error: 0.5490
# Epoch 2/150
# 1/1 [==============================] - 0s 320ms/step - loss: 0.6261 - mean_absolute_error: 0.6391 - val_loss: 0.3012 - val_mean_absolute_error: 0.4841
# Epoch 3/150
# 1/1 [==============================] - 0s 327ms/step - loss: 0.6034 - mean_absolute_error: 0.6238 - val_loss: 0.2802 - val_mean_absolute_error: 0.4637
# Epoch 4/150
# 1/1 [==============================] - 0s 286ms/step - loss: 0.5495 - mean_absolute_error: 0.5888 - val_loss: 0.2343 - val_mean_absolute_error: 0.4158
# Epoch 5/150
# 1/1 [==============================] - 0s 317ms/step - loss: 0.5160 - mean_absolute_error: 0.5484 - val_loss: 0.2045 - val_mean_absolute_error: 0.3868
# Epoch 6/150
# 1/1 [==============================] - 0s 301ms/step - loss: 0.4760 - mean_absolute_error: 0.5086 - val_loss: 0.1678 - val_mean_absolute_error: 0.3412
# Epoch 7/150
# 1/1 [==============================] - 0s 344ms/step - loss: 0.3313 - mean_absolute_error: 0.4266 - val_loss: 0.1328 - val_mean_absolute_error: 0.2983
# Epoch 8/150
# 1/1 [==============================] - 0s 312ms/step - loss: 0.2896 - mean_absolute_error: 0.3791 - val_loss: 0.1047 - val_mean_absolute_error: 0.2594
# Epoch 9/150
# 1/1 [==============================] - 0s 300ms/step - loss: 0.2873 - mean_absolute_error: 0.3470 - val_loss: 0.0992 - val_mean_absolute_error: 0.2526
# Epoch 10/150
# 1/1 [==============================] - 0s 327ms/step - loss: 0.2286 - mean_absolute_error: 0.3191 - val_loss: 0.1148 - val_mean_absolute_error: 0.2701
# Epoch 11/150
# 1/1 [==============================] - 0s 296ms/step - loss: 0.2996 - mean_absolute_error: 0.3573 - val_loss: 0.1315 - val_mean_absolute_error: 0.2879
# Epoch 12/150
# 1/1 [==============================] - 0s 274ms/step - loss: 0.2405 - mean_absolute_error: 0.3367 - val_loss: 0.1566 - val_mean_absolute_error: 0.3158
# Epoch 13/150
# 1/1 [==============================] - 0s 290ms/step - loss: 0.2350 - mean_absolute_error: 0.3317 - val_loss: 0.1693 - val_mean_absolute_error: 0.3231
# Epoch 14/150
# 1/1 [==============================] - 0s 322ms/step - loss: 0.1751 - mean_absolute_error: 0.3101 - val_loss: 0.1833 - val_mean_absolute_error: 0.3297
# Epoch 15/150
# 1/1 [==============================] - 0s 312ms/step - loss: 0.2117 - mean_absolute_error: 0.3344 - val_loss: 0.2128 - val_mean_absolute_error: 0.3571
# Epoch 16/150
# 1/1 [==============================] - 0s 311ms/step - loss: 0.1731 - mean_absolute_error: 0.3049 - val_loss: 0.2109 - val_mean_absolute_error: 0.3547
# Epoch 17/150
# 1/1 [==============================] - 0s 300ms/step - loss: 0.1670 - mean_absolute_error: 0.2970 - val_loss: 0.2094 - val_mean_absolute_error: 0.3567
# Epoch 18/150
# 1/1 [==============================] - 0s 288ms/step - loss: 0.1535 - mean_absolute_error: 0.2906 - val_loss: 0.1929 - val_mean_absolute_error: 0.3446
# Epoch 19/150
# 1/1 [==============================] - 0s 280ms/step - loss: 0.1752 - mean_absolute_error: 0.3066 - val_loss: 0.1855 - val_mean_absolute_error: 0.3473
# Epoch 20/150
# 1/1 [==============================] - 0s 337ms/step - loss: 0.1744 - mean_absolute_error: 0.3008 - val_loss: 0.1704 - val_mean_absolute_error: 0.3360
# Epoch 21/150
# 1/1 [==============================] - 0s 264ms/step - loss: 0.1740 - mean_absolute_error: 0.2959 - val_loss: 0.1681 - val_mean_absolute_error: 0.3330
# Epoch 22/150
# 1/1 [==============================] - 0s 332ms/step - loss: 0.1286 - mean_absolute_error: 0.2608 - val_loss: 0.1466 - val_mean_absolute_error: 0.3152
# Epoch 23/150
# 1/1 [==============================] - 0s 298ms/step - loss: 0.1082 - mean_absolute_error: 0.2367 - val_loss: 0.1354 - val_mean_absolute_error: 0.3069
# Epoch 24/150
# 1/1 [==============================] - 0s 335ms/step - loss: 0.1173 - mean_absolute_error: 0.2379 - val_loss: 0.1238 - val_mean_absolute_error: 0.2949
# Epoch 25/150
# 1/1 [==============================] - 0s 337ms/step - loss: 0.1202 - mean_absolute_error: 0.2328 - val_loss: 0.1228 - val_mean_absolute_error: 0.2899
# Epoch 26/150
# 1/1 [==============================] - 0s 277ms/step - loss: 0.1125 - mean_absolute_error: 0.2307 - val_loss: 0.1031 - val_mean_absolute_error: 0.2660
# Epoch 27/150
# 1/1 [==============================] - 0s 303ms/step - loss: 0.0971 - mean_absolute_error: 0.2172 - val_loss: 0.1110 - val_mean_absolute_error: 0.2762
# Epoch 28/150
# 1/1 [==============================] - 0s 321ms/step - loss: 0.1031 - mean_absolute_error: 0.2172 - val_loss: 0.0943 - val_mean_absolute_error: 0.2534
# Epoch 29/150
# 1/1 [==============================] - 0s 303ms/step - loss: 0.1016 - mean_absolute_error: 0.2208 - val_loss: 0.0878 - val_mean_absolute_error: 0.2390
# Epoch 30/150
# 1/1 [==============================] - 0s 271ms/step - loss: 0.0991 - mean_absolute_error: 0.2128 - val_loss: 0.0915 - val_mean_absolute_error: 0.2491
# Epoch 31/150
# 1/1 [==============================] - 0s 280ms/step - loss: 0.0893 - mean_absolute_error: 0.2022 - val_loss: 0.0862 - val_mean_absolute_error: 0.2421
# Epoch 32/150
# 1/1 [==============================] - 0s 273ms/step - loss: 0.0924 - mean_absolute_error: 0.2069 - val_loss: 0.0813 - val_mean_absolute_error: 0.2335
# Epoch 33/150
# 1/1 [==============================] - 0s 306ms/step - loss: 0.1013 - mean_absolute_error: 0.2193 - val_loss: 0.0818 - val_mean_absolute_error: 0.2337
# Epoch 34/150
# 1/1 [==============================] - 0s 301ms/step - loss: 0.0780 - mean_absolute_error: 0.1986 - val_loss: 0.0782 - val_mean_absolute_error: 0.2286
# Epoch 35/150
# 1/1 [==============================] - 0s 335ms/step - loss: 0.0779 - mean_absolute_error: 0.1980 - val_loss: 0.0768 - val_mean_absolute_error: 0.2293
# Epoch 36/150
# 1/1 [==============================] - 0s 294ms/step - loss: 0.1017 - mean_absolute_error: 0.2158 - val_loss: 0.0826 - val_mean_absolute_error: 0.2394
# Epoch 37/150
# 1/1 [==============================] - 0s 287ms/step - loss: 0.0785 - mean_absolute_error: 0.1993 - val_loss: 0.0839 - val_mean_absolute_error: 0.2382
# Epoch 38/150
# 1/1 [==============================] - 0s 407ms/step - loss: 0.0811 - mean_absolute_error: 0.1978 - val_loss: 0.0898 - val_mean_absolute_error: 0.2463
# Epoch 39/150
# 1/1 [==============================] - 0s 320ms/step - loss: 0.0718 - mean_absolute_error: 0.1858 - val_loss: 0.0836 - val_mean_absolute_error: 0.2351
# Epoch 40/150
# 1/1 [==============================] - 0s 313ms/step - loss: 0.0739 - mean_absolute_error: 0.1855 - val_loss: 0.0958 - val_mean_absolute_error: 0.2485
# Epoch 41/150
# 1/1 [==============================] - 0s 312ms/step - loss: 0.0692 - mean_absolute_error: 0.1869 - val_loss: 0.0884 - val_mean_absolute_error: 0.2410
# Epoch 42/150
# 1/1 [==============================] - 0s 310ms/step - loss: 0.0626 - mean_absolute_error: 0.1787 - val_loss: 0.1009 - val_mean_absolute_error: 0.2533
# Epoch 43/150
# 1/1 [==============================] - 0s 290ms/step - loss: 0.0653 - mean_absolute_error: 0.1828 - val_loss: 0.0957 - val_mean_absolute_error: 0.2533
# Epoch 44/150
# 1/1 [==============================] - 0s 303ms/step - loss: 0.0682 - mean_absolute_error: 0.1863 - val_loss: 0.0972 - val_mean_absolute_error: 0.2547
# Epoch 45/150
# 1/1 [==============================] - 0s 330ms/step - loss: 0.0859 - mean_absolute_error: 0.2031 - val_loss: 0.1059 - val_mean_absolute_error: 0.2644
# Epoch 46/150
# 1/1 [==============================] - 0s 318ms/step - loss: 0.0634 - mean_absolute_error: 0.1842 - val_loss: 0.1056 - val_mean_absolute_error: 0.2610
# Epoch 47/150
# 1/1 [==============================] - 0s 290ms/step - loss: 0.0759 - mean_absolute_error: 0.1951 - val_loss: 0.0918 - val_mean_absolute_error: 0.2471
# Epoch 48/150
# 1/1 [==============================] - 0s 273ms/step - loss: 0.0754 - mean_absolute_error: 0.1902 - val_loss: 0.0907 - val_mean_absolute_error: 0.2478
# Epoch 49/150
# 1/1 [==============================] - 0s 292ms/step - loss: 0.0663 - mean_absolute_error: 0.1837 - val_loss: 0.0882 - val_mean_absolute_error: 0.2430
# Epoch 50/150
# 1/1 [==============================] - 0s 285ms/step - loss: 0.0632 - mean_absolute_error: 0.1842 - val_loss: 0.0894 - val_mean_absolute_error: 0.2422
# Epoch 51/150
# 1/1 [==============================] - 0s 293ms/step - loss: 0.0627 - mean_absolute_error: 0.1822 - val_loss: 0.0806 - val_mean_absolute_error: 0.2320
# Epoch 52/150
# 1/1 [==============================] - 0s 269ms/step - loss: 0.0630 - mean_absolute_error: 0.1750 - val_loss: 0.0900 - val_mean_absolute_error: 0.2447
# Epoch 53/150
# 1/1 [==============================] - 0s 302ms/step - loss: 0.0816 - mean_absolute_error: 0.1982 - val_loss: 0.0761 - val_mean_absolute_error: 0.2294
# Epoch 54/150
# 1/1 [==============================] - 0s 290ms/step - loss: 0.0523 - mean_absolute_error: 0.1699 - val_loss: 0.0746 - val_mean_absolute_error: 0.2223
# Epoch 55/150
# 1/1 [==============================] - 0s 288ms/step - loss: 0.0593 - mean_absolute_error: 0.1768 - val_loss: 0.0761 - val_mean_absolute_error: 0.2272
# Epoch 56/150
# 1/1 [==============================] - 0s 300ms/step - loss: 0.0614 - mean_absolute_error: 0.1754 - val_loss: 0.0702 - val_mean_absolute_error: 0.2199
# Epoch 57/150
# 1/1 [==============================] - 0s 313ms/step - loss: 0.0578 - mean_absolute_error: 0.1724 - val_loss: 0.0713 - val_mean_absolute_error: 0.2202
# Epoch 58/150
# 1/1 [==============================] - 0s 295ms/step - loss: 0.0671 - mean_absolute_error: 0.1805 - val_loss: 0.0717 - val_mean_absolute_error: 0.2198
# Epoch 59/150
# 1/1 [==============================] - 0s 271ms/step - loss: 0.0764 - mean_absolute_error: 0.1893 - val_loss: 0.0747 - val_mean_absolute_error: 0.2221
# Epoch 60/150
# 1/1 [==============================] - 0s 290ms/step - loss: 0.0618 - mean_absolute_error: 0.1793 - val_loss: 0.0711 - val_mean_absolute_error: 0.2192
# Epoch 61/150
# 1/1 [==============================] - 0s 311ms/step - loss: 0.0649 - mean_absolute_error: 0.1838 - val_loss: 0.0797 - val_mean_absolute_error: 0.2312
# Epoch 62/150
# 1/1 [==============================] - 0s 271ms/step - loss: 0.0597 - mean_absolute_error: 0.1761 - val_loss: 0.0817 - val_mean_absolute_error: 0.2319
# Epoch 63/150
# 1/1 [==============================] - 0s 331ms/step - loss: 0.0618 - mean_absolute_error: 0.1727 - val_loss: 0.0953 - val_mean_absolute_error: 0.2474
# Epoch 64/150
# 1/1 [==============================] - 0s 316ms/step - loss: 0.0590 - mean_absolute_error: 0.1735 - val_loss: 0.0818 - val_mean_absolute_error: 0.2310
# Epoch 65/150
# 1/1 [==============================] - 0s 325ms/step - loss: 0.0445 - mean_absolute_error: 0.1559 - val_loss: 0.1030 - val_mean_absolute_error: 0.2542
# Epoch 66/150
# 1/1 [==============================] - 0s 304ms/step - loss: 0.0579 - mean_absolute_error: 0.1738 - val_loss: 0.0931 - val_mean_absolute_error: 0.2426
# Epoch 67/150
# 1/1 [==============================] - 0s 313ms/step - loss: 0.0569 - mean_absolute_error: 0.1656 - val_loss: 0.0946 - val_mean_absolute_error: 0.2449
# Epoch 68/150
# 1/1 [==============================] - 0s 306ms/step - loss: 0.0534 - mean_absolute_error: 0.1693 - val_loss: 0.0964 - val_mean_absolute_error: 0.2517
# Epoch 69/150
# 1/1 [==============================] - 0s 305ms/step - loss: 0.0502 - mean_absolute_error: 0.1596 - val_loss: 0.0929 - val_mean_absolute_error: 0.2465
# Epoch 70/150
# 1/1 [==============================] - 0s 273ms/step - loss: 0.0448 - mean_absolute_error: 0.1574 - val_loss: 0.0964 - val_mean_absolute_error: 0.2544
# Epoch 71/150
# 1/1 [==============================] - 0s 299ms/step - loss: 0.0587 - mean_absolute_error: 0.1725 - val_loss: 0.0930 - val_mean_absolute_error: 0.2482
# Epoch 72/150
# 1/1 [==============================] - 0s 300ms/step - loss: 0.0517 - mean_absolute_error: 0.1678 - val_loss: 0.0781 - val_mean_absolute_error: 0.2282
# Epoch 73/150
# 1/1 [==============================] - 0s 288ms/step - loss: 0.0531 - mean_absolute_error: 0.1687 - val_loss: 0.0767 - val_mean_absolute_error: 0.2284
# Epoch 74/150
# 1/1 [==============================] - 0s 333ms/step - loss: 0.0440 - mean_absolute_error: 0.1537 - val_loss: 0.0768 - val_mean_absolute_error: 0.2265
# Epoch 75/150
# 1/1 [==============================] - 0s 327ms/step - loss: 0.0602 - mean_absolute_error: 0.1674 - val_loss: 0.0790 - val_mean_absolute_error: 0.2281
# Epoch 76/150
# 1/1 [==============================] - 0s 263ms/step - loss: 0.0534 - mean_absolute_error: 0.1653 - val_loss: 0.0701 - val_mean_absolute_error: 0.2141
# Epoch 77/150
# 1/1 [==============================] - 0s 304ms/step - loss: 0.0442 - mean_absolute_error: 0.1560 - val_loss: 0.0824 - val_mean_absolute_error: 0.2317
# Epoch 78/150
# 1/1 [==============================] - 0s 294ms/step - loss: 0.0459 - mean_absolute_error: 0.1560 - val_loss: 0.0761 - val_mean_absolute_error: 0.2230
# Epoch 79/150
# 1/1 [==============================] - 0s 282ms/step - loss: 0.0429 - mean_absolute_error: 0.1498 - val_loss: 0.0780 - val_mean_absolute_error: 0.2230
# Epoch 80/150
# 1/1 [==============================] - 0s 310ms/step - loss: 0.0460 - mean_absolute_error: 0.1578 - val_loss: 0.0823 - val_mean_absolute_error: 0.2290
# Epoch 81/150
# 1/1 [==============================] - 0s 353ms/step - loss: 0.0495 - mean_absolute_error: 0.1556 - val_loss: 0.0782 - val_mean_absolute_error: 0.2289
# Epoch 82/150
# 1/1 [==============================] - 0s 274ms/step - loss: 0.0475 - mean_absolute_error: 0.1575 - val_loss: 0.0811 - val_mean_absolute_error: 0.2297
# Epoch 83/150
# 1/1 [==============================] - 0s 278ms/step - loss: 0.0465 - mean_absolute_error: 0.1589 - val_loss: 0.0777 - val_mean_absolute_error: 0.2260
# Epoch 84/150
# 1/1 [==============================] - 0s 289ms/step - loss: 0.0421 - mean_absolute_error: 0.1545 - val_loss: 0.0839 - val_mean_absolute_error: 0.2340
# Epoch 85/150
# 1/1 [==============================] - 0s 288ms/step - loss: 0.0462 - mean_absolute_error: 0.1556 - val_loss: 0.0767 - val_mean_absolute_error: 0.2263
# Epoch 86/150
# 1/1 [==============================] - 0s 307ms/step - loss: 0.0394 - mean_absolute_error: 0.1490 - val_loss: 0.0796 - val_mean_absolute_error: 0.2281
# Epoch 87/150
# 1/1 [==============================] - 0s 291ms/step - loss: 0.0450 - mean_absolute_error: 0.1570 - val_loss: 0.0784 - val_mean_absolute_error: 0.2254
# Epoch 88/150
# 1/1 [==============================] - 0s 330ms/step - loss: 0.0461 - mean_absolute_error: 0.1476 - val_loss: 0.0867 - val_mean_absolute_error: 0.2362
# Epoch 89/150
# 1/1 [==============================] - 0s 334ms/step - loss: 0.0438 - mean_absolute_error: 0.1551 - val_loss: 0.0719 - val_mean_absolute_error: 0.2158
# Epoch 90/150
# 1/1 [==============================] - 0s 313ms/step - loss: 0.0395 - mean_absolute_error: 0.1476 - val_loss: 0.0878 - val_mean_absolute_error: 0.2385
# Epoch 91/150
# 1/1 [==============================] - 0s 293ms/step - loss: 0.0395 - mean_absolute_error: 0.1494 - val_loss: 0.0820 - val_mean_absolute_error: 0.2285
# Epoch 92/150
# 1/1 [==============================] - 0s 318ms/step - loss: 0.0420 - mean_absolute_error: 0.1552 - val_loss: 0.0743 - val_mean_absolute_error: 0.2199
# Epoch 93/150
# 1/1 [==============================] - 0s 283ms/step - loss: 0.0463 - mean_absolute_error: 0.1548 - val_loss: 0.0868 - val_mean_absolute_error: 0.2402
# Epoch 94/150
# 1/1 [==============================] - 0s 312ms/step - loss: 0.0544 - mean_absolute_error: 0.1658 - val_loss: 0.0785 - val_mean_absolute_error: 0.2260
# Epoch 95/150
# 1/1 [==============================] - 0s 294ms/step - loss: 0.0414 - mean_absolute_error: 0.1512 - val_loss: 0.0909 - val_mean_absolute_error: 0.2460
# Epoch 96/150
# 1/1 [==============================] - 0s 302ms/step - loss: 0.0431 - mean_absolute_error: 0.1512 - val_loss: 0.0821 - val_mean_absolute_error: 0.2329
# Epoch 97/150
# 1/1 [==============================] - 0s 302ms/step - loss: 0.0393 - mean_absolute_error: 0.1464 - val_loss: 0.0725 - val_mean_absolute_error: 0.2185
# Epoch 98/150
# 1/1 [==============================] - 0s 308ms/step - loss: 0.0433 - mean_absolute_error: 0.1531 - val_loss: 0.0726 - val_mean_absolute_error: 0.2197
# Epoch 99/150
# 1/1 [==============================] - 0s 292ms/step - loss: 0.0397 - mean_absolute_error: 0.1437 - val_loss: 0.0704 - val_mean_absolute_error: 0.2157
# Epoch 100/150
# 1/1 [==============================] - 0s 308ms/step - loss: 0.0451 - mean_absolute_error: 0.1503 - val_loss: 0.0790 - val_mean_absolute_error: 0.2275
# Epoch 101/150
# 1/1 [==============================] - 0s 339ms/step - loss: 0.0337 - mean_absolute_error: 0.1373 - val_loss: 0.0689 - val_mean_absolute_error: 0.2129
# Epoch 102/150
# 1/1 [==============================] - 0s 290ms/step - loss: 0.0408 - mean_absolute_error: 0.1474 - val_loss: 0.0828 - val_mean_absolute_error: 0.2355
# Epoch 103/150
# 1/1 [==============================] - 0s 301ms/step - loss: 0.0416 - mean_absolute_error: 0.1474 - val_loss: 0.0811 - val_mean_absolute_error: 0.2344
# Epoch 104/150
# 1/1 [==============================] - 0s 314ms/step - loss: 0.0367 - mean_absolute_error: 0.1434 - val_loss: 0.0792 - val_mean_absolute_error: 0.2282
# Epoch 105/150
# 1/1 [==============================] - 0s 279ms/step - loss: 0.0358 - mean_absolute_error: 0.1431 - val_loss: 0.0790 - val_mean_absolute_error: 0.2270
# Epoch 106/150
# 1/1 [==============================] - 0s 304ms/step - loss: 0.0408 - mean_absolute_error: 0.1488 - val_loss: 0.0774 - val_mean_absolute_error: 0.2293
# Epoch 107/150
# 1/1 [==============================] - 0s 294ms/step - loss: 0.0372 - mean_absolute_error: 0.1405 - val_loss: 0.0801 - val_mean_absolute_error: 0.2283
# Epoch 108/150
# 1/1 [==============================] - 0s 274ms/step - loss: 0.0426 - mean_absolute_error: 0.1491 - val_loss: 0.0702 - val_mean_absolute_error: 0.2167
# Epoch 109/150
# 1/1 [==============================] - 0s 273ms/step - loss: 0.0405 - mean_absolute_error: 0.1461 - val_loss: 0.0784 - val_mean_absolute_error: 0.2310
# Epoch 110/150
# 1/1 [==============================] - 0s 303ms/step - loss: 0.0439 - mean_absolute_error: 0.1500 - val_loss: 0.0767 - val_mean_absolute_error: 0.2317
# Epoch 111/150
# 1/1 [==============================] - 0s 315ms/step - loss: 0.0337 - mean_absolute_error: 0.1395 - val_loss: 0.0781 - val_mean_absolute_error: 0.2335
# Epoch 112/150
# 1/1 [==============================] - 0s 312ms/step - loss: 0.0419 - mean_absolute_error: 0.1515 - val_loss: 0.0768 - val_mean_absolute_error: 0.2282
# Epoch 113/150
# 1/1 [==============================] - 0s 280ms/step - loss: 0.0358 - mean_absolute_error: 0.1394 - val_loss: 0.0813 - val_mean_absolute_error: 0.2340
# Epoch 114/150
# 1/1 [==============================] - 0s 294ms/step - loss: 0.0349 - mean_absolute_error: 0.1382 - val_loss: 0.0678 - val_mean_absolute_error: 0.2101
# Epoch 115/150
# 1/1 [==============================] - 0s 280ms/step - loss: 0.0375 - mean_absolute_error: 0.1429 - val_loss: 0.0831 - val_mean_absolute_error: 0.2313
# Epoch 116/150
# 1/1 [==============================] - 0s 301ms/step - loss: 0.0406 - mean_absolute_error: 0.1488 - val_loss: 0.0777 - val_mean_absolute_error: 0.2216
# Epoch 117/150
# 1/1 [==============================] - 0s 293ms/step - loss: 0.0340 - mean_absolute_error: 0.1377 - val_loss: 0.0711 - val_mean_absolute_error: 0.2141
# Epoch 118/150
# 1/1 [==============================] - 0s 292ms/step - loss: 0.0323 - mean_absolute_error: 0.1330 - val_loss: 0.0862 - val_mean_absolute_error: 0.2392
# Epoch 119/150
# 1/1 [==============================] - 0s 267ms/step - loss: 0.0325 - mean_absolute_error: 0.1331 - val_loss: 0.0747 - val_mean_absolute_error: 0.2218
# Epoch 120/150
# 1/1 [==============================] - 0s 284ms/step - loss: 0.0353 - mean_absolute_error: 0.1368 - val_loss: 0.0915 - val_mean_absolute_error: 0.2489
# Epoch 121/150
# 1/1 [==============================] - 0s 289ms/step - loss: 0.0367 - mean_absolute_error: 0.1412 - val_loss: 0.0820 - val_mean_absolute_error: 0.2353
# Epoch 122/150
# 1/1 [==============================] - 0s 326ms/step - loss: 0.0330 - mean_absolute_error: 0.1348 - val_loss: 0.0765 - val_mean_absolute_error: 0.2250
# Epoch 123/150
# 1/1 [==============================] - 0s 287ms/step - loss: 0.0391 - mean_absolute_error: 0.1453 - val_loss: 0.0692 - val_mean_absolute_error: 0.2139
# Epoch 124/150
# 1/1 [==============================] - 0s 325ms/step - loss: 0.0315 - mean_absolute_error: 0.1301 - val_loss: 0.0675 - val_mean_absolute_error: 0.2083
# Epoch 125/150
# 1/1 [==============================] - 0s 289ms/step - loss: 0.0339 - mean_absolute_error: 0.1396 - val_loss: 0.0734 - val_mean_absolute_error: 0.2166
# Epoch 126/150
# 1/1 [==============================] - 0s 264ms/step - loss: 0.0342 - mean_absolute_error: 0.1389 - val_loss: 0.0676 - val_mean_absolute_error: 0.2078
# Epoch 127/150
# 1/1 [==============================] - 0s 336ms/step - loss: 0.0315 - mean_absolute_error: 0.1326 - val_loss: 0.0712 - val_mean_absolute_error: 0.2160
# Epoch 128/150
# 1/1 [==============================] - 0s 269ms/step - loss: 0.0283 - mean_absolute_error: 0.1246 - val_loss: 0.0792 - val_mean_absolute_error: 0.2323
# Epoch 129/150
# 1/1 [==============================] - 0s 283ms/step - loss: 0.0299 - mean_absolute_error: 0.1308 - val_loss: 0.0732 - val_mean_absolute_error: 0.2223
# Epoch 130/150
# 1/1 [==============================] - 0s 264ms/step - loss: 0.0383 - mean_absolute_error: 0.1391 - val_loss: 0.0718 - val_mean_absolute_error: 0.2198
# Epoch 131/150
# 1/1 [==============================] - 0s 277ms/step - loss: 0.0344 - mean_absolute_error: 0.1357 - val_loss: 0.0753 - val_mean_absolute_error: 0.2265
# Epoch 132/150
# 1/1 [==============================] - 0s 307ms/step - loss: 0.0311 - mean_absolute_error: 0.1287 - val_loss: 0.0750 - val_mean_absolute_error: 0.2250
# Epoch 133/150
# 1/1 [==============================] - 0s 278ms/step - loss: 0.0342 - mean_absolute_error: 0.1352 - val_loss: 0.0632 - val_mean_absolute_error: 0.2063
# Epoch 134/150
# 1/1 [==============================] - 0s 349ms/step - loss: 0.0310 - mean_absolute_error: 0.1261 - val_loss: 0.0678 - val_mean_absolute_error: 0.2114
# Epoch 135/150
# 1/1 [==============================] - 0s 285ms/step - loss: 0.0355 - mean_absolute_error: 0.1348 - val_loss: 0.0670 - val_mean_absolute_error: 0.2105
# Epoch 136/150
# 1/1 [==============================] - 0s 316ms/step - loss: 0.0331 - mean_absolute_error: 0.1323 - val_loss: 0.0673 - val_mean_absolute_error: 0.2123
# Epoch 137/150
# 1/1 [==============================] - 0s 283ms/step - loss: 0.0326 - mean_absolute_error: 0.1338 - val_loss: 0.0641 - val_mean_absolute_error: 0.2055
# Epoch 138/150
# 1/1 [==============================] - 0s 343ms/step - loss: 0.0366 - mean_absolute_error: 0.1372 - val_loss: 0.0687 - val_mean_absolute_error: 0.2118
# Epoch 139/150
# 1/1 [==============================] - 0s 289ms/step - loss: 0.0317 - mean_absolute_error: 0.1296 - val_loss: 0.0581 - val_mean_absolute_error: 0.1926
# Epoch 140/150
# 1/1 [==============================] - 0s 275ms/step - loss: 0.0362 - mean_absolute_error: 0.1328 - val_loss: 0.0690 - val_mean_absolute_error: 0.2146
# Epoch 141/150
# 1/1 [==============================] - 0s 306ms/step - loss: 0.0301 - mean_absolute_error: 0.1241 - val_loss: 0.0684 - val_mean_absolute_error: 0.2120
# Epoch 142/150
# 1/1 [==============================] - 0s 308ms/step - loss: 0.0314 - mean_absolute_error: 0.1278 - val_loss: 0.0658 - val_mean_absolute_error: 0.2103
# Epoch 143/150
# 1/1 [==============================] - 0s 301ms/step - loss: 0.0335 - mean_absolute_error: 0.1284 - val_loss: 0.0737 - val_mean_absolute_error: 0.2244
# Epoch 144/150
# 1/1 [==============================] - 0s 304ms/step - loss: 0.0306 - mean_absolute_error: 0.1265 - val_loss: 0.0665 - val_mean_absolute_error: 0.2089
# Epoch 145/150
# 1/1 [==============================] - 0s 291ms/step - loss: 0.0338 - mean_absolute_error: 0.1348 - val_loss: 0.0778 - val_mean_absolute_error: 0.2282
# Epoch 146/150
# 1/1 [==============================] - 0s 299ms/step - loss: 0.0363 - mean_absolute_error: 0.1366 - val_loss: 0.0659 - val_mean_absolute_error: 0.2100
# Epoch 147/150
# 1/1 [==============================] - 0s 290ms/step - loss: 0.0260 - mean_absolute_error: 0.1192 - val_loss: 0.0713 - val_mean_absolute_error: 0.2148
# Epoch 148/150
# 1/1 [==============================] - 0s 318ms/step - loss: 0.0303 - mean_absolute_error: 0.1291 - val_loss: 0.0645 - val_mean_absolute_error: 0.2067
# Epoch 149/150
# 1/1 [==============================] - 0s 313ms/step - loss: 0.0311 - mean_absolute_error: 0.1293 - val_loss: 0.0620 - val_mean_absolute_error: 0.2022
# Epoch 150/150
# 1/1 [==============================] - 0s 328ms/step - loss: 0.0299 - mean_absolute_error: 0.1241 - val_loss: 0.0678 - val_mean_absolute_error: 0.2139
# 100/100 [==============================] - 10s 103ms/step - loss: 0.0673 - mean_absolute_error: 0.2131
# 100/100 [==============================] - 10s 98ms/step - loss: 0.0719 - mean_absolute_error: 0.2160
# val performance = [0.06733142584562302, 0.2131291776895523]
# test performance =  [0.07187250256538391, 0.21596965193748474]

# %%
plot_history(history)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
multi_window.plot2(elman_model, plot_col=out_features[0])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# **GRU**

# %%
gru_model = tf.keras.Sequential([
    # Take the last time step.
    # Shape [batch, time, features] => [batch, 1, features]
#     tf.keras.layers.GRU(128, return_sequences=True),
#     tf.keras.layers.GRU(128, return_sequences=True),
#     tf.keras.layers.GRU(128, return_sequences=True),
#     tf.keras.layers.GRU(128, return_sequences=True),
#     tf.keras.layers.GRU(128, return_sequences=True),
#     tf.keras.layers.GRU(128, return_sequences=True),
#     tf.keras.layers.GRU(128, return_sequences=True),
#     tf.keras.layers.GRU(128, return_sequences=True),
    tf.keras.layers.GRU(128, return_sequences=False),
    tf.keras.layers.Dense(OUT_STEPS*out_num_features,
                          kernel_initializer=tf.initializers.zeros),
    # Shape => [batch, out_steps, features]
    tf.keras.layers.Reshape([OUT_STEPS, out_num_features])
])

# %%
history = compile_and_fit(gru_model, multi_window)
multi_val_performance['GRU'] = gru_model.evaluate(multi_window.val.repeat(-1), steps=100)
multi_performance['GRU'] = gru_model.evaluate(multi_window.test.repeat(-1), verbose=1, steps=100)
print('val performance =', multi_val_performance['GRU'])
print('test performance = ', multi_performance['GRU'])
# Out:
# Epoch 1/150
# 1/1 [==============================] - 1s 969ms/step - loss: 0.6185 - mean_absolute_error: 0.6376 - val_loss: 0.3547 - val_mean_absolute_error: 0.5371
# Epoch 2/150
# 1/1 [==============================] - 0s 323ms/step - loss: 0.6379 - mean_absolute_error: 0.6458 - val_loss: 0.3511 - val_mean_absolute_error: 0.5368
# Epoch 3/150
# 1/1 [==============================] - 0s 330ms/step - loss: 0.6113 - mean_absolute_error: 0.6267 - val_loss: 0.3190 - val_mean_absolute_error: 0.5057
# Epoch 4/150
# 1/1 [==============================] - 0s 315ms/step - loss: 0.5698 - mean_absolute_error: 0.6018 - val_loss: 0.2951 - val_mean_absolute_error: 0.4816
# Epoch 5/150
# 1/1 [==============================] - 0s 325ms/step - loss: 0.5872 - mean_absolute_error: 0.5977 - val_loss: 0.2404 - val_mean_absolute_error: 0.4264
# Epoch 6/150
# 1/1 [==============================] - 0s 364ms/step - loss: 0.4942 - mean_absolute_error: 0.5560 - val_loss: 0.2294 - val_mean_absolute_error: 0.4135
# Epoch 7/150
# 1/1 [==============================] - 0s 329ms/step - loss: 0.4959 - mean_absolute_error: 0.5300 - val_loss: 0.1842 - val_mean_absolute_error: 0.3597
# Epoch 8/150
# 1/1 [==============================] - 0s 373ms/step - loss: 0.4351 - mean_absolute_error: 0.4950 - val_loss: 0.1738 - val_mean_absolute_error: 0.3551
# Epoch 9/150
# 1/1 [==============================] - 0s 307ms/step - loss: 0.4524 - mean_absolute_error: 0.4685 - val_loss: 0.1213 - val_mean_absolute_error: 0.2862
# Epoch 10/150
# 1/1 [==============================] - 0s 310ms/step - loss: 0.2987 - mean_absolute_error: 0.3735 - val_loss: 0.1054 - val_mean_absolute_error: 0.2684
# Epoch 11/150
# 1/1 [==============================] - 0s 305ms/step - loss: 0.2987 - mean_absolute_error: 0.3702 - val_loss: 0.0956 - val_mean_absolute_error: 0.2516
# Epoch 12/150
# 1/1 [==============================] - 0s 307ms/step - loss: 0.3375 - mean_absolute_error: 0.3809 - val_loss: 0.1063 - val_mean_absolute_error: 0.2650
# Epoch 13/150
# 1/1 [==============================] - 0s 324ms/step - loss: 0.2891 - mean_absolute_error: 0.3599 - val_loss: 0.1195 - val_mean_absolute_error: 0.2785
# Epoch 14/150
# 1/1 [==============================] - 0s 329ms/step - loss: 0.2170 - mean_absolute_error: 0.3314 - val_loss: 0.1555 - val_mean_absolute_error: 0.3145
# Epoch 15/150
# 1/1 [==============================] - 0s 325ms/step - loss: 0.2918 - mean_absolute_error: 0.3815 - val_loss: 0.1655 - val_mean_absolute_error: 0.3209
# Epoch 16/150
# 1/1 [==============================] - 0s 360ms/step - loss: 0.2380 - mean_absolute_error: 0.3582 - val_loss: 0.2043 - val_mean_absolute_error: 0.3640
# Epoch 17/150
# 1/1 [==============================] - 0s 339ms/step - loss: 0.2195 - mean_absolute_error: 0.3540 - val_loss: 0.2125 - val_mean_absolute_error: 0.3683
# Epoch 18/150
# 1/1 [==============================] - 0s 320ms/step - loss: 0.1837 - mean_absolute_error: 0.3208 - val_loss: 0.2310 - val_mean_absolute_error: 0.3835
# Epoch 19/150
# 1/1 [==============================] - 0s 352ms/step - loss: 0.2230 - mean_absolute_error: 0.3332 - val_loss: 0.2637 - val_mean_absolute_error: 0.4037
# Epoch 20/150
# 1/1 [==============================] - 0s 310ms/step - loss: 0.1802 - mean_absolute_error: 0.3105 - val_loss: 0.2766 - val_mean_absolute_error: 0.4129
# Epoch 21/150
# 1/1 [==============================] - 0s 304ms/step - loss: 0.1641 - mean_absolute_error: 0.2901 - val_loss: 0.3048 - val_mean_absolute_error: 0.4370
# Epoch 22/150
# 1/1 [==============================] - 0s 310ms/step - loss: 0.1594 - mean_absolute_error: 0.2924 - val_loss: 0.2973 - val_mean_absolute_error: 0.4275
# Epoch 23/150
# 1/1 [==============================] - 0s 378ms/step - loss: 0.1743 - mean_absolute_error: 0.3002 - val_loss: 0.2777 - val_mean_absolute_error: 0.4165
# Epoch 24/150
# 1/1 [==============================] - 0s 328ms/step - loss: 0.1750 - mean_absolute_error: 0.2935 - val_loss: 0.2306 - val_mean_absolute_error: 0.3855
# Epoch 25/150
# 1/1 [==============================] - 0s 349ms/step - loss: 0.1472 - mean_absolute_error: 0.2767 - val_loss: 0.2182 - val_mean_absolute_error: 0.3787
# Epoch 26/150
# 1/1 [==============================] - 0s 334ms/step - loss: 0.1189 - mean_absolute_error: 0.2527 - val_loss: 0.1788 - val_mean_absolute_error: 0.3473
# Epoch 27/150
# 1/1 [==============================] - 0s 330ms/step - loss: 0.1199 - mean_absolute_error: 0.2494 - val_loss: 0.1558 - val_mean_absolute_error: 0.3286
# Epoch 28/150
# 1/1 [==============================] - 0s 304ms/step - loss: 0.1301 - mean_absolute_error: 0.2612 - val_loss: 0.1348 - val_mean_absolute_error: 0.3077
# Epoch 29/150
# 1/1 [==============================] - 0s 349ms/step - loss: 0.1210 - mean_absolute_error: 0.2370 - val_loss: 0.1216 - val_mean_absolute_error: 0.2917
# Epoch 30/150
# 1/1 [==============================] - 0s 333ms/step - loss: 0.1400 - mean_absolute_error: 0.2471 - val_loss: 0.1112 - val_mean_absolute_error: 0.2790
# Epoch 31/150
# 1/1 [==============================] - 0s 315ms/step - loss: 0.1155 - mean_absolute_error: 0.2335 - val_loss: 0.1060 - val_mean_absolute_error: 0.2689
# Epoch 32/150
# 1/1 [==============================] - 0s 317ms/step - loss: 0.0995 - mean_absolute_error: 0.2147 - val_loss: 0.1034 - val_mean_absolute_error: 0.2625
# Epoch 33/150
# 1/1 [==============================] - 0s 321ms/step - loss: 0.1184 - mean_absolute_error: 0.2353 - val_loss: 0.0991 - val_mean_absolute_error: 0.2597
# Epoch 34/150
# 1/1 [==============================] - 0s 348ms/step - loss: 0.1090 - mean_absolute_error: 0.2229 - val_loss: 0.0867 - val_mean_absolute_error: 0.2422
# Epoch 35/150
# 1/1 [==============================] - 0s 299ms/step - loss: 0.0989 - mean_absolute_error: 0.2198 - val_loss: 0.0907 - val_mean_absolute_error: 0.2451
# Epoch 36/150
# 1/1 [==============================] - 0s 321ms/step - loss: 0.1163 - mean_absolute_error: 0.2187 - val_loss: 0.0903 - val_mean_absolute_error: 0.2450
# Epoch 37/150
# 1/1 [==============================] - 0s 351ms/step - loss: 0.0888 - mean_absolute_error: 0.2141 - val_loss: 0.0922 - val_mean_absolute_error: 0.2483
# Epoch 38/150
# 1/1 [==============================] - 0s 338ms/step - loss: 0.0905 - mean_absolute_error: 0.2086 - val_loss: 0.0904 - val_mean_absolute_error: 0.2492
# Epoch 39/150
# 1/1 [==============================] - 0s 309ms/step - loss: 0.0875 - mean_absolute_error: 0.2052 - val_loss: 0.0911 - val_mean_absolute_error: 0.2502
# Epoch 40/150
# 1/1 [==============================] - 0s 345ms/step - loss: 0.0971 - mean_absolute_error: 0.2102 - val_loss: 0.0863 - val_mean_absolute_error: 0.2435
# Epoch 41/150
# 1/1 [==============================] - 0s 373ms/step - loss: 0.1037 - mean_absolute_error: 0.2202 - val_loss: 0.0897 - val_mean_absolute_error: 0.2465
# Epoch 42/150
# 1/1 [==============================] - 0s 348ms/step - loss: 0.0827 - mean_absolute_error: 0.2072 - val_loss: 0.0847 - val_mean_absolute_error: 0.2400
# Epoch 43/150
# 1/1 [==============================] - 0s 326ms/step - loss: 0.0803 - mean_absolute_error: 0.2059 - val_loss: 0.0892 - val_mean_absolute_error: 0.2478
# Epoch 44/150
# 1/1 [==============================] - 0s 321ms/step - loss: 0.0797 - mean_absolute_error: 0.2041 - val_loss: 0.0831 - val_mean_absolute_error: 0.2406
# Epoch 45/150
# 1/1 [==============================] - 0s 320ms/step - loss: 0.1031 - mean_absolute_error: 0.2199 - val_loss: 0.0796 - val_mean_absolute_error: 0.2351
# Epoch 46/150
# 1/1 [==============================] - 0s 322ms/step - loss: 0.0961 - mean_absolute_error: 0.2082 - val_loss: 0.0905 - val_mean_absolute_error: 0.2484
# Epoch 47/150
# 1/1 [==============================] - 0s 322ms/step - loss: 0.0951 - mean_absolute_error: 0.2089 - val_loss: 0.0836 - val_mean_absolute_error: 0.2407
# Epoch 48/150
# 1/1 [==============================] - 0s 310ms/step - loss: 0.0960 - mean_absolute_error: 0.2094 - val_loss: 0.0861 - val_mean_absolute_error: 0.2432
# Epoch 49/150
# 1/1 [==============================] - 0s 320ms/step - loss: 0.0777 - mean_absolute_error: 0.1948 - val_loss: 0.0913 - val_mean_absolute_error: 0.2523
# Epoch 50/150
# 1/1 [==============================] - 0s 315ms/step - loss: 0.0954 - mean_absolute_error: 0.2092 - val_loss: 0.0845 - val_mean_absolute_error: 0.2388
# Epoch 51/150
# 1/1 [==============================] - 0s 354ms/step - loss: 0.0797 - mean_absolute_error: 0.1960 - val_loss: 0.0872 - val_mean_absolute_error: 0.2445
# Epoch 52/150
# 1/1 [==============================] - 0s 323ms/step - loss: 0.0685 - mean_absolute_error: 0.1898 - val_loss: 0.0819 - val_mean_absolute_error: 0.2381
# Epoch 53/150
# 1/1 [==============================] - 0s 342ms/step - loss: 0.0690 - mean_absolute_error: 0.1938 - val_loss: 0.0783 - val_mean_absolute_error: 0.2331
# Epoch 54/150
# 1/1 [==============================] - 0s 306ms/step - loss: 0.0803 - mean_absolute_error: 0.1926 - val_loss: 0.0840 - val_mean_absolute_error: 0.2405
# Epoch 55/150
# 1/1 [==============================] - 0s 350ms/step - loss: 0.0981 - mean_absolute_error: 0.2139 - val_loss: 0.0839 - val_mean_absolute_error: 0.2415
# Epoch 56/150
# 1/1 [==============================] - 0s 320ms/step - loss: 0.0677 - mean_absolute_error: 0.1912 - val_loss: 0.0810 - val_mean_absolute_error: 0.2352
# Epoch 57/150
# 1/1 [==============================] - 0s 319ms/step - loss: 0.0798 - mean_absolute_error: 0.1948 - val_loss: 0.0821 - val_mean_absolute_error: 0.2347
# Epoch 58/150
# 1/1 [==============================] - 0s 337ms/step - loss: 0.0722 - mean_absolute_error: 0.1893 - val_loss: 0.0783 - val_mean_absolute_error: 0.2331
# Epoch 59/150
# 1/1 [==============================] - 0s 329ms/step - loss: 0.0609 - mean_absolute_error: 0.1728 - val_loss: 0.0681 - val_mean_absolute_error: 0.2159
# Epoch 60/150
# 1/1 [==============================] - 0s 338ms/step - loss: 0.0650 - mean_absolute_error: 0.1851 - val_loss: 0.0710 - val_mean_absolute_error: 0.2201
# Epoch 61/150
# 1/1 [==============================] - 0s 296ms/step - loss: 0.0602 - mean_absolute_error: 0.1744 - val_loss: 0.0735 - val_mean_absolute_error: 0.2230
# Epoch 62/150
# 1/1 [==============================] - 0s 315ms/step - loss: 0.0643 - mean_absolute_error: 0.1798 - val_loss: 0.0747 - val_mean_absolute_error: 0.2244
# Epoch 63/150
# 1/1 [==============================] - 0s 299ms/step - loss: 0.0696 - mean_absolute_error: 0.1864 - val_loss: 0.0723 - val_mean_absolute_error: 0.2236
# Epoch 64/150
# 1/1 [==============================] - 0s 392ms/step - loss: 0.0624 - mean_absolute_error: 0.1799 - val_loss: 0.0746 - val_mean_absolute_error: 0.2270
# Epoch 65/150
# 1/1 [==============================] - 0s 308ms/step - loss: 0.0618 - mean_absolute_error: 0.1803 - val_loss: 0.0716 - val_mean_absolute_error: 0.2200
# Epoch 66/150
# 1/1 [==============================] - 0s 329ms/step - loss: 0.0655 - mean_absolute_error: 0.1790 - val_loss: 0.0742 - val_mean_absolute_error: 0.2232
# Epoch 67/150
# 1/1 [==============================] - 0s 330ms/step - loss: 0.0552 - mean_absolute_error: 0.1701 - val_loss: 0.0700 - val_mean_absolute_error: 0.2173
# Epoch 68/150
# 1/1 [==============================] - 0s 351ms/step - loss: 0.0600 - mean_absolute_error: 0.1761 - val_loss: 0.0717 - val_mean_absolute_error: 0.2214
# Epoch 69/150
# 1/1 [==============================] - 0s 347ms/step - loss: 0.0706 - mean_absolute_error: 0.1848 - val_loss: 0.0678 - val_mean_absolute_error: 0.2167
# Epoch 70/150
# 1/1 [==============================] - 0s 304ms/step - loss: 0.0661 - mean_absolute_error: 0.1854 - val_loss: 0.0676 - val_mean_absolute_error: 0.2173
# Epoch 71/150
# 1/1 [==============================] - 0s 297ms/step - loss: 0.0629 - mean_absolute_error: 0.1823 - val_loss: 0.0751 - val_mean_absolute_error: 0.2264
# Epoch 72/150
# 1/1 [==============================] - 0s 323ms/step - loss: 0.0499 - mean_absolute_error: 0.1675 - val_loss: 0.0698 - val_mean_absolute_error: 0.2176
# Epoch 73/150
# 1/1 [==============================] - 0s 365ms/step - loss: 0.0561 - mean_absolute_error: 0.1722 - val_loss: 0.0716 - val_mean_absolute_error: 0.2194
# Epoch 74/150
# 1/1 [==============================] - 0s 337ms/step - loss: 0.0681 - mean_absolute_error: 0.1796 - val_loss: 0.0719 - val_mean_absolute_error: 0.2204
# Epoch 75/150
# 1/1 [==============================] - 0s 317ms/step - loss: 0.0512 - mean_absolute_error: 0.1659 - val_loss: 0.0719 - val_mean_absolute_error: 0.2186
# Epoch 76/150
# 1/1 [==============================] - 0s 343ms/step - loss: 0.0602 - mean_absolute_error: 0.1769 - val_loss: 0.0713 - val_mean_absolute_error: 0.2167
# Epoch 77/150
# 1/1 [==============================] - 0s 341ms/step - loss: 0.0484 - mean_absolute_error: 0.1608 - val_loss: 0.0702 - val_mean_absolute_error: 0.2198
# Epoch 78/150
# 1/1 [==============================] - 0s 335ms/step - loss: 0.0487 - mean_absolute_error: 0.1617 - val_loss: 0.0631 - val_mean_absolute_error: 0.2104
# Epoch 79/150
# 1/1 [==============================] - 0s 325ms/step - loss: 0.0580 - mean_absolute_error: 0.1732 - val_loss: 0.0696 - val_mean_absolute_error: 0.2167
# Epoch 80/150
# 1/1 [==============================] - 0s 327ms/step - loss: 0.0620 - mean_absolute_error: 0.1770 - val_loss: 0.0702 - val_mean_absolute_error: 0.2212
# Epoch 81/150
# 1/1 [==============================] - 0s 330ms/step - loss: 0.0500 - mean_absolute_error: 0.1630 - val_loss: 0.0673 - val_mean_absolute_error: 0.2147
# Epoch 82/150
# 1/1 [==============================] - 0s 337ms/step - loss: 0.0490 - mean_absolute_error: 0.1647 - val_loss: 0.0703 - val_mean_absolute_error: 0.2204
# Epoch 83/150
# 1/1 [==============================] - 0s 319ms/step - loss: 0.0507 - mean_absolute_error: 0.1625 - val_loss: 0.0665 - val_mean_absolute_error: 0.2155
# Epoch 84/150
# 1/1 [==============================] - 0s 315ms/step - loss: 0.0490 - mean_absolute_error: 0.1612 - val_loss: 0.0619 - val_mean_absolute_error: 0.2087
# Epoch 85/150
# 1/1 [==============================] - 0s 334ms/step - loss: 0.0487 - mean_absolute_error: 0.1621 - val_loss: 0.0619 - val_mean_absolute_error: 0.2077
# Epoch 86/150
# 1/1 [==============================] - 0s 315ms/step - loss: 0.0508 - mean_absolute_error: 0.1630 - val_loss: 0.0682 - val_mean_absolute_error: 0.2158
# Epoch 87/150
# 1/1 [==============================] - 0s 344ms/step - loss: 0.0579 - mean_absolute_error: 0.1685 - val_loss: 0.0682 - val_mean_absolute_error: 0.2169
# Epoch 88/150
# 1/1 [==============================] - 0s 356ms/step - loss: 0.0475 - mean_absolute_error: 0.1610 - val_loss: 0.0697 - val_mean_absolute_error: 0.2206
# Epoch 89/150
# 1/1 [==============================] - 0s 343ms/step - loss: 0.0442 - mean_absolute_error: 0.1564 - val_loss: 0.0700 - val_mean_absolute_error: 0.2222
# Epoch 90/150
# 1/1 [==============================] - 0s 327ms/step - loss: 0.0441 - mean_absolute_error: 0.1555 - val_loss: 0.0676 - val_mean_absolute_error: 0.2150
# Epoch 91/150
# 1/1 [==============================] - 0s 339ms/step - loss: 0.0449 - mean_absolute_error: 0.1592 - val_loss: 0.0704 - val_mean_absolute_error: 0.2202
# Epoch 92/150
# 1/1 [==============================] - 0s 329ms/step - loss: 0.0520 - mean_absolute_error: 0.1641 - val_loss: 0.0683 - val_mean_absolute_error: 0.2162
# Epoch 93/150
# 1/1 [==============================] - 0s 386ms/step - loss: 0.0628 - mean_absolute_error: 0.1691 - val_loss: 0.0681 - val_mean_absolute_error: 0.2177
# Epoch 94/150
# 1/1 [==============================] - 0s 374ms/step - loss: 0.0421 - mean_absolute_error: 0.1513 - val_loss: 0.0643 - val_mean_absolute_error: 0.2137
# Epoch 95/150
# 1/1 [==============================] - 0s 318ms/step - loss: 0.0432 - mean_absolute_error: 0.1552 - val_loss: 0.0645 - val_mean_absolute_error: 0.2150
# Epoch 96/150
# 1/1 [==============================] - 0s 344ms/step - loss: 0.0423 - mean_absolute_error: 0.1538 - val_loss: 0.0669 - val_mean_absolute_error: 0.2166
# Epoch 97/150
# 1/1 [==============================] - 0s 314ms/step - loss: 0.0393 - mean_absolute_error: 0.1491 - val_loss: 0.0664 - val_mean_absolute_error: 0.2124
# Epoch 98/150
# 1/1 [==============================] - 0s 342ms/step - loss: 0.0464 - mean_absolute_error: 0.1598 - val_loss: 0.0632 - val_mean_absolute_error: 0.2071
# Epoch 99/150
# 1/1 [==============================] - 0s 373ms/step - loss: 0.0464 - mean_absolute_error: 0.1561 - val_loss: 0.0668 - val_mean_absolute_error: 0.2146
# Epoch 100/150
# 1/1 [==============================] - 0s 306ms/step - loss: 0.0440 - mean_absolute_error: 0.1550 - val_loss: 0.0671 - val_mean_absolute_error: 0.2127
# Epoch 101/150
# 1/1 [==============================] - 0s 333ms/step - loss: 0.0411 - mean_absolute_error: 0.1501 - val_loss: 0.0656 - val_mean_absolute_error: 0.2099
# Epoch 102/150
# 1/1 [==============================] - 0s 350ms/step - loss: 0.0449 - mean_absolute_error: 0.1536 - val_loss: 0.0647 - val_mean_absolute_error: 0.2118
# Epoch 103/150
# 1/1 [==============================] - 0s 361ms/step - loss: 0.0440 - mean_absolute_error: 0.1572 - val_loss: 0.0638 - val_mean_absolute_error: 0.2116
# Epoch 104/150
# 1/1 [==============================] - 0s 335ms/step - loss: 0.0418 - mean_absolute_error: 0.1482 - val_loss: 0.0664 - val_mean_absolute_error: 0.2135
# Epoch 105/150
# 1/1 [==============================] - 0s 373ms/step - loss: 0.0431 - mean_absolute_error: 0.1553 - val_loss: 0.0670 - val_mean_absolute_error: 0.2173
# Epoch 106/150
# 1/1 [==============================] - 0s 349ms/step - loss: 0.0487 - mean_absolute_error: 0.1573 - val_loss: 0.0659 - val_mean_absolute_error: 0.2135
# Epoch 107/150
# 1/1 [==============================] - 0s 343ms/step - loss: 0.0489 - mean_absolute_error: 0.1568 - val_loss: 0.0701 - val_mean_absolute_error: 0.2211
# Epoch 108/150
# 1/1 [==============================] - 0s 339ms/step - loss: 0.0437 - mean_absolute_error: 0.1545 - val_loss: 0.0664 - val_mean_absolute_error: 0.2157
# Epoch 109/150
# 1/1 [==============================] - 0s 344ms/step - loss: 0.0461 - mean_absolute_error: 0.1542 - val_loss: 0.0618 - val_mean_absolute_error: 0.2086
# Epoch 110/150
# 1/1 [==============================] - 0s 346ms/step - loss: 0.0446 - mean_absolute_error: 0.1547 - val_loss: 0.0589 - val_mean_absolute_error: 0.2030
# Epoch 111/150
# 1/1 [==============================] - 0s 316ms/step - loss: 0.0433 - mean_absolute_error: 0.1537 - val_loss: 0.0632 - val_mean_absolute_error: 0.2095
# Epoch 112/150
# 1/1 [==============================] - 0s 309ms/step - loss: 0.0390 - mean_absolute_error: 0.1472 - val_loss: 0.0625 - val_mean_absolute_error: 0.2095
# Epoch 113/150
# 1/1 [==============================] - 0s 345ms/step - loss: 0.0377 - mean_absolute_error: 0.1419 - val_loss: 0.0657 - val_mean_absolute_error: 0.2167
# Epoch 114/150
# 1/1 [==============================] - 0s 373ms/step - loss: 0.0383 - mean_absolute_error: 0.1447 - val_loss: 0.0669 - val_mean_absolute_error: 0.2180
# Epoch 115/150
# 1/1 [==============================] - 0s 336ms/step - loss: 0.0367 - mean_absolute_error: 0.1429 - val_loss: 0.0630 - val_mean_absolute_error: 0.2088
# Epoch 116/150
# 1/1 [==============================] - 0s 310ms/step - loss: 0.0406 - mean_absolute_error: 0.1472 - val_loss: 0.0681 - val_mean_absolute_error: 0.2187
# Epoch 117/150
# 1/1 [==============================] - 0s 408ms/step - loss: 0.0448 - mean_absolute_error: 0.1516 - val_loss: 0.0645 - val_mean_absolute_error: 0.2088
# Epoch 118/150
# 1/1 [==============================] - 0s 313ms/step - loss: 0.0424 - mean_absolute_error: 0.1523 - val_loss: 0.0623 - val_mean_absolute_error: 0.2068
# Epoch 119/150
# 1/1 [==============================] - 0s 364ms/step - loss: 0.0328 - mean_absolute_error: 0.1368 - val_loss: 0.0631 - val_mean_absolute_error: 0.2089
# Epoch 120/150
# 1/1 [==============================] - 0s 344ms/step - loss: 0.0365 - mean_absolute_error: 0.1404 - val_loss: 0.0639 - val_mean_absolute_error: 0.2123
# Epoch 121/150
# 1/1 [==============================] - 0s 321ms/step - loss: 0.0367 - mean_absolute_error: 0.1431 - val_loss: 0.0644 - val_mean_absolute_error: 0.2110
# Epoch 122/150
# 1/1 [==============================] - 0s 357ms/step - loss: 0.0377 - mean_absolute_error: 0.1426 - val_loss: 0.0635 - val_mean_absolute_error: 0.2089
# Epoch 123/150
# 1/1 [==============================] - 0s 315ms/step - loss: 0.0383 - mean_absolute_error: 0.1455 - val_loss: 0.0588 - val_mean_absolute_error: 0.1999
# Epoch 124/150
# 1/1 [==============================] - 0s 332ms/step - loss: 0.0431 - mean_absolute_error: 0.1520 - val_loss: 0.0669 - val_mean_absolute_error: 0.2159
# Epoch 125/150
# 1/1 [==============================] - 0s 357ms/step - loss: 0.0390 - mean_absolute_error: 0.1472 - val_loss: 0.0656 - val_mean_absolute_error: 0.2137
# Epoch 126/150
# 1/1 [==============================] - 0s 357ms/step - loss: 0.0373 - mean_absolute_error: 0.1444 - val_loss: 0.0654 - val_mean_absolute_error: 0.2117
# Epoch 127/150
# 1/1 [==============================] - 0s 296ms/step - loss: 0.0365 - mean_absolute_error: 0.1402 - val_loss: 0.0605 - val_mean_absolute_error: 0.2074
# Epoch 128/150
# 1/1 [==============================] - 0s 388ms/step - loss: 0.0328 - mean_absolute_error: 0.1347 - val_loss: 0.0630 - val_mean_absolute_error: 0.2125
# Epoch 129/150
# 1/1 [==============================] - 0s 347ms/step - loss: 0.0340 - mean_absolute_error: 0.1373 - val_loss: 0.0627 - val_mean_absolute_error: 0.2096
# Epoch 130/150
# 1/1 [==============================] - 0s 353ms/step - loss: 0.0414 - mean_absolute_error: 0.1462 - val_loss: 0.0627 - val_mean_absolute_error: 0.2095
# Epoch 131/150
# 1/1 [==============================] - 0s 336ms/step - loss: 0.0338 - mean_absolute_error: 0.1374 - val_loss: 0.0624 - val_mean_absolute_error: 0.2090
# Epoch 132/150
# 1/1 [==============================] - 0s 321ms/step - loss: 0.0413 - mean_absolute_error: 0.1481 - val_loss: 0.0675 - val_mean_absolute_error: 0.2165
# Epoch 133/150
# 1/1 [==============================] - 0s 345ms/step - loss: 0.0382 - mean_absolute_error: 0.1457 - val_loss: 0.0645 - val_mean_absolute_error: 0.2115
# Epoch 134/150
# 1/1 [==============================] - 0s 332ms/step - loss: 0.0379 - mean_absolute_error: 0.1433 - val_loss: 0.0603 - val_mean_absolute_error: 0.2059
# Epoch 135/150
# 1/1 [==============================] - 0s 327ms/step - loss: 0.0360 - mean_absolute_error: 0.1389 - val_loss: 0.0610 - val_mean_absolute_error: 0.2048
# Epoch 136/150
# 1/1 [==============================] - 0s 310ms/step - loss: 0.0366 - mean_absolute_error: 0.1386 - val_loss: 0.0617 - val_mean_absolute_error: 0.2063
# Epoch 137/150
# 1/1 [==============================] - 0s 349ms/step - loss: 0.0387 - mean_absolute_error: 0.1441 - val_loss: 0.0632 - val_mean_absolute_error: 0.2103
# Epoch 138/150
# 1/1 [==============================] - 0s 330ms/step - loss: 0.0336 - mean_absolute_error: 0.1368 - val_loss: 0.0685 - val_mean_absolute_error: 0.2193
# Epoch 139/150
# 1/1 [==============================] - 0s 342ms/step - loss: 0.0293 - mean_absolute_error: 0.1295 - val_loss: 0.0642 - val_mean_absolute_error: 0.2124
# Epoch 140/150
# 1/1 [==============================] - 0s 323ms/step - loss: 0.0347 - mean_absolute_error: 0.1392 - val_loss: 0.0616 - val_mean_absolute_error: 0.2062
# Epoch 141/150
# 1/1 [==============================] - 0s 320ms/step - loss: 0.0367 - mean_absolute_error: 0.1443 - val_loss: 0.0702 - val_mean_absolute_error: 0.2211
# Epoch 142/150
# 1/1 [==============================] - 0s 360ms/step - loss: 0.0330 - mean_absolute_error: 0.1364 - val_loss: 0.0621 - val_mean_absolute_error: 0.2054
# Epoch 143/150
# 1/1 [==============================] - 0s 363ms/step - loss: 0.0333 - mean_absolute_error: 0.1381 - val_loss: 0.0610 - val_mean_absolute_error: 0.2052
# Epoch 144/150
# 1/1 [==============================] - 0s 349ms/step - loss: 0.0314 - mean_absolute_error: 0.1334 - val_loss: 0.0625 - val_mean_absolute_error: 0.2102
# Epoch 145/150
# 1/1 [==============================] - 0s 322ms/step - loss: 0.0341 - mean_absolute_error: 0.1394 - val_loss: 0.0629 - val_mean_absolute_error: 0.2125
# Epoch 146/150
# 1/1 [==============================] - 0s 326ms/step - loss: 0.0383 - mean_absolute_error: 0.1447 - val_loss: 0.0633 - val_mean_absolute_error: 0.2117
# Epoch 147/150
# 1/1 [==============================] - 0s 335ms/step - loss: 0.0312 - mean_absolute_error: 0.1315 - val_loss: 0.0609 - val_mean_absolute_error: 0.2055
# Epoch 148/150
# 1/1 [==============================] - 0s 351ms/step - loss: 0.0320 - mean_absolute_error: 0.1321 - val_loss: 0.0580 - val_mean_absolute_error: 0.2012
# Epoch 149/150
# 1/1 [==============================] - 0s 346ms/step - loss: 0.0332 - mean_absolute_error: 0.1350 - val_loss: 0.0637 - val_mean_absolute_error: 0.2109
# Epoch 150/150
# 1/1 [==============================] - 0s 338ms/step - loss: 0.0361 - mean_absolute_error: 0.1400 - val_loss: 0.0688 - val_mean_absolute_error: 0.2205
# 100/100 [==============================] - 11s 112ms/step - loss: 0.0634 - mean_absolute_error: 0.2113
# 100/100 [==============================] - 11s 108ms/step - loss: 0.0617 - mean_absolute_error: 0.1990
# val performance = [0.06336439400911331, 0.21130143105983734]
# test performance =  [0.06173459067940712, 0.19899243116378784]

# %% [markdown]
# **LSTM**

# %%
multi_lstm_model = tf.keras.Sequential([
    # Shape [batch, time, features] => [batch, lstm_units]
    # Adding more `lstm_units` just overfits more quickly.
    #tf.keras.layers.LSTM(32, return_sequences=False),
#     tf.keras.layers.LSTM(128, return_sequences=True),
#     tf.keras.layers.LSTM(128, return_sequences=True),
#     tf.keras.layers.LSTM(128, return_sequences=True),
#     tf.keras.layers.LSTM(128, return_sequences=True),
#     tf.keras.layers.LSTM(128, return_sequences=True),
#     tf.keras.layers.LSTM(128, return_sequences=True),
#     tf.keras.layers.LSTM(128, return_sequences=True),
#     tf.keras.layers.LSTM(128, return_sequences=True),
#     tf.keras.layers.LSTM(128, return_sequences=True),
#     tf.keras.layers.LSTM(128, return_sequences=True),
    tf.keras.layers.LSTM(128, return_sequences=False),
    # Shape => [batch, out_steps*features]
    tf.keras.layers.Dense(OUT_STEPS*out_num_features,
                          kernel_initializer=tf.initializers.zeros),
    # Shape => [batch, out_steps, features]
    tf.keras.layers.Reshape([OUT_STEPS, out_num_features])
])

# %%
history = compile_and_fit(multi_lstm_model, multi_window)

#IPython.display.clear_output()

multi_val_performance['LSTM'] = multi_lstm_model.evaluate(multi_window.val)
multi_performance['LSTM'] = multi_lstm_model.evaluate(multi_window.test, verbose=0)
print('val performance =', multi_val_performance['LSTM'])
print('test performance = ', multi_performance['LSTM'])
# Out:
# Epoch 1/150
# 1/1 [==============================] - 3s 3s/step - loss: 0.6542 - mean_absolute_error: 0.6653 - val_loss: 0.3632 - val_mean_absolute_error: 0.5461
# Epoch 2/150
# 1/1 [==============================] - 0s 239ms/step - loss: 0.6260 - mean_absolute_error: 0.6509 - val_loss: 0.3307 - val_mean_absolute_error: 0.5158
# Epoch 3/150
# 1/1 [==============================] - 0s 275ms/step - loss: 0.5957 - mean_absolute_error: 0.6288 - val_loss: 0.3312 - val_mean_absolute_error: 0.5171
# Epoch 4/150
# 1/1 [==============================] - 0s 254ms/step - loss: 0.5899 - mean_absolute_error: 0.6143 - val_loss: 0.2810 - val_mean_absolute_error: 0.4630
# Epoch 5/150
# 1/1 [==============================] - 0s 263ms/step - loss: 0.6064 - mean_absolute_error: 0.6013 - val_loss: 0.2461 - val_mean_absolute_error: 0.4338
# Epoch 6/150
# 1/1 [==============================] - 0s 258ms/step - loss: 0.5149 - mean_absolute_error: 0.5727 - val_loss: 0.2154 - val_mean_absolute_error: 0.3984
# Epoch 7/150
# 1/1 [==============================] - 0s 242ms/step - loss: 0.5443 - mean_absolute_error: 0.5483 - val_loss: 0.1598 - val_mean_absolute_error: 0.3343
# Epoch 8/150
# 1/1 [==============================] - 0s 271ms/step - loss: 0.4489 - mean_absolute_error: 0.4898 - val_loss: 0.1508 - val_mean_absolute_error: 0.3272
# Epoch 9/150
# 1/1 [==============================] - 0s 278ms/step - loss: 0.3554 - mean_absolute_error: 0.4226 - val_loss: 0.1124 - val_mean_absolute_error: 0.2780
# Epoch 10/150
# 1/1 [==============================] - 0s 257ms/step - loss: 0.3845 - mean_absolute_error: 0.4146 - val_loss: 0.0963 - val_mean_absolute_error: 0.2551
# Epoch 11/150
# 1/1 [==============================] - 0s 246ms/step - loss: 0.2160 - mean_absolute_error: 0.3129 - val_loss: 0.1012 - val_mean_absolute_error: 0.2604
# Epoch 12/150
# 1/1 [==============================] - 0s 254ms/step - loss: 0.2645 - mean_absolute_error: 0.3258 - val_loss: 0.1144 - val_mean_absolute_error: 0.2772
# Epoch 13/150
# 1/1 [==============================] - 0s 283ms/step - loss: 0.3214 - mean_absolute_error: 0.3719 - val_loss: 0.1361 - val_mean_absolute_error: 0.2960
# Epoch 14/150
# 1/1 [==============================] - 0s 242ms/step - loss: 0.2619 - mean_absolute_error: 0.3538 - val_loss: 0.1480 - val_mean_absolute_error: 0.3055
# Epoch 15/150
# 1/1 [==============================] - 0s 282ms/step - loss: 0.2760 - mean_absolute_error: 0.3646 - val_loss: 0.1782 - val_mean_absolute_error: 0.3305
# Epoch 16/150
# 1/1 [==============================] - 0s 267ms/step - loss: 0.2600 - mean_absolute_error: 0.3557 - val_loss: 0.1889 - val_mean_absolute_error: 0.3414
# Epoch 17/150
# 1/1 [==============================] - 0s 252ms/step - loss: 0.2172 - mean_absolute_error: 0.3374 - val_loss: 0.2086 - val_mean_absolute_error: 0.3568
# Epoch 18/150
# 1/1 [==============================] - 0s 259ms/step - loss: 0.2075 - mean_absolute_error: 0.3302 - val_loss: 0.2181 - val_mean_absolute_error: 0.3721
# Epoch 19/150
# 1/1 [==============================] - 0s 277ms/step - loss: 0.1789 - mean_absolute_error: 0.3034 - val_loss: 0.2111 - val_mean_absolute_error: 0.3728
# Epoch 20/150
# 1/1 [==============================] - 0s 291ms/step - loss: 0.1663 - mean_absolute_error: 0.2953 - val_loss: 0.2059 - val_mean_absolute_error: 0.3712
# Epoch 21/150
# 1/1 [==============================] - 0s 267ms/step - loss: 0.1704 - mean_absolute_error: 0.2826 - val_loss: 0.2094 - val_mean_absolute_error: 0.3770
# Epoch 22/150
# 1/1 [==============================] - 0s 255ms/step - loss: 0.1481 - mean_absolute_error: 0.2775 - val_loss: 0.2074 - val_mean_absolute_error: 0.3755
# Epoch 23/150
# 1/1 [==============================] - 0s 251ms/step - loss: 0.1414 - mean_absolute_error: 0.2781 - val_loss: 0.1769 - val_mean_absolute_error: 0.3521
# Epoch 24/150
# 1/1 [==============================] - 0s 269ms/step - loss: 0.1467 - mean_absolute_error: 0.2717 - val_loss: 0.1614 - val_mean_absolute_error: 0.3377
# Epoch 25/150
# 1/1 [==============================] - 0s 253ms/step - loss: 0.1280 - mean_absolute_error: 0.2672 - val_loss: 0.1596 - val_mean_absolute_error: 0.3366
# Epoch 26/150
# 1/1 [==============================] - 0s 272ms/step - loss: 0.1193 - mean_absolute_error: 0.2541 - val_loss: 0.1451 - val_mean_absolute_error: 0.3242
# Epoch 27/150
# 1/1 [==============================] - 0s 255ms/step - loss: 0.1099 - mean_absolute_error: 0.2486 - val_loss: 0.1328 - val_mean_absolute_error: 0.3061
# Epoch 28/150
# 1/1 [==============================] - 0s 291ms/step - loss: 0.1183 - mean_absolute_error: 0.2493 - val_loss: 0.1318 - val_mean_absolute_error: 0.3020
# Epoch 29/150
# 1/1 [==============================] - 0s 253ms/step - loss: 0.1263 - mean_absolute_error: 0.2487 - val_loss: 0.1290 - val_mean_absolute_error: 0.2969
# Epoch 30/150
# 1/1 [==============================] - 0s 264ms/step - loss: 0.1318 - mean_absolute_error: 0.2507 - val_loss: 0.1081 - val_mean_absolute_error: 0.2696
# Epoch 31/150
# 1/1 [==============================] - 0s 278ms/step - loss: 0.1482 - mean_absolute_error: 0.2486 - val_loss: 0.1054 - val_mean_absolute_error: 0.2666
# Epoch 32/150
# 1/1 [==============================] - 0s 245ms/step - loss: 0.1110 - mean_absolute_error: 0.2329 - val_loss: 0.0990 - val_mean_absolute_error: 0.2552
# Epoch 33/150
# 1/1 [==============================] - 0s 257ms/step - loss: 0.0992 - mean_absolute_error: 0.2304 - val_loss: 0.0888 - val_mean_absolute_error: 0.2443
# Epoch 34/150
# 1/1 [==============================] - 0s 267ms/step - loss: 0.1111 - mean_absolute_error: 0.2269 - val_loss: 0.0837 - val_mean_absolute_error: 0.2352
# Epoch 35/150
# 1/1 [==============================] - 0s 279ms/step - loss: 0.1447 - mean_absolute_error: 0.2374 - val_loss: 0.0841 - val_mean_absolute_error: 0.2355
# Epoch 36/150
# 1/1 [==============================] - 0s 257ms/step - loss: 0.1054 - mean_absolute_error: 0.2197 - val_loss: 0.0830 - val_mean_absolute_error: 0.2304
# Epoch 37/150
# 1/1 [==============================] - 0s 249ms/step - loss: 0.0997 - mean_absolute_error: 0.2220 - val_loss: 0.0798 - val_mean_absolute_error: 0.2277
# Epoch 38/150
# 1/1 [==============================] - 0s 287ms/step - loss: 0.1210 - mean_absolute_error: 0.2346 - val_loss: 0.0866 - val_mean_absolute_error: 0.2319
# Epoch 39/150
# 1/1 [==============================] - 0s 239ms/step - loss: 0.0984 - mean_absolute_error: 0.2236 - val_loss: 0.0778 - val_mean_absolute_error: 0.2189
# Epoch 40/150
# 1/1 [==============================] - 0s 257ms/step - loss: 0.1173 - mean_absolute_error: 0.2239 - val_loss: 0.0855 - val_mean_absolute_error: 0.2310
# Epoch 41/150
# 1/1 [==============================] - 0s 254ms/step - loss: 0.1177 - mean_absolute_error: 0.2343 - val_loss: 0.0976 - val_mean_absolute_error: 0.2496
# Epoch 42/150
# 1/1 [==============================] - 0s 287ms/step - loss: 0.0897 - mean_absolute_error: 0.2133 - val_loss: 0.0983 - val_mean_absolute_error: 0.2508
# Epoch 43/150
# 1/1 [==============================] - 0s 237ms/step - loss: 0.0894 - mean_absolute_error: 0.2126 - val_loss: 0.0993 - val_mean_absolute_error: 0.2531
# Epoch 44/150
# 1/1 [==============================] - 0s 254ms/step - loss: 0.0783 - mean_absolute_error: 0.1998 - val_loss: 0.0966 - val_mean_absolute_error: 0.2514
# Epoch 45/150
# 1/1 [==============================] - 0s 269ms/step - loss: 0.0761 - mean_absolute_error: 0.1977 - val_loss: 0.0949 - val_mean_absolute_error: 0.2501
# Epoch 46/150
# 1/1 [==============================] - 0s 233ms/step - loss: 0.0774 - mean_absolute_error: 0.2047 - val_loss: 0.1115 - val_mean_absolute_error: 0.2751
# Epoch 47/150
# 1/1 [==============================] - 0s 262ms/step - loss: 0.0862 - mean_absolute_error: 0.2016 - val_loss: 0.1125 - val_mean_absolute_error: 0.2739
# Epoch 48/150
# 1/1 [==============================] - 0s 266ms/step - loss: 0.0828 - mean_absolute_error: 0.1975 - val_loss: 0.1044 - val_mean_absolute_error: 0.2691
# Epoch 49/150
# 1/1 [==============================] - 0s 259ms/step - loss: 0.0667 - mean_absolute_error: 0.1911 - val_loss: 0.1066 - val_mean_absolute_error: 0.2708
# Epoch 50/150
# 1/1 [==============================] - 0s 282ms/step - loss: 0.0683 - mean_absolute_error: 0.1890 - val_loss: 0.1064 - val_mean_absolute_error: 0.2704
# Epoch 51/150
# 1/1 [==============================] - 0s 248ms/step - loss: 0.0842 - mean_absolute_error: 0.2055 - val_loss: 0.0994 - val_mean_absolute_error: 0.2619
# Epoch 52/150
# 1/1 [==============================] - 0s 276ms/step - loss: 0.0830 - mean_absolute_error: 0.1993 - val_loss: 0.1082 - val_mean_absolute_error: 0.2701
# Epoch 53/150
# 1/1 [==============================] - 0s 247ms/step - loss: 0.0716 - mean_absolute_error: 0.1987 - val_loss: 0.0988 - val_mean_absolute_error: 0.2595
# Epoch 54/150
# 1/1 [==============================] - 0s 270ms/step - loss: 0.0767 - mean_absolute_error: 0.2029 - val_loss: 0.1145 - val_mean_absolute_error: 0.2717
# Epoch 55/150
# 1/1 [==============================] - 0s 243ms/step - loss: 0.0781 - mean_absolute_error: 0.1989 - val_loss: 0.0969 - val_mean_absolute_error: 0.2527
# Epoch 56/150
# 1/1 [==============================] - 0s 252ms/step - loss: 0.0767 - mean_absolute_error: 0.1991 - val_loss: 0.0983 - val_mean_absolute_error: 0.2548
# Epoch 57/150
# 1/1 [==============================] - 0s 251ms/step - loss: 0.0697 - mean_absolute_error: 0.1953 - val_loss: 0.1052 - val_mean_absolute_error: 0.2611
# Epoch 58/150
# 1/1 [==============================] - 0s 216ms/step - loss: 0.0615 - mean_absolute_error: 0.1811 - val_loss: 0.0955 - val_mean_absolute_error: 0.2523
# Epoch 59/150
# 1/1 [==============================] - 0s 256ms/step - loss: 0.0604 - mean_absolute_error: 0.1838 - val_loss: 0.1001 - val_mean_absolute_error: 0.2544
# Epoch 60/150
# 1/1 [==============================] - 0s 255ms/step - loss: 0.0734 - mean_absolute_error: 0.1886 - val_loss: 0.0968 - val_mean_absolute_error: 0.2563
# Epoch 61/150
# 1/1 [==============================] - 0s 261ms/step - loss: 0.0544 - mean_absolute_error: 0.1735 - val_loss: 0.0990 - val_mean_absolute_error: 0.2515
# Epoch 62/150
# 1/1 [==============================] - 0s 267ms/step - loss: 0.0788 - mean_absolute_error: 0.2037 - val_loss: 0.0920 - val_mean_absolute_error: 0.2482
# Epoch 63/150
# 1/1 [==============================] - 0s 274ms/step - loss: 0.0672 - mean_absolute_error: 0.1858 - val_loss: 0.1009 - val_mean_absolute_error: 0.2587
# Epoch 64/150
# 1/1 [==============================] - 0s 234ms/step - loss: 0.0717 - mean_absolute_error: 0.1870 - val_loss: 0.0925 - val_mean_absolute_error: 0.2451
# Epoch 65/150
# 1/1 [==============================] - 0s 248ms/step - loss: 0.0631 - mean_absolute_error: 0.1856 - val_loss: 0.1007 - val_mean_absolute_error: 0.2560
# Epoch 66/150
# 1/1 [==============================] - 0s 272ms/step - loss: 0.0632 - mean_absolute_error: 0.1795 - val_loss: 0.1051 - val_mean_absolute_error: 0.2632
# Epoch 67/150
# 1/1 [==============================] - 0s 237ms/step - loss: 0.0559 - mean_absolute_error: 0.1732 - val_loss: 0.1024 - val_mean_absolute_error: 0.2611
# Epoch 68/150
# 1/1 [==============================] - 0s 291ms/step - loss: 0.0536 - mean_absolute_error: 0.1715 - val_loss: 0.1033 - val_mean_absolute_error: 0.2583
# Epoch 69/150
# 1/1 [==============================] - 0s 254ms/step - loss: 0.0678 - mean_absolute_error: 0.1850 - val_loss: 0.0988 - val_mean_absolute_error: 0.2558
# Epoch 70/150
# 1/1 [==============================] - 0s 292ms/step - loss: 0.0619 - mean_absolute_error: 0.1748 - val_loss: 0.0970 - val_mean_absolute_error: 0.2539
# Epoch 71/150
# 1/1 [==============================] - 0s 259ms/step - loss: 0.0537 - mean_absolute_error: 0.1735 - val_loss: 0.1049 - val_mean_absolute_error: 0.2627
# Epoch 72/150
# 1/1 [==============================] - 0s 268ms/step - loss: 0.0596 - mean_absolute_error: 0.1738 - val_loss: 0.1094 - val_mean_absolute_error: 0.2659
# Epoch 73/150
# 1/1 [==============================] - 0s 241ms/step - loss: 0.0571 - mean_absolute_error: 0.1711 - val_loss: 0.1023 - val_mean_absolute_error: 0.2576
# Epoch 74/150
# 1/1 [==============================] - 0s 269ms/step - loss: 0.0543 - mean_absolute_error: 0.1735 - val_loss: 0.0954 - val_mean_absolute_error: 0.2532
# Epoch 75/150
# 1/1 [==============================] - 0s 278ms/step - loss: 0.0547 - mean_absolute_error: 0.1686 - val_loss: 0.1002 - val_mean_absolute_error: 0.2590
# Epoch 76/150
# 1/1 [==============================] - 0s 236ms/step - loss: 0.0563 - mean_absolute_error: 0.1719 - val_loss: 0.0990 - val_mean_absolute_error: 0.2571
# Epoch 77/150
# 1/1 [==============================] - 0s 243ms/step - loss: 0.0459 - mean_absolute_error: 0.1600 - val_loss: 0.1070 - val_mean_absolute_error: 0.2628
# Epoch 78/150
# 1/1 [==============================] - 0s 272ms/step - loss: 0.0629 - mean_absolute_error: 0.1753 - val_loss: 0.0953 - val_mean_absolute_error: 0.2522
# Epoch 79/150
# 1/1 [==============================] - 0s 273ms/step - loss: 0.0500 - mean_absolute_error: 0.1638 - val_loss: 0.1231 - val_mean_absolute_error: 0.2821
# Epoch 80/150
# 1/1 [==============================] - 0s 286ms/step - loss: 0.0477 - mean_absolute_error: 0.1631 - val_loss: 0.0982 - val_mean_absolute_error: 0.2544
# Epoch 81/150
# 1/1 [==============================] - 0s 285ms/step - loss: 0.0528 - mean_absolute_error: 0.1694 - val_loss: 0.1024 - val_mean_absolute_error: 0.2599
# Epoch 82/150
# 1/1 [==============================] - 0s 239ms/step - loss: 0.0530 - mean_absolute_error: 0.1682 - val_loss: 0.1141 - val_mean_absolute_error: 0.2746
# Epoch 83/150
# 1/1 [==============================] - 0s 259ms/step - loss: 0.0456 - mean_absolute_error: 0.1580 - val_loss: 0.1042 - val_mean_absolute_error: 0.2620
# Epoch 84/150
# 1/1 [==============================] - 0s 294ms/step - loss: 0.0475 - mean_absolute_error: 0.1599 - val_loss: 0.1017 - val_mean_absolute_error: 0.2580
# Epoch 85/150
# 1/1 [==============================] - 0s 274ms/step - loss: 0.0509 - mean_absolute_error: 0.1650 - val_loss: 0.1030 - val_mean_absolute_error: 0.2607
# Epoch 86/150
# 1/1 [==============================] - 0s 252ms/step - loss: 0.0520 - mean_absolute_error: 0.1643 - val_loss: 0.0968 - val_mean_absolute_error: 0.2476
# Epoch 87/150
# 1/1 [==============================] - 0s 274ms/step - loss: 0.0502 - mean_absolute_error: 0.1648 - val_loss: 0.0961 - val_mean_absolute_error: 0.2483
# Epoch 88/150
# 1/1 [==============================] - 0s 258ms/step - loss: 0.0446 - mean_absolute_error: 0.1561 - val_loss: 0.0971 - val_mean_absolute_error: 0.2497
# Epoch 89/150
# 1/1 [==============================] - 0s 270ms/step - loss: 0.0556 - mean_absolute_error: 0.1636 - val_loss: 0.0896 - val_mean_absolute_error: 0.2376
# Epoch 90/150
# 1/1 [==============================] - 0s 244ms/step - loss: 0.0490 - mean_absolute_error: 0.1627 - val_loss: 0.0964 - val_mean_absolute_error: 0.2460
# Epoch 91/150
# 1/1 [==============================] - 0s 290ms/step - loss: 0.0464 - mean_absolute_error: 0.1607 - val_loss: 0.1036 - val_mean_absolute_error: 0.2545
# Epoch 92/150
# 1/1 [==============================] - 0s 246ms/step - loss: 0.0450 - mean_absolute_error: 0.1562 - val_loss: 0.0980 - val_mean_absolute_error: 0.2550
# Epoch 93/150
# 1/1 [==============================] - 0s 279ms/step - loss: 0.0457 - mean_absolute_error: 0.1572 - val_loss: 0.1064 - val_mean_absolute_error: 0.2580
# Epoch 94/150
# 1/1 [==============================] - 0s 251ms/step - loss: 0.0439 - mean_absolute_error: 0.1528 - val_loss: 0.1014 - val_mean_absolute_error: 0.2560
# Epoch 95/150
# 1/1 [==============================] - 0s 250ms/step - loss: 0.0424 - mean_absolute_error: 0.1556 - val_loss: 0.1068 - val_mean_absolute_error: 0.2645
# Epoch 96/150
# 1/1 [==============================] - 0s 254ms/step - loss: 0.0409 - mean_absolute_error: 0.1510 - val_loss: 0.1089 - val_mean_absolute_error: 0.2675
# Epoch 97/150
# 1/1 [==============================] - 0s 242ms/step - loss: 0.0515 - mean_absolute_error: 0.1649 - val_loss: 0.1100 - val_mean_absolute_error: 0.2684
# Epoch 98/150
# 1/1 [==============================] - 0s 282ms/step - loss: 0.0568 - mean_absolute_error: 0.1658 - val_loss: 0.1111 - val_mean_absolute_error: 0.2708
# Epoch 99/150
# 1/1 [==============================] - 0s 275ms/step - loss: 0.0598 - mean_absolute_error: 0.1648 - val_loss: 0.0994 - val_mean_absolute_error: 0.2594
# Epoch 100/150
# 1/1 [==============================] - 0s 255ms/step - loss: 0.0619 - mean_absolute_error: 0.1687 - val_loss: 0.0986 - val_mean_absolute_error: 0.2598
# Epoch 101/150
# 1/1 [==============================] - 0s 249ms/step - loss: 0.0878 - mean_absolute_error: 0.1905 - val_loss: 0.1028 - val_mean_absolute_error: 0.2663
# Epoch 102/150
# 1/1 [==============================] - 0s 275ms/step - loss: 0.0666 - mean_absolute_error: 0.1771 - val_loss: 0.1086 - val_mean_absolute_error: 0.2695
# Epoch 103/150
# 1/1 [==============================] - 0s 243ms/step - loss: 0.0697 - mean_absolute_error: 0.1778 - val_loss: 0.0964 - val_mean_absolute_error: 0.2572
# Epoch 104/150
# 1/1 [==============================] - 0s 275ms/step - loss: 0.0642 - mean_absolute_error: 0.1755 - val_loss: 0.1224 - val_mean_absolute_error: 0.2863
# Epoch 105/150
# 1/1 [==============================] - 0s 237ms/step - loss: 0.0632 - mean_absolute_error: 0.1801 - val_loss: 0.1032 - val_mean_absolute_error: 0.2604
# Epoch 106/150
# 1/1 [==============================] - 0s 282ms/step - loss: 0.0602 - mean_absolute_error: 0.1768 - val_loss: 0.1052 - val_mean_absolute_error: 0.2626
# Epoch 107/150
# 1/1 [==============================] - 0s 263ms/step - loss: 0.0499 - mean_absolute_error: 0.1671 - val_loss: 0.1143 - val_mean_absolute_error: 0.2744
# Epoch 108/150
# 1/1 [==============================] - 0s 270ms/step - loss: 0.0602 - mean_absolute_error: 0.1812 - val_loss: 0.1155 - val_mean_absolute_error: 0.2759
# Epoch 109/150
# 1/1 [==============================] - 0s 249ms/step - loss: 0.0620 - mean_absolute_error: 0.1777 - val_loss: 0.1170 - val_mean_absolute_error: 0.2785
# Epoch 110/150
# 1/1 [==============================] - 0s 285ms/step - loss: 0.0507 - mean_absolute_error: 0.1643 - val_loss: 0.1132 - val_mean_absolute_error: 0.2747
# Epoch 111/150
# 1/1 [==============================] - 0s 271ms/step - loss: 0.0515 - mean_absolute_error: 0.1656 - val_loss: 0.1098 - val_mean_absolute_error: 0.2669
# Epoch 112/150
# 1/1 [==============================] - 0s 237ms/step - loss: 0.0532 - mean_absolute_error: 0.1646 - val_loss: 0.1046 - val_mean_absolute_error: 0.2599
# Epoch 113/150
# 1/1 [==============================] - 0s 253ms/step - loss: 0.0515 - mean_absolute_error: 0.1570 - val_loss: 0.1053 - val_mean_absolute_error: 0.2606
# Epoch 114/150
# 1/1 [==============================] - 0s 255ms/step - loss: 0.0573 - mean_absolute_error: 0.1645 - val_loss: 0.1017 - val_mean_absolute_error: 0.2504
# Epoch 115/150
# 1/1 [==============================] - 0s 263ms/step - loss: 0.0483 - mean_absolute_error: 0.1533 - val_loss: 0.1014 - val_mean_absolute_error: 0.2484
# Epoch 116/150
# 1/1 [==============================] - 0s 240ms/step - loss: 0.0509 - mean_absolute_error: 0.1679 - val_loss: 0.1103 - val_mean_absolute_error: 0.2583
# Epoch 117/150
# 1/1 [==============================] - 0s 267ms/step - loss: 0.0577 - mean_absolute_error: 0.1680 - val_loss: 0.0967 - val_mean_absolute_error: 0.2462
# Epoch 118/150
# 1/1 [==============================] - 0s 235ms/step - loss: 0.0560 - mean_absolute_error: 0.1700 - val_loss: 0.1045 - val_mean_absolute_error: 0.2502
# Epoch 119/150
# 1/1 [==============================] - 0s 283ms/step - loss: 0.0451 - mean_absolute_error: 0.1561 - val_loss: 0.0978 - val_mean_absolute_error: 0.2494
# Epoch 120/150
# 1/1 [==============================] - 0s 250ms/step - loss: 0.0542 - mean_absolute_error: 0.1649 - val_loss: 0.1008 - val_mean_absolute_error: 0.2538
# Epoch 121/150
# 1/1 [==============================] - 0s 259ms/step - loss: 0.0379 - mean_absolute_error: 0.1479 - val_loss: 0.1032 - val_mean_absolute_error: 0.2589
# Epoch 122/150
# 1/1 [==============================] - 0s 265ms/step - loss: 0.0412 - mean_absolute_error: 0.1523 - val_loss: 0.1051 - val_mean_absolute_error: 0.2627
# Epoch 123/150
# 1/1 [==============================] - 0s 279ms/step - loss: 0.0527 - mean_absolute_error: 0.1627 - val_loss: 0.1117 - val_mean_absolute_error: 0.2701
# Epoch 124/150
# 1/1 [==============================] - 0s 252ms/step - loss: 0.0431 - mean_absolute_error: 0.1486 - val_loss: 0.1012 - val_mean_absolute_error: 0.2611
# Epoch 125/150
# 1/1 [==============================] - 0s 303ms/step - loss: 0.0454 - mean_absolute_error: 0.1563 - val_loss: 0.0998 - val_mean_absolute_error: 0.2573
# Epoch 126/150
# 1/1 [==============================] - 0s 272ms/step - loss: 0.0429 - mean_absolute_error: 0.1573 - val_loss: 0.1032 - val_mean_absolute_error: 0.2584
# Epoch 127/150
# 1/1 [==============================] - 0s 270ms/step - loss: 0.0452 - mean_absolute_error: 0.1543 - val_loss: 0.1067 - val_mean_absolute_error: 0.2637
# Epoch 128/150
# 1/1 [==============================] - 0s 259ms/step - loss: 0.0447 - mean_absolute_error: 0.1524 - val_loss: 0.0929 - val_mean_absolute_error: 0.2459
# Epoch 129/150
# 1/1 [==============================] - 0s 249ms/step - loss: 0.0503 - mean_absolute_error: 0.1603 - val_loss: 0.1103 - val_mean_absolute_error: 0.2634
# Epoch 130/150
# 1/1 [==============================] - 0s 262ms/step - loss: 0.0435 - mean_absolute_error: 0.1548 - val_loss: 0.1005 - val_mean_absolute_error: 0.2540
# Epoch 131/150
# 1/1 [==============================] - 0s 297ms/step - loss: 0.0438 - mean_absolute_error: 0.1521 - val_loss: 0.0926 - val_mean_absolute_error: 0.2450
# Epoch 132/150
# 1/1 [==============================] - 0s 262ms/step - loss: 0.0358 - mean_absolute_error: 0.1427 - val_loss: 0.1021 - val_mean_absolute_error: 0.2590
# Epoch 133/150
# 1/1 [==============================] - 0s 242ms/step - loss: 0.0478 - mean_absolute_error: 0.1565 - val_loss: 0.1019 - val_mean_absolute_error: 0.2569
# Epoch 134/150
# 1/1 [==============================] - 0s 269ms/step - loss: 0.0409 - mean_absolute_error: 0.1497 - val_loss: 0.1056 - val_mean_absolute_error: 0.2629
# Epoch 135/150
# 1/1 [==============================] - 0s 243ms/step - loss: 0.0369 - mean_absolute_error: 0.1428 - val_loss: 0.1036 - val_mean_absolute_error: 0.2618
# Epoch 136/150
# 1/1 [==============================] - 0s 242ms/step - loss: 0.0418 - mean_absolute_error: 0.1485 - val_loss: 0.1016 - val_mean_absolute_error: 0.2584
# Epoch 137/150
# 1/1 [==============================] - 0s 272ms/step - loss: 0.0368 - mean_absolute_error: 0.1449 - val_loss: 0.1019 - val_mean_absolute_error: 0.2581
# Epoch 138/150
# 1/1 [==============================] - 0s 295ms/step - loss: 0.0403 - mean_absolute_error: 0.1502 - val_loss: 0.1014 - val_mean_absolute_error: 0.2611
# Epoch 139/150
# 1/1 [==============================] - 0s 276ms/step - loss: 0.0444 - mean_absolute_error: 0.1524 - val_loss: 0.1001 - val_mean_absolute_error: 0.2548
# Epoch 140/150
# 1/1 [==============================] - 0s 273ms/step - loss: 0.0387 - mean_absolute_error: 0.1444 - val_loss: 0.1052 - val_mean_absolute_error: 0.2609
# Epoch 141/150
# 1/1 [==============================] - 0s 300ms/step - loss: 0.0385 - mean_absolute_error: 0.1461 - val_loss: 0.1155 - val_mean_absolute_error: 0.2739
# Epoch 142/150
# 1/1 [==============================] - 0s 260ms/step - loss: 0.0380 - mean_absolute_error: 0.1468 - val_loss: 0.1004 - val_mean_absolute_error: 0.2596
# Epoch 143/150
# 1/1 [==============================] - 0s 250ms/step - loss: 0.0414 - mean_absolute_error: 0.1498 - val_loss: 0.1136 - val_mean_absolute_error: 0.2721
# Epoch 144/150
# 1/1 [==============================] - 0s 273ms/step - loss: 0.0363 - mean_absolute_error: 0.1412 - val_loss: 0.1014 - val_mean_absolute_error: 0.2614
# Epoch 145/150
# 1/1 [==============================] - 0s 280ms/step - loss: 0.0388 - mean_absolute_error: 0.1465 - val_loss: 0.1039 - val_mean_absolute_error: 0.2611
# Epoch 146/150
# 1/1 [==============================] - 0s 255ms/step - loss: 0.0364 - mean_absolute_error: 0.1438 - val_loss: 0.0953 - val_mean_absolute_error: 0.2552
# Epoch 147/150
# 1/1 [==============================] - 0s 291ms/step - loss: 0.0365 - mean_absolute_error: 0.1425 - val_loss: 0.1031 - val_mean_absolute_error: 0.2629
# Epoch 148/150
# 1/1 [==============================] - 0s 248ms/step - loss: 0.0344 - mean_absolute_error: 0.1426 - val_loss: 0.1044 - val_mean_absolute_error: 0.2647
# Epoch 149/150
# 1/1 [==============================] - 0s 250ms/step - loss: 0.0361 - mean_absolute_error: 0.1409 - val_loss: 0.0977 - val_mean_absolute_error: 0.2579
# Epoch 150/150
# 1/1 [==============================] - 0s 280ms/step - loss: 0.0337 - mean_absolute_error: 0.1402 - val_loss: 0.0913 - val_mean_absolute_error: 0.2516
# 1/1 [==============================] - 0s 128ms/step - loss: 0.0995 - mean_absolute_error: 0.2574
# val performance = [0.09950731694698334, 0.2574203908443451]
# test performance =  [0.08939381688833237, 0.23023824393749237]

# %% [markdown]
# **CNN model**

# %%
CONV_WIDTH = 7
CONV_LAYER_NO = 1
multi_conv_model = tf.keras.Sequential([
    # Shape [batch, time, features] => [batch, CONV_WIDTH, features]
    tf.keras.layers.Lambda(lambda x: x[:, -(CONV_WIDTH*CONV_LAYER_NO-CONV_LAYER_NO+1):, :]),
] + [
    # Shape => [batch, 1, conv_units]
    tf.keras.layers.Conv1D(1024, activation='relu', kernel_size=(CONV_WIDTH)) for i in range(CONV_LAYER_NO)
] + [
    # Shape => [batch, 1,  out_steps*features]
    tf.keras.layers.Dense(OUT_STEPS*out_num_features,
                          kernel_initializer=tf.initializers.zeros),
    # Shape => [batch, out_steps, features]
    tf.keras.layers.Reshape([OUT_STEPS, out_num_features])
])

# %%
history = compile_and_fit(multi_conv_model, multi_window)

#IPython.display.clear_output()

multi_val_performance['Conv'] = multi_conv_model.evaluate(multi_window.val)
multi_performance['Conv'] = multi_conv_model.evaluate(multi_window.test, verbose=0)
print('val performance =', multi_val_performance['Conv'])
print('test performance = ', multi_performance['Conv'])
# Out:
# Epoch 1/150
# 1/1 [==============================] - 1s 774ms/step - loss: 0.7376 - mean_absolute_error: 0.6753 - val_loss: 0.3089 - val_mean_absolute_error: 0.4969
# Epoch 2/150
# 1/1 [==============================] - 0s 268ms/step - loss: 0.5936 - mean_absolute_error: 0.6051 - val_loss: 0.1575 - val_mean_absolute_error: 0.3444
# Epoch 3/150
# 1/1 [==============================] - 0s 258ms/step - loss: 0.4284 - mean_absolute_error: 0.4883 - val_loss: 0.0754 - val_mean_absolute_error: 0.2171
# Epoch 4/150
# 1/1 [==============================] - 0s 229ms/step - loss: 0.3493 - mean_absolute_error: 0.4203 - val_loss: 0.1650 - val_mean_absolute_error: 0.3440
# Epoch 5/150
# 1/1 [==============================] - 0s 227ms/step - loss: 0.3572 - mean_absolute_error: 0.4352 - val_loss: 0.1737 - val_mean_absolute_error: 0.3539
# Epoch 6/150
# 1/1 [==============================] - 0s 258ms/step - loss: 0.2952 - mean_absolute_error: 0.4249 - val_loss: 0.1696 - val_mean_absolute_error: 0.3408
# Epoch 7/150
# 1/1 [==============================] - 0s 243ms/step - loss: 0.1917 - mean_absolute_error: 0.3464 - val_loss: 0.1520 - val_mean_absolute_error: 0.3157
# Epoch 8/150
# 1/1 [==============================] - 0s 247ms/step - loss: 0.1476 - mean_absolute_error: 0.2853 - val_loss: 0.1608 - val_mean_absolute_error: 0.3287
# Epoch 9/150
# 1/1 [==============================] - 0s 279ms/step - loss: 0.1155 - mean_absolute_error: 0.2583 - val_loss: 0.1413 - val_mean_absolute_error: 0.3150
# Epoch 10/150
# 1/1 [==============================] - 0s 254ms/step - loss: 0.1157 - mean_absolute_error: 0.2599 - val_loss: 0.1314 - val_mean_absolute_error: 0.3089
# Epoch 11/150
# 1/1 [==============================] - 0s 231ms/step - loss: 0.1333 - mean_absolute_error: 0.2881 - val_loss: 0.1277 - val_mean_absolute_error: 0.3057
# Epoch 12/150
# 1/1 [==============================] - 0s 239ms/step - loss: 0.0982 - mean_absolute_error: 0.2549 - val_loss: 0.1089 - val_mean_absolute_error: 0.2822
# Epoch 13/150
# 1/1 [==============================] - 0s 245ms/step - loss: 0.1145 - mean_absolute_error: 0.2599 - val_loss: 0.1221 - val_mean_absolute_error: 0.2960
# Epoch 14/150
# 1/1 [==============================] - 0s 258ms/step - loss: 0.1059 - mean_absolute_error: 0.2432 - val_loss: 0.1252 - val_mean_absolute_error: 0.3025
# Epoch 15/150
# 1/1 [==============================] - 0s 249ms/step - loss: 0.1243 - mean_absolute_error: 0.2486 - val_loss: 0.1140 - val_mean_absolute_error: 0.2825
# Epoch 16/150
# 1/1 [==============================] - 0s 242ms/step - loss: 0.1002 - mean_absolute_error: 0.2270 - val_loss: 0.0969 - val_mean_absolute_error: 0.2560
# Epoch 17/150
# 1/1 [==============================] - 0s 266ms/step - loss: 0.0976 - mean_absolute_error: 0.2191 - val_loss: 0.0718 - val_mean_absolute_error: 0.2199
# Epoch 18/150
# 1/1 [==============================] - 0s 245ms/step - loss: 0.0766 - mean_absolute_error: 0.2038 - val_loss: 0.0747 - val_mean_absolute_error: 0.2245
# Epoch 19/150
# 1/1 [==============================] - 0s 237ms/step - loss: 0.0710 - mean_absolute_error: 0.1975 - val_loss: 0.0872 - val_mean_absolute_error: 0.2401
# Epoch 20/150
# 1/1 [==============================] - 0s 215ms/step - loss: 0.0849 - mean_absolute_error: 0.2217 - val_loss: 0.0773 - val_mean_absolute_error: 0.2298
# Epoch 21/150
# 1/1 [==============================] - 0s 256ms/step - loss: 0.0743 - mean_absolute_error: 0.2087 - val_loss: 0.0660 - val_mean_absolute_error: 0.2179
# Epoch 22/150
# 1/1 [==============================] - 0s 234ms/step - loss: 0.0765 - mean_absolute_error: 0.2047 - val_loss: 0.0565 - val_mean_absolute_error: 0.1997
# Epoch 23/150
# 1/1 [==============================] - 0s 247ms/step - loss: 0.0597 - mean_absolute_error: 0.1895 - val_loss: 0.0584 - val_mean_absolute_error: 0.2023
# Epoch 24/150
# 1/1 [==============================] - 0s 238ms/step - loss: 0.0662 - mean_absolute_error: 0.1956 - val_loss: 0.0604 - val_mean_absolute_error: 0.2057
# Epoch 25/150
# 1/1 [==============================] - 0s 234ms/step - loss: 0.0616 - mean_absolute_error: 0.1925 - val_loss: 0.0580 - val_mean_absolute_error: 0.1995
# Epoch 26/150
# 1/1 [==============================] - 0s 232ms/step - loss: 0.0610 - mean_absolute_error: 0.1885 - val_loss: 0.0623 - val_mean_absolute_error: 0.2059
# Epoch 27/150
# 1/1 [==============================] - 0s 259ms/step - loss: 0.0585 - mean_absolute_error: 0.1784 - val_loss: 0.0680 - val_mean_absolute_error: 0.2131
# Epoch 28/150
# 1/1 [==============================] - 0s 253ms/step - loss: 0.0545 - mean_absolute_error: 0.1733 - val_loss: 0.0761 - val_mean_absolute_error: 0.2281
# Epoch 29/150
# 1/1 [==============================] - 0s 230ms/step - loss: 0.0589 - mean_absolute_error: 0.1767 - val_loss: 0.0692 - val_mean_absolute_error: 0.2160
# Epoch 30/150
# 1/1 [==============================] - 0s 246ms/step - loss: 0.0431 - mean_absolute_error: 0.1572 - val_loss: 0.0741 - val_mean_absolute_error: 0.2258
# Epoch 31/150
# 1/1 [==============================] - 0s 218ms/step - loss: 0.0446 - mean_absolute_error: 0.1612 - val_loss: 0.0695 - val_mean_absolute_error: 0.2179
# Epoch 32/150
# 1/1 [==============================] - 0s 231ms/step - loss: 0.0541 - mean_absolute_error: 0.1713 - val_loss: 0.0660 - val_mean_absolute_error: 0.2126
# Epoch 33/150
# 1/1 [==============================] - 0s 246ms/step - loss: 0.0511 - mean_absolute_error: 0.1686 - val_loss: 0.0700 - val_mean_absolute_error: 0.2210
# Epoch 34/150
# 1/1 [==============================] - 0s 243ms/step - loss: 0.0367 - mean_absolute_error: 0.1479 - val_loss: 0.0704 - val_mean_absolute_error: 0.2236
# Epoch 35/150
# 1/1 [==============================] - 0s 248ms/step - loss: 0.0459 - mean_absolute_error: 0.1604 - val_loss: 0.0711 - val_mean_absolute_error: 0.2243
# Epoch 36/150
# 1/1 [==============================] - 0s 248ms/step - loss: 0.0435 - mean_absolute_error: 0.1542 - val_loss: 0.0699 - val_mean_absolute_error: 0.2214
# Epoch 37/150
# 1/1 [==============================] - 0s 222ms/step - loss: 0.0418 - mean_absolute_error: 0.1533 - val_loss: 0.0624 - val_mean_absolute_error: 0.2070
# Epoch 38/150
# 1/1 [==============================] - 0s 213ms/step - loss: 0.0361 - mean_absolute_error: 0.1443 - val_loss: 0.0651 - val_mean_absolute_error: 0.2135
# Epoch 39/150
# 1/1 [==============================] - 0s 263ms/step - loss: 0.0391 - mean_absolute_error: 0.1492 - val_loss: 0.0703 - val_mean_absolute_error: 0.2212
# Epoch 40/150
# 1/1 [==============================] - 0s 242ms/step - loss: 0.0368 - mean_absolute_error: 0.1458 - val_loss: 0.0677 - val_mean_absolute_error: 0.2173
# Epoch 41/150
# 1/1 [==============================] - 0s 210ms/step - loss: 0.0380 - mean_absolute_error: 0.1480 - val_loss: 0.0664 - val_mean_absolute_error: 0.2122
# Epoch 42/150
# 1/1 [==============================] - 0s 268ms/step - loss: 0.0444 - mean_absolute_error: 0.1554 - val_loss: 0.0589 - val_mean_absolute_error: 0.1995
# Epoch 43/150
# 1/1 [==============================] - 0s 241ms/step - loss: 0.0358 - mean_absolute_error: 0.1451 - val_loss: 0.0658 - val_mean_absolute_error: 0.2133
# Epoch 44/150
# 1/1 [==============================] - 0s 255ms/step - loss: 0.0368 - mean_absolute_error: 0.1425 - val_loss: 0.0687 - val_mean_absolute_error: 0.2137
# Epoch 45/150
# 1/1 [==============================] - 0s 247ms/step - loss: 0.0364 - mean_absolute_error: 0.1420 - val_loss: 0.0699 - val_mean_absolute_error: 0.2173
# Epoch 46/150
# 1/1 [==============================] - 0s 251ms/step - loss: 0.0388 - mean_absolute_error: 0.1460 - val_loss: 0.0613 - val_mean_absolute_error: 0.2048
# Epoch 47/150
# 1/1 [==============================] - 0s 241ms/step - loss: 0.0329 - mean_absolute_error: 0.1334 - val_loss: 0.0640 - val_mean_absolute_error: 0.2098
# Epoch 48/150
# 1/1 [==============================] - 0s 222ms/step - loss: 0.0421 - mean_absolute_error: 0.1422 - val_loss: 0.0654 - val_mean_absolute_error: 0.2121
# Epoch 49/150
# 1/1 [==============================] - 0s 232ms/step - loss: 0.0386 - mean_absolute_error: 0.1393 - val_loss: 0.0680 - val_mean_absolute_error: 0.2180
# Epoch 50/150
# 1/1 [==============================] - 0s 244ms/step - loss: 0.0390 - mean_absolute_error: 0.1358 - val_loss: 0.0632 - val_mean_absolute_error: 0.2098
# Epoch 51/150
# 1/1 [==============================] - 0s 284ms/step - loss: 0.0361 - mean_absolute_error: 0.1356 - val_loss: 0.0675 - val_mean_absolute_error: 0.2171
# Epoch 52/150
# 1/1 [==============================] - 0s 234ms/step - loss: 0.0336 - mean_absolute_error: 0.1353 - val_loss: 0.0663 - val_mean_absolute_error: 0.2139
# Epoch 53/150
# 1/1 [==============================] - 0s 250ms/step - loss: 0.0354 - mean_absolute_error: 0.1384 - val_loss: 0.0654 - val_mean_absolute_error: 0.2137
# Epoch 54/150
# 1/1 [==============================] - 0s 274ms/step - loss: 0.0304 - mean_absolute_error: 0.1303 - val_loss: 0.0674 - val_mean_absolute_error: 0.2154
# Epoch 55/150
# 1/1 [==============================] - 0s 220ms/step - loss: 0.0330 - mean_absolute_error: 0.1313 - val_loss: 0.0683 - val_mean_absolute_error: 0.2183
# Epoch 56/150
# 1/1 [==============================] - 0s 262ms/step - loss: 0.0404 - mean_absolute_error: 0.1384 - val_loss: 0.0656 - val_mean_absolute_error: 0.2124
# Epoch 57/150
# 1/1 [==============================] - 0s 260ms/step - loss: 0.0370 - mean_absolute_error: 0.1354 - val_loss: 0.0689 - val_mean_absolute_error: 0.2154
# Epoch 58/150
# 1/1 [==============================] - 0s 226ms/step - loss: 0.0320 - mean_absolute_error: 0.1302 - val_loss: 0.0719 - val_mean_absolute_error: 0.2243
# Epoch 59/150
# 1/1 [==============================] - 0s 240ms/step - loss: 0.0333 - mean_absolute_error: 0.1338 - val_loss: 0.0741 - val_mean_absolute_error: 0.2281
# Epoch 60/150
# 1/1 [==============================] - 0s 242ms/step - loss: 0.0351 - mean_absolute_error: 0.1324 - val_loss: 0.0727 - val_mean_absolute_error: 0.2242
# Epoch 61/150
# 1/1 [==============================] - 0s 267ms/step - loss: 0.0264 - mean_absolute_error: 0.1224 - val_loss: 0.0708 - val_mean_absolute_error: 0.2225
# Epoch 62/150
# 1/1 [==============================] - 0s 249ms/step - loss: 0.0252 - mean_absolute_error: 0.1173 - val_loss: 0.0643 - val_mean_absolute_error: 0.2100
# Epoch 63/150
# 1/1 [==============================] - 0s 238ms/step - loss: 0.0281 - mean_absolute_error: 0.1261 - val_loss: 0.0629 - val_mean_absolute_error: 0.2094
# Epoch 64/150
# 1/1 [==============================] - 0s 257ms/step - loss: 0.0285 - mean_absolute_error: 0.1237 - val_loss: 0.0687 - val_mean_absolute_error: 0.2182
# Epoch 65/150
# 1/1 [==============================] - 0s 245ms/step - loss: 0.0279 - mean_absolute_error: 0.1236 - val_loss: 0.0680 - val_mean_absolute_error: 0.2165
# Epoch 66/150
# 1/1 [==============================] - 0s 230ms/step - loss: 0.0323 - mean_absolute_error: 0.1293 - val_loss: 0.0640 - val_mean_absolute_error: 0.2076
# Epoch 67/150
# 1/1 [==============================] - 0s 254ms/step - loss: 0.0288 - mean_absolute_error: 0.1238 - val_loss: 0.0593 - val_mean_absolute_error: 0.1987
# Epoch 68/150
# 1/1 [==============================] - 0s 256ms/step - loss: 0.0275 - mean_absolute_error: 0.1232 - val_loss: 0.0629 - val_mean_absolute_error: 0.2080
# Epoch 69/150
# 1/1 [==============================] - 0s 228ms/step - loss: 0.0304 - mean_absolute_error: 0.1275 - val_loss: 0.0715 - val_mean_absolute_error: 0.2210
# Epoch 70/150
# 1/1 [==============================] - 0s 242ms/step - loss: 0.0268 - mean_absolute_error: 0.1209 - val_loss: 0.0709 - val_mean_absolute_error: 0.2213
# Epoch 71/150
# 1/1 [==============================] - 0s 278ms/step - loss: 0.0311 - mean_absolute_error: 0.1250 - val_loss: 0.0658 - val_mean_absolute_error: 0.2153
# Epoch 72/150
# 1/1 [==============================] - 0s 221ms/step - loss: 0.0309 - mean_absolute_error: 0.1244 - val_loss: 0.0691 - val_mean_absolute_error: 0.2195
# Epoch 73/150
# 1/1 [==============================] - 0s 224ms/step - loss: 0.0335 - mean_absolute_error: 0.1296 - val_loss: 0.0693 - val_mean_absolute_error: 0.2195
# Epoch 74/150
# 1/1 [==============================] - 0s 257ms/step - loss: 0.0363 - mean_absolute_error: 0.1294 - val_loss: 0.0715 - val_mean_absolute_error: 0.2256
# Epoch 75/150
# 1/1 [==============================] - 0s 249ms/step - loss: 0.0297 - mean_absolute_error: 0.1215 - val_loss: 0.0649 - val_mean_absolute_error: 0.2135
# Epoch 76/150
# 1/1 [==============================] - 0s 255ms/step - loss: 0.0309 - mean_absolute_error: 0.1229 - val_loss: 0.0618 - val_mean_absolute_error: 0.2059
# Epoch 77/150
# 1/1 [==============================] - 0s 237ms/step - loss: 0.0301 - mean_absolute_error: 0.1243 - val_loss: 0.0622 - val_mean_absolute_error: 0.2068
# Epoch 78/150
# 1/1 [==============================] - 0s 244ms/step - loss: 0.0286 - mean_absolute_error: 0.1200 - val_loss: 0.0567 - val_mean_absolute_error: 0.1953
# Epoch 79/150
# 1/1 [==============================] - 0s 241ms/step - loss: 0.0315 - mean_absolute_error: 0.1252 - val_loss: 0.0616 - val_mean_absolute_error: 0.2060
# Epoch 80/150
# 1/1 [==============================] - 0s 269ms/step - loss: 0.0271 - mean_absolute_error: 0.1166 - val_loss: 0.0640 - val_mean_absolute_error: 0.2113
# Epoch 81/150
# 1/1 [==============================] - 0s 228ms/step - loss: 0.0317 - mean_absolute_error: 0.1243 - val_loss: 0.0651 - val_mean_absolute_error: 0.2122
# Epoch 82/150
# 1/1 [==============================] - 0s 251ms/step - loss: 0.0288 - mean_absolute_error: 0.1207 - val_loss: 0.0671 - val_mean_absolute_error: 0.2131
# Epoch 83/150
# 1/1 [==============================] - 0s 240ms/step - loss: 0.0300 - mean_absolute_error: 0.1201 - val_loss: 0.0723 - val_mean_absolute_error: 0.2245
# Epoch 84/150
# 1/1 [==============================] - 0s 259ms/step - loss: 0.0295 - mean_absolute_error: 0.1229 - val_loss: 0.0749 - val_mean_absolute_error: 0.2304
# Epoch 85/150
# 1/1 [==============================] - 0s 240ms/step - loss: 0.0316 - mean_absolute_error: 0.1223 - val_loss: 0.0662 - val_mean_absolute_error: 0.2148
# Epoch 86/150
# 1/1 [==============================] - 0s 265ms/step - loss: 0.0272 - mean_absolute_error: 0.1152 - val_loss: 0.0660 - val_mean_absolute_error: 0.2119
# Epoch 87/150
# 1/1 [==============================] - 0s 265ms/step - loss: 0.0372 - mean_absolute_error: 0.1242 - val_loss: 0.0640 - val_mean_absolute_error: 0.2084
# Epoch 88/150
# 1/1 [==============================] - 0s 241ms/step - loss: 0.0275 - mean_absolute_error: 0.1159 - val_loss: 0.0555 - val_mean_absolute_error: 0.1941
# Epoch 89/150
# 1/1 [==============================] - 0s 252ms/step - loss: 0.0248 - mean_absolute_error: 0.1164 - val_loss: 0.0657 - val_mean_absolute_error: 0.2107
# Epoch 90/150
# 1/1 [==============================] - 0s 268ms/step - loss: 0.0260 - mean_absolute_error: 0.1111 - val_loss: 0.0667 - val_mean_absolute_error: 0.2119
# Epoch 91/150
# 1/1 [==============================] - 0s 261ms/step - loss: 0.0288 - mean_absolute_error: 0.1201 - val_loss: 0.0664 - val_mean_absolute_error: 0.2098
# Epoch 92/150
# 1/1 [==============================] - 0s 270ms/step - loss: 0.0254 - mean_absolute_error: 0.1120 - val_loss: 0.0591 - val_mean_absolute_error: 0.1958
# Epoch 93/150
# 1/1 [==============================] - 0s 264ms/step - loss: 0.0259 - mean_absolute_error: 0.1152 - val_loss: 0.0590 - val_mean_absolute_error: 0.1996
# Epoch 94/150
# 1/1 [==============================] - 0s 249ms/step - loss: 0.0242 - mean_absolute_error: 0.1143 - val_loss: 0.0730 - val_mean_absolute_error: 0.2198
# Epoch 95/150
# 1/1 [==============================] - 0s 278ms/step - loss: 0.0264 - mean_absolute_error: 0.1178 - val_loss: 0.0654 - val_mean_absolute_error: 0.2079
# Epoch 96/150
# 1/1 [==============================] - 0s 230ms/step - loss: 0.0242 - mean_absolute_error: 0.1106 - val_loss: 0.0585 - val_mean_absolute_error: 0.1999
# Epoch 97/150
# 1/1 [==============================] - 0s 238ms/step - loss: 0.0324 - mean_absolute_error: 0.1215 - val_loss: 0.0636 - val_mean_absolute_error: 0.2078
# Epoch 98/150
# 1/1 [==============================] - 0s 253ms/step - loss: 0.0248 - mean_absolute_error: 0.1142 - val_loss: 0.0657 - val_mean_absolute_error: 0.2115
# Epoch 99/150
# 1/1 [==============================] - 0s 239ms/step - loss: 0.0260 - mean_absolute_error: 0.1174 - val_loss: 0.0662 - val_mean_absolute_error: 0.2140
# Epoch 100/150
# 1/1 [==============================] - 0s 225ms/step - loss: 0.0257 - mean_absolute_error: 0.1135 - val_loss: 0.0647 - val_mean_absolute_error: 0.2121
# Epoch 101/150
# 1/1 [==============================] - 0s 248ms/step - loss: 0.0270 - mean_absolute_error: 0.1141 - val_loss: 0.0600 - val_mean_absolute_error: 0.2003
# Epoch 102/150
# 1/1 [==============================] - 0s 266ms/step - loss: 0.0285 - mean_absolute_error: 0.1165 - val_loss: 0.0622 - val_mean_absolute_error: 0.2046
# Epoch 103/150
# 1/1 [==============================] - 0s 221ms/step - loss: 0.0251 - mean_absolute_error: 0.1124 - val_loss: 0.0539 - val_mean_absolute_error: 0.1877
# Epoch 104/150
# 1/1 [==============================] - 0s 239ms/step - loss: 0.0237 - mean_absolute_error: 0.1102 - val_loss: 0.0560 - val_mean_absolute_error: 0.1930
# Epoch 105/150
# 1/1 [==============================] - 0s 241ms/step - loss: 0.0275 - mean_absolute_error: 0.1137 - val_loss: 0.0563 - val_mean_absolute_error: 0.1957
# Epoch 106/150
# 1/1 [==============================] - 0s 257ms/step - loss: 0.0249 - mean_absolute_error: 0.1110 - val_loss: 0.0596 - val_mean_absolute_error: 0.2017
# Epoch 107/150
# 1/1 [==============================] - 0s 227ms/step - loss: 0.0207 - mean_absolute_error: 0.1039 - val_loss: 0.0626 - val_mean_absolute_error: 0.2047
# Epoch 108/150
# 1/1 [==============================] - 0s 248ms/step - loss: 0.0262 - mean_absolute_error: 0.1127 - val_loss: 0.0625 - val_mean_absolute_error: 0.2066
# Epoch 109/150
# 1/1 [==============================] - 0s 241ms/step - loss: 0.0252 - mean_absolute_error: 0.1109 - val_loss: 0.0686 - val_mean_absolute_error: 0.2178
# Epoch 110/150
# 1/1 [==============================] - 0s 238ms/step - loss: 0.0237 - mean_absolute_error: 0.1110 - val_loss: 0.0587 - val_mean_absolute_error: 0.1983
# Epoch 111/150
# 1/1 [==============================] - 0s 242ms/step - loss: 0.0233 - mean_absolute_error: 0.1065 - val_loss: 0.0626 - val_mean_absolute_error: 0.2036
# Epoch 112/150
# 1/1 [==============================] - 0s 264ms/step - loss: 0.0254 - mean_absolute_error: 0.1120 - val_loss: 0.0628 - val_mean_absolute_error: 0.2030
# Epoch 113/150
# 1/1 [==============================] - 0s 241ms/step - loss: 0.0239 - mean_absolute_error: 0.1094 - val_loss: 0.0553 - val_mean_absolute_error: 0.1929
# Epoch 114/150
# 1/1 [==============================] - 0s 217ms/step - loss: 0.0252 - mean_absolute_error: 0.1086 - val_loss: 0.0644 - val_mean_absolute_error: 0.2065
# Epoch 115/150
# 1/1 [==============================] - 0s 259ms/step - loss: 0.0214 - mean_absolute_error: 0.1029 - val_loss: 0.0647 - val_mean_absolute_error: 0.2088
# Epoch 116/150
# 1/1 [==============================] - 0s 224ms/step - loss: 0.0215 - mean_absolute_error: 0.1041 - val_loss: 0.0652 - val_mean_absolute_error: 0.2083
# Epoch 117/150
# 1/1 [==============================] - 0s 250ms/step - loss: 0.0267 - mean_absolute_error: 0.1133 - val_loss: 0.0579 - val_mean_absolute_error: 0.1930
# Epoch 118/150
# 1/1 [==============================] - 0s 271ms/step - loss: 0.0286 - mean_absolute_error: 0.1168 - val_loss: 0.0543 - val_mean_absolute_error: 0.1906
# Epoch 119/150
# 1/1 [==============================] - 0s 235ms/step - loss: 0.0235 - mean_absolute_error: 0.1083 - val_loss: 0.0665 - val_mean_absolute_error: 0.2066
# Epoch 120/150
# 1/1 [==============================] - 0s 239ms/step - loss: 0.0243 - mean_absolute_error: 0.1103 - val_loss: 0.0619 - val_mean_absolute_error: 0.2007
# Epoch 121/150
# 1/1 [==============================] - 0s 243ms/step - loss: 0.0257 - mean_absolute_error: 0.1083 - val_loss: 0.0540 - val_mean_absolute_error: 0.1909
# Epoch 122/150
# 1/1 [==============================] - 0s 236ms/step - loss: 0.0246 - mean_absolute_error: 0.1073 - val_loss: 0.0566 - val_mean_absolute_error: 0.1947
# Epoch 123/150
# 1/1 [==============================] - 0s 265ms/step - loss: 0.0269 - mean_absolute_error: 0.1141 - val_loss: 0.0622 - val_mean_absolute_error: 0.2046
# Epoch 124/150
# 1/1 [==============================] - 0s 244ms/step - loss: 0.0238 - mean_absolute_error: 0.1068 - val_loss: 0.0612 - val_mean_absolute_error: 0.2046
# Epoch 125/150
# 1/1 [==============================] - 0s 270ms/step - loss: 0.0227 - mean_absolute_error: 0.1062 - val_loss: 0.0604 - val_mean_absolute_error: 0.2025
# Epoch 126/150
# 1/1 [==============================] - 0s 256ms/step - loss: 0.0211 - mean_absolute_error: 0.1036 - val_loss: 0.0583 - val_mean_absolute_error: 0.1960
# Epoch 127/150
# 1/1 [==============================] - 0s 246ms/step - loss: 0.0260 - mean_absolute_error: 0.1127 - val_loss: 0.0606 - val_mean_absolute_error: 0.2034
# Epoch 128/150
# 1/1 [==============================] - 0s 239ms/step - loss: 0.0231 - mean_absolute_error: 0.1042 - val_loss: 0.0566 - val_mean_absolute_error: 0.1932
# Epoch 129/150
# 1/1 [==============================] - 0s 267ms/step - loss: 0.0220 - mean_absolute_error: 0.1051 - val_loss: 0.0624 - val_mean_absolute_error: 0.2059
# Epoch 130/150
# 1/1 [==============================] - 0s 269ms/step - loss: 0.0250 - mean_absolute_error: 0.1117 - val_loss: 0.0619 - val_mean_absolute_error: 0.2042
# Epoch 131/150
# 1/1 [==============================] - 0s 251ms/step - loss: 0.0244 - mean_absolute_error: 0.1085 - val_loss: 0.0618 - val_mean_absolute_error: 0.2041
# Epoch 132/150
# 1/1 [==============================] - 0s 248ms/step - loss: 0.0233 - mean_absolute_error: 0.1083 - val_loss: 0.0634 - val_mean_absolute_error: 0.2055
# Epoch 133/150
# 1/1 [==============================] - 0s 271ms/step - loss: 0.0257 - mean_absolute_error: 0.1109 - val_loss: 0.0635 - val_mean_absolute_error: 0.2058
# Epoch 134/150
# 1/1 [==============================] - 0s 230ms/step - loss: 0.0291 - mean_absolute_error: 0.1138 - val_loss: 0.0658 - val_mean_absolute_error: 0.2115
# Epoch 135/150
# 1/1 [==============================] - 0s 247ms/step - loss: 0.0283 - mean_absolute_error: 0.1123 - val_loss: 0.0575 - val_mean_absolute_error: 0.1960
# Epoch 136/150
# 1/1 [==============================] - 0s 241ms/step - loss: 0.0250 - mean_absolute_error: 0.1100 - val_loss: 0.0634 - val_mean_absolute_error: 0.2043
# Epoch 137/150
# 1/1 [==============================] - 0s 224ms/step - loss: 0.0261 - mean_absolute_error: 0.1109 - val_loss: 0.0632 - val_mean_absolute_error: 0.2053
# Epoch 138/150
# 1/1 [==============================] - 0s 235ms/step - loss: 0.0225 - mean_absolute_error: 0.1046 - val_loss: 0.0531 - val_mean_absolute_error: 0.1887
# Epoch 139/150
# 1/1 [==============================] - 0s 246ms/step - loss: 0.0248 - mean_absolute_error: 0.1096 - val_loss: 0.0620 - val_mean_absolute_error: 0.2015
# Epoch 140/150
# 1/1 [==============================] - 0s 246ms/step - loss: 0.0256 - mean_absolute_error: 0.1119 - val_loss: 0.0595 - val_mean_absolute_error: 0.1978
# Epoch 141/150
# 1/1 [==============================] - 0s 246ms/step - loss: 0.0248 - mean_absolute_error: 0.1104 - val_loss: 0.0633 - val_mean_absolute_error: 0.2037
# Epoch 142/150
# 1/1 [==============================] - 0s 278ms/step - loss: 0.0258 - mean_absolute_error: 0.1130 - val_loss: 0.0557 - val_mean_absolute_error: 0.1889
# Epoch 143/150
# 1/1 [==============================] - 0s 282ms/step - loss: 0.0228 - mean_absolute_error: 0.1031 - val_loss: 0.0551 - val_mean_absolute_error: 0.1898
# Epoch 144/150
# 1/1 [==============================] - 0s 252ms/step - loss: 0.0253 - mean_absolute_error: 0.1125 - val_loss: 0.0693 - val_mean_absolute_error: 0.2132
# Epoch 145/150
# 1/1 [==============================] - 0s 245ms/step - loss: 0.0241 - mean_absolute_error: 0.1085 - val_loss: 0.0703 - val_mean_absolute_error: 0.2155
# Epoch 146/150
# 1/1 [==============================] - 0s 252ms/step - loss: 0.0299 - mean_absolute_error: 0.1142 - val_loss: 0.0575 - val_mean_absolute_error: 0.1970
# Epoch 147/150
# 1/1 [==============================] - 0s 250ms/step - loss: 0.0270 - mean_absolute_error: 0.1079 - val_loss: 0.0630 - val_mean_absolute_error: 0.2039
# Epoch 148/150
# 1/1 [==============================] - 0s 239ms/step - loss: 0.0215 - mean_absolute_error: 0.1065 - val_loss: 0.0614 - val_mean_absolute_error: 0.2010
# Epoch 149/150
# 1/1 [==============================] - 0s 242ms/step - loss: 0.0223 - mean_absolute_error: 0.1080 - val_loss: 0.0563 - val_mean_absolute_error: 0.1923
# Epoch 150/150
# 1/1 [==============================] - 0s 260ms/step - loss: 0.0224 - mean_absolute_error: 0.1068 - val_loss: 0.0532 - val_mean_absolute_error: 0.1877
# 1/1 [==============================] - 0s 111ms/step - loss: 0.0538 - mean_absolute_error: 0.1893
# val performance = [0.05379815027117729, 0.18932464718818665]
# test performance =  [0.04984414950013161, 0.16563519835472107]

# %%
multi_val_performance['Conv'] = multi_conv_model.evaluate(multi_window.val)
multi_performance['Conv'] = multi_conv_model.evaluate(multi_window.test, verbose=0)
print('val performance =', multi_val_performance['Conv'])
print('test performance = ', multi_performance['Conv'])
# Out:
# 1/1 [==============================] - 0s 140ms/step - loss: 0.0561 - mean_absolute_error: 0.1924
# val performance = [0.056100938469171524, 0.19239039719104767]
# test performance =  [0.05243118107318878, 0.17323140799999237]

# %% [markdown]
# **performance**

# %%
x = np.arange(len(multi_performance))
width = 0.3


metric_name = 'mean_absolute_error'
metric_index = multi_conv_model.metrics_names.index('mean_absolute_error')
val_mae = [v[metric_index] for v in multi_val_performance.values()]
test_mae = [v[metric_index] for v in multi_performance.values()]

plt.figure()
plt.bar(x - 0.17, val_mae, width, label='Validation')
plt.bar(x + 0.17, test_mae, width, label='Test')
plt.xticks(ticks=x, labels=multi_performance.keys(),
           rotation=45)
plt.ylabel(f'MAE (average over all times and outputs)')
_ = plt.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
multi_window.compa(elman_model, plot_col=out_features, windows=multi_window.example3)
# Out:
# p
# [645.00836   324.08884   168.89215     1.4607162 654.99146  ]
# o
# [654.2147    307.11932   168.41794     1.4334812 427.40152  ]
# 1.4072382
# 5.525381
# 0.28156897
# 1.8999225
# 53.24968

# %%
train_mean
# Out:
# 수온          1.616900e+01
# 수소이온농도      7.806489e+00
# 전기전도도       1.856745e+02
# 용존산소        9.814162e+00
# 총유기탄소       2.957587e+00
# 총질소         1.771791e+00
# 총인          1.902386e-02
# 클로로필-a      9.978119e+00
# Day sin     6.037102e-15
# Day cos     2.747704e-15
# Year sin   -5.681266e-08
# Year cos    2.053380e-05
# dtype: float64

# %%
31.669886 / 0.01902386
# Out:
# 1664.7455353435107

# %%
95.59061 / 9.978119
# Out:
# 9.580023048432276
