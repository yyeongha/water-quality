# %%
import pandas as pd
import numpy as np
import os

# %%
def util_filename_parser(file_name):
    name, year = file_name.split('_')
    year = int(year.split('.')[0])
    return name, year

basepath = 'data_test/한강/AWS/'

data = []
for entry in os.listdir(basepath):
    if os.path.isfile(os.path.join(basepath, entry)):
        name, year = util_filename_parser(entry)
        ass = {}
        ass['name'] = name
        ass['year'] = year
        ass['path'] = entry
        
        data.append(entry)
        
        #print(entry)
        #ass.append(entry)
        
data.sort()
print(data)

file_names = [data]
#df = pd.DataFrame(data)
#df = df.sort_values(by=['name','year'])
#a = df.groupby(['name']).size()

#print(a.colums())

#print(a)

#ass.sort()

#print(df)

#file_names = [ass]
# Out:
# ['남이섬_2016.xlsx', '남이섬_2017.xlsx', '남이섬_2018.xlsx', '남이섬_2019.xlsx', '남이섬_2020.xlsx', '외서_2016.xlsx', '외서_2017.xlsx', '외서_2018.xlsx', '외서_2019.xlsx', '외서_2020.xlsx', '읍내_2016.xlsx', '읍내_2017.xlsx', '읍내_2018.xlsx', '읍내_2019.xlsx', '읍내_2020.xlsx', '청평_2016.xlsx', '청평_2017.xlsx', '청평_2018.xlsx', '청평_2019.xlsx', '청평_2020.xlsx', '춘천_2016.xlsx', '춘천_2017.xlsx', '춘천_2018.xlsx', '춘천_2019.xlsx', '춘천_2020.xlsx', '화천_2016.xlsx', '화천_2017.xlsx', '화천_2018.xlsx', '화천_2019.xlsx', '화천_2020.xlsx']

# %%
in_folder = 'data_test/한강/AWS/'
out_folder = 'data_test/한강1/AWS/'

#file_names = [
    #['남이섬_2016.xlsx','남이섬_2017.xlsx','남이섬_2018.xlsx', '남이섬_2019.xlsx'],
    #['외서_2016.xlsx','외서_2017.xlsx','외서_2018.xlsx', '외서_2019.xlsx'],
    #['읍내_2016.xlsx','읍내_2017.xlsx','읍내_2018.xlsx', '읍내_2019.xlsx'],
    #['청평_2016.xlsx','청평_2017.xlsx','청평_2018.xlsx', '청평_2019.xlsx'],
    #['남이섬_2016.xlsx','남이섬_2017.xlsx','남이섬_2018.xlsx', '남이섬_2019.xlsx']
    #         ]

for i in range(len(file_names)):
    for j in range(len(file_names[i])):
        in_path = os.path.join(in_folder, file_names[i][j])
        print(in_path)
        df = pd.read_excel(in_path)
        print(df.shape)
        date_col = df.columns[0]
        
        df = df.drop_duplicates([date_col], keep="first")
        df = df.sort_values([date_col], axis=0)
        
        print(df.shape)
        
        out_path = os.path.join(out_folder, file_names[i][j])
        print(out_path)
        df.to_excel(out_path, index = False)
# Out:
# data_test/한강/AWS/남이섬_2016.xlsx
# (17568, 30)
# (8784, 30)
# data_test/한강1/AWS/남이섬_2016.xlsx
# data_test/한강/AWS/남이섬_2017.xlsx
# (17520, 30)
# (8760, 30)
# data_test/한강1/AWS/남이섬_2017.xlsx
# data_test/한강/AWS/남이섬_2018.xlsx
# (17520, 30)
# (8760, 30)
# data_test/한강1/AWS/남이섬_2018.xlsx
# data_test/한강/AWS/남이섬_2019.xlsx
# (17520, 30)
# (8760, 30)
# data_test/한강1/AWS/남이섬_2019.xlsx
# data_test/한강/AWS/남이섬_2020.xlsx
# (17568, 30)
# (8784, 30)
# data_test/한강1/AWS/남이섬_2020.xlsx
# data_test/한강/AWS/외서_2016.xlsx
# (17568, 30)
# (8784, 30)
# data_test/한강1/AWS/외서_2016.xlsx
# data_test/한강/AWS/외서_2017.xlsx
# (17520, 30)
# (8760, 30)
# data_test/한강1/AWS/외서_2017.xlsx
# data_test/한강/AWS/외서_2018.xlsx
# (17520, 30)
# (8760, 30)
# data_test/한강1/AWS/외서_2018.xlsx
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-71-a4fc9d9ce428> in <module>
# ...

# %%
in_folder = 'data_test/한강/AWS/'
out_folder = 'data_test/한강1/AWS/'

for i in range(len(file_names)):
    for j in range(len(file_names[i])):
        in_path = os.path.join(in_folder, file_names[i][j])
        print(in_path)
        df = pd.read_excel(in_path)

        print(df.shape)
        
        df = df.dropna(axis='rows', thresh=5)
        
        print(df.shape)
        
        out_path = os.path.join(out_folder, file_names[i][j])
        print(out_path)
        df.to_excel(out_path, index = False)
# Out:
# data_test/한강/AWS/남이섬_2016.xlsx
# Exception ignored in: <function ZipFile.__del__ at 0x7f5fe8b0f5f0>
# Traceback (most recent call last):
#   File "/home/jaewon/.pyenv/versions/3.7.9/lib/python3.7/zipfile.py", line 1809, in __del__
#     self.close()
#   File "/home/jaewon/.pyenv/versions/3.7.9/lib/python3.7/zipfile.py", line 1826, in close
#     self.fp.seek(self.start_dir)
# ValueError: seek of closed file
# (17568, 30)
# (8784, 30)
# data_test/한강1/AWS/남이섬_2016.xlsx
# data_test/한강/AWS/남이섬_2017.xlsx
# (17520, 30)
# (8760, 30)
# data_test/한강1/AWS/남이섬_2017.xlsx
# data_test/한강/AWS/남이섬_2018.xlsx
# (17520, 30)
# (8760, 30)
# data_test/한강1/AWS/남이섬_2018.xlsx
# data_test/한강/AWS/남이섬_2019.xlsx
# (17520, 30)
# (8760, 30)
# data_test/한강1/AWS/남이섬_2019.xlsx
# data_test/한강/AWS/남이섬_2020.xlsx
# (17568, 30)
# (8784, 30)
# data_test/한강1/AWS/남이섬_2020.xlsx
# data_test/한강/AWS/외서_2016.xlsx
# (17568, 30)
# (8784, 30)
# data_test/한강1/AWS/외서_2016.xlsx
# data_test/한강/AWS/외서_2017.xlsx
# (17520, 30)
# ...

# %%
#df = df.dropna(axis='rows', thresh=5)
#df.to_excel(input_file_name, index = False)

# %%
import datetime
print("마지막 돌린 날짜 : ")
print(datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# 마지막 돌린 날짜 :
# 2021-01-19 14:50:27
