# %%
import pandas as pd
import os

# %%
folder = 'data'
file_names = [['감천_2015.xlsx','감천_2016.xlsx', '감천_2017.xlsx', '감천_2018.xlsx', '감천_2019.xlsx'],
              ['도개_2015.xlsx','도개_2016.xlsx', '도개_2017.xlsx', '도개_2018.xlsx', '도개_2019.xlsx'],
              ['해평_2015.xlsx','해평_2016.xlsx', '해평_2017.xlsx', '해평_2018.xlsx', '해평_2019.xlsx']]

# %%
input_file_name = 'data/감천_2015.xlsx'
output_file_name = "22.xlsx"
csv_file = pd.read_excel(input_file_name)
csv_file
# Out:
#                   측정날짜 측정소명   수온  수소이온농도  전기전도도  용존산소  총유기탄소    총질소     총인  \
# 0     2015.05.01 00:00   감천  NaN     NaN    NaN   NaN    NaN    NaN    NaN
# 1     2015.05.01 01:00   감천  NaN     NaN    NaN   NaN    NaN    NaN    NaN
# 2     2015.05.01 02:00   감천  NaN     NaN    NaN   NaN    NaN    NaN    NaN
# 3     2015.05.01 03:00   감천  NaN     NaN    NaN   NaN    NaN    NaN    NaN
# 4     2015.05.01 04:00   감천  NaN     NaN    NaN   NaN    NaN    NaN    NaN
# ...                ...  ...  ...     ...    ...   ...    ...    ...    ...
# 5871  2015.12.31 19:00   감천  5.5     7.6  348.0  11.3    1.1  3.657  0.038
# 5872  2015.12.31 20:00   감천  5.2     7.6  347.0  11.4    1.1  3.634  0.037
# 5873  2015.12.31 21:00   감천  4.8     7.6  346.0  11.5    1.1  3.629  0.037
# 5874  2015.12.31 22:00   감천  4.5     7.6  342.0  11.6    1.1  3.635  0.037
# 5875  2015.12.31 23:00   감천  4.2     7.6  340.0  11.7    1.1  3.636  0.037
#
#       클로로필-a
# 0        NaN
# 1        NaN
# 2        NaN
# ...

# %%
csv_file['측정날짜']
# Out:
# 0       2015.05.01 00:00
# 1       2015.05.01 01:00
# 2       2015.05.01 02:00
# 3       2015.05.01 03:00
# 4       2015.05.01 04:00
#               ...
# 5871    2015.12.31 19:00
# 5872    2015.12.31 20:00
# 5873    2015.12.31 21:00
# 5874    2015.12.31 22:00
# 5875    2015.12.31 23:00
# Name: 측정날짜, Length: 5876, dtype: object

# %%
a = csv_file['측정날짜'].dt.strftime('%Y')
print(a[0] + "-01-01 00:00")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-fcc315015247> in <module>
# ----> 1 a = csv_file['측정날짜'].dt.strftime('%Y')
#       2 print(a[0] + "-01-01 00:00")
#
# ~/work/tf-2/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5133             or name in self._accessors
#    5134         ):
# -> 5135             return object.__getattribute__(self, name)
#    5136         else:
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~/work/tf-2/lib/python3.7/site-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     185             # we're accessing the attribute of the class, i.e., Dataset.geo
#     186             return self._accessor
# --> 187         accessor_obj = self._accessor(obj)
#     188         # Replace the property with the accessor object. Inspired by:
# ...

# %%
import datetime

# %%
df[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/work/tf-2/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-115-ad11118bc8f3> in <module>
# ----> 1 df[0]
#
# ...

# %%
columns = list(csv_file.columns)
year = csv_file['측정날짜'][0].dt.strftime('%Y')


date_time_str = str(year+'-01-01 00:00')
print(date_time_str)
date_time_obj = datetime.datetime.strptime(date_time_str, '%Y-%m-%d %H:%M')

print('Date:', date_time_obj.date())
print('Time:', date_time_obj.time())
print('Date-time:', date_time_obj)

print(str(year[0]+'-01-01 00:00'))

datetime.datetime.strptime((str(year[0]+'-01-01 00:00')), '%Y-%m-%d %H:%M')
# start = datetime.datetime(int(year[0]), 1, 1 )
print('1111')
# print(type(start))
# start = '2015-01-01 00:00'
# print('2222')
# print(type(start))
# print('333')
# # end = csv_file.iloc[-1][0]
# end = str(tt[0] + '-12-31 23:00')
# # end = '2015-12-31 23:00'
# print('sss')
# print(end)
# print('ssss')

ts_ms = pd.date_range(start , end, freq='H')
# ts_ms = pd.date_range('2015-01-01 00:00' , '2015-12-31 23:00', freq='H')
ts_ms = pd.DataFrame(ts_ms)
ts_ms.columns = [date_name]

csv_file[date_name] = pd.to_datetime(csv_file[date_name])

df = pd.concat([ts_ms, csv_file], axis=0)
df = df.drop_duplicates([date_name], keep="last")
df = df.sort_values([date_name], axis=0)

df.to_excel(output_file_name, index = False)
df
# Out:
# 0    2015
# 0    2015
# Name: 측정날짜, dtype: object
# adsf
# 0    2015-01-01 00:00
# 0    2015-01-01 00:00
# Name: 측정날짜, dtype: object
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-114-b1a2a449feca> in <module>
#       6 date_time_str = str(year+'-01-01 00:00')
#       7 print(date_time_str)
# ----> 8 date_time_obj = datetime.datetime.strptime(date_time_str, '%Y-%m-%d %H:%M')
#       9
#      10 print('Date:', date_time_obj.date())
#
# ~/.pyenv/versions/3.7.8/lib/python3.7/_strptime.py in _strptime_datetime(cls, data_string, format)
#     575     """Return a class cls instance based on the input string and the
#     576     format string."""
# --> 577     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#     578     tzname, gmtoff = tt[-2:]
#     579     args = tt[:6] + (fraction,)
#
# ...
